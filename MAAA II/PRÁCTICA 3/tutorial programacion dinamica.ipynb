# %% [markdown]
# # Notebook 6: Aprendizaje por refuerzo - Programación dinámica
#
# En este notebook nos familizarizaremos con [Gymnasium](https://gymnasium.farama.org/), una librería de Python para simular problemas que se pueden resolver utilizando aprendizaje por refuerzo.
# Además, desarrollaremos algunos métodos de control basados en programación dinámica.
#
# ## Gymnasium
# Gymnasium es una herramienta de OpenAI para desarrollar y comparar algoritmos de aprendizaje por refuerzo. Facilita la simulación de interacciones de un agente con entornos muy diversos.
#
# Para utilizar Gymnasium, el primer paso es importar la librería. Una vez hecho, podremos crear un entorno que nos permita simular el problema que deseemos de entre los muchos disponibles.
#
# En esta práctica utilizaremos un entorno muy sencillo que simula un *GridWorld*, es decir, un mundo compuesto por casillas por las que el agente podrá desplazarse. En particular, cargaremos el entorno `MiniGrid-Empty-5x5-v0` (más info sobre el entorno [aquí](https://minigrid.farama.org/))

# %%
# Si los paquetes no están instalados, hay que ejecutar estas líneas:
# !pip install gymnasium[classic-control]
# !pip install minigrid
import gymnasium as gym
import minigrid
import numpy as np
env = gym.make('MiniGrid-Empty-5x5-v0', render_mode='rgb_array')

# %% [markdown]
# El método `gym.make` devuelve un objeto de tipo entorno que nos ofrece, entre otros, los siguientes métodos y propiedades:
#  - `reset`: Devuelve el entorno a su estado original
#  - `actions`: Muestra una lista de las acciones disponibles
#  - `max_steps`: Fija el número máximo de acciones que puede realizar el agente en cada episodio
#  - `render`: Devuelve una imagen donde aparece representada la situación actual
#  - `step(accion)`: Ejecuta una acción y actualiza el entorno en consecuencia
#
#
# El objetivo del agente en este problema es alcanzar la **meta**, representada por una **casilla verde**. El **agente** aparece representado como una **flecha roja** que refleja su **posición** y **orientación**.

# %%
# Muestra las acciones disponibles ('left', 'right', 'forward', etc.)
acciones = env.get_wrapper_attr('actions')
print([a.name for a in acciones])

# Definimos una función para mostrar el estado del entorno
import matplotlib.pyplot as plt

def muestra_entorno(env:gym.Env) -> None:
    im = plt.imshow(env.render())
    plt.show()

# Resetea el entorno
env.reset()
# Mostramos el entorno en su estado inicial
muestra_entorno(env)

# TODO: Ejecuta la acción forward (puedes referirte a la acción i-ésima como acciones(i) o como acciones.nombre) y muestra el entorno de nuevo
env.step(acciones.forward)
muestra_entorno(env)

# TODO: Prueba a ver cómo afectan las distintas acciones al entorno
env.step(acciones.left)
muestra_entorno(env)


env.step(acciones.right)
muestra_entorno(env)


env.step(acciones.pickup)
muestra_entorno(env)
# Out:
# ['left', 'right', 'forward', 'pickup', 'drop', 'toggle', 'done']

# %% [markdown]
# El método [`step(acción)`](https://gymnasium.farama.org/api/env/#gymnasium.Env.step) devuelve cinco valores:
#  - Observación: Representa lo que puede percibir el agente del entorno en su estado actual
#  - Recompensa: Indica el valor de la señal de recompensa cuando se ejecuta una acción en un determinado estado.
#  - Terminated: Valor booleano que indica si se ha terminado el episodio
#  - Truncated: Valor booleano que indica si el episodio ha alcanzado el número máximo de pasos
#  - Info: Información adicional
#
# De cara a aprender una política, debemos buscar una manera de representar los estados. Habitualmente, el agente se basaría en sus observaciones para generar una representación del estado. Sin embargo, para este problema en particular, vamos a utilizar una representación del estado más sencilla que la observación que puede hacer el agente. Esta labor de representación del estado la llevará a cabo un **intérprete** que transformará las observaciones del entorno en un formato útil para el agente.
# ![Esquema de aprendizaje por refuerzo](https://raw.githubusercontent.com/eirasf/GCED-AA3/94f123b1ad1ec5686d86b8ce7c8cda757a26ca02/lab4/img/Reinforcement_learning_diagram.svg)
#
# El intérprete identificará el estado con un vector de tres componentes que indicarán, respectivamente, la columna, fila y orientación del agente. Las filas/columnas se numerarán del 0 al 2 (de arriba a abajo y derecha a izquierda) y la orientación podrá tomar los siguientes valores:
#  - 0 $\rightarrow$ derecha
#  - 1 $\rightarrow$ abajo
#  - 2 $\rightarrow$ izquierda
#  - 3 $\rightarrow$ arriba
#
# El entorno de este problema nos da acceso directo a dos variables que serán de utilidad:
#  - `agent_pos`: Indica la casilla en la que está el agente. Las casillas del tablero están numeradas del 1 al 3, por lo que será necesario adaptar dicha numeración.
#  - `agent_dir`: Indica la orientación del agente de acuerdo a la codificación descrita.
#
#  Puedes acceder a estos valores como `env.get_wrapper_attr('agent_pos')` y `env.get_wrapper_attr('agent_dir')` respectivamente.
# Creemos una función que haga las labores de intérprete y devuelva la codificación del estado actual del entorno:

# %%
from collections import namedtuple

# Representaremos los estados como tuplas con los siguientes campos con nombre:
#  - x: Representa la columna en que se encuentra el agente. La columna visitable más a la izquierda será la 0
#  - y: Representa la fila en que se encuentra el agente. La fila visitable más arriba será la 0
#  - dir: Representa la dirección en que apunta el agente. Respetaremos el código numérico indicado por agent_dir

Estado = namedtuple('Estado', ['x', 'y', 'dir'])


def get_estado(env:gym.Env) -> Estado:
    x, y = env.get_wrapper_attr("agent_pos")
    dir = env.get_wrapper_attr("agent_dir")
    return Estado(x-1, y-1, dir)

print()

env.reset()

# COMPROBACIÓN
estado_actual = get_estado(env)
assert estado_actual.x == 0, f'El estado inmediatamente después de resetear debe indicar x=0 y el tuyo indica {estado_actual.x}'
assert estado_actual.y == 0, f'El estado inmediatamente después de resetear debe indicar y=0 y el tuyo indica {estado_actual.y}'
assert estado_actual.dir == 0, f'El estado inmediatamente después de resetear debe indicar dir=0 y el tuyo indica {estado_actual.dir}'

# %% [markdown]
# ### Simulación de un episodio con política aleatoria
#
# Ahora que sabemos manejar el entorno, vamos a probar qué tal funciona una política aleatoria.
#
# Crea un bucle que simule un episodio completo siguiendo una política aleatoria, es decir, que aplique una acción aleatoria hasta que el entorno nos indique que el episodio ha acabado. Puedes obtener una acción aleatoria llamando a `env.action_space.sample()`.
#
# Muestra el entorno tras aplicar cada acción. Además muestra un mensaje que indique:
#  - Qué número de paso se ha ejecutado
#  - El nombre de la acción aplicada
#  - El estado resultante
#  - La recompensa obtenida en ese paso
#  - Si ha terminado la ejecución

# %%
env.reset()
# Eliminamos el límite de pasos por defecto por episodio. El episodio solo acabará al alcanzar la meta.
env.max_steps = float('inf')
print(f'Max steps modificado: {env.max_steps}')


completado = False
contador = 0
while not completado:
    # TODO - Completa el bucle
    accion_aleatoria = env.action_space.sample()
    observacion, recompensa, terminated, truncated, info = env.step(accion_aleatoria)
    estado = get_estado(env)
    contador += 1
    print("Número de paso: ", contador)
    print("Acción aplicada: ", accion_aleatoria)
    print("Estado resultante: ", estado)
    print("Recompensa obtenida: ", recompensa)
    if estado.x == 2 and estado.y == 2 :
        completado = True
    print("Ejecución completada? ", completado)
    muestra_entorno(env)
# Out:
# Max steps modificado: inf
# Número de paso:  1
# Acción aplicada:  0
# Estado resultante:  Estado(x=0, y=0, dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  2
# Acción aplicada:  3
# Estado resultante:  Estado(x=0, y=0, dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  3
# Acción aplicada:  6
# Estado resultante:  Estado(x=0, y=0, dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  4
# Acción aplicada:  3
# Estado resultante:  Estado(x=0, y=0, dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  5
# Acción aplicada:  6
# Estado resultante:  Estado(x=0, y=0, dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  6
# Acción aplicada:  5
# Estado resultante:  Estado(x=0, y=0, dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  7
# Acción aplicada:  5
# Estado resultante:  Estado(x=0, y=0, dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  8
# Acción aplicada:  0
# Estado resultante:  Estado(x=0, y=0, dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  9
# Acción aplicada:  4
# Estado resultante:  Estado(x=0, y=0, dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  10
# Acción aplicada:  2
# Estado resultante:  Estado(x=0, y=0, dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  11
# Acción aplicada:  6
# Estado resultante:  Estado(x=0, y=0, dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  12
# Acción aplicada:  2
# Estado resultante:  Estado(x=0, y=0, dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  13
# Acción aplicada:  1
# Estado resultante:  Estado(x=0, y=0, dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  14
# Acción aplicada:  6
# Estado resultante:  Estado(x=0, y=0, dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  15
# Acción aplicada:  0
# Estado resultante:  Estado(x=0, y=0, dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  16
# Acción aplicada:  3
# Estado resultante:  Estado(x=0, y=0, dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  17
# Acción aplicada:  4
# Estado resultante:  Estado(x=0, y=0, dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  18
# Acción aplicada:  2
# Estado resultante:  Estado(x=0, y=0, dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  19
# Acción aplicada:  1
# Estado resultante:  Estado(x=0, y=0, dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  20
# Acción aplicada:  4
# Estado resultante:  Estado(x=0, y=0, dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  21
# Acción aplicada:  2
# Estado resultante:  Estado(x=0, y=0, dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  22
# Acción aplicada:  6
# Estado resultante:  Estado(x=0, y=0, dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  23
# Acción aplicada:  5
# Estado resultante:  Estado(x=0, y=0, dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  24
# Acción aplicada:  5
# Estado resultante:  Estado(x=0, y=0, dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  25
# Acción aplicada:  2
# Estado resultante:  Estado(x=0, y=0, dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  26
# Acción aplicada:  1
# Estado resultante:  Estado(x=0, y=0, dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  27
# Acción aplicada:  0
# Estado resultante:  Estado(x=0, y=0, dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  28
# Acción aplicada:  1
# Estado resultante:  Estado(x=0, y=0, dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  29
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  30
# Acción aplicada:  0
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  31
# Acción aplicada:  1
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  32
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  33
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  34
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  35
# Acción aplicada:  0
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  36
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  37
# Acción aplicada:  5
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  38
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  39
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  40
# Acción aplicada:  1
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  41
# Acción aplicada:  6
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  42
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  43
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  44
# Acción aplicada:  0
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  45
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  46
# Acción aplicada:  1
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  47
# Acción aplicada:  5
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  48
# Acción aplicada:  0
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  49
# Acción aplicada:  6
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  50
# Acción aplicada:  1
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  51
# Acción aplicada:  5
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  52
# Acción aplicada:  6
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  53
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  54
# Acción aplicada:  5
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  55
# Acción aplicada:  0
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  56
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  57
# Acción aplicada:  1
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  58
# Acción aplicada:  1
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  59
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  60
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  61
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  62
# Acción aplicada:  1
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  63
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  64
# Acción aplicada:  6
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  65
# Acción aplicada:  6
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  66
# Acción aplicada:  5
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  67
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  68
# Acción aplicada:  1
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  69
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  70
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  71
# Acción aplicada:  6
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  72
# Acción aplicada:  6
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  73
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  74
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  75
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  76
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  77
# Acción aplicada:  5
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  78
# Acción aplicada:  6
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  79
# Acción aplicada:  5
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  80
# Acción aplicada:  6
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  81
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  82
# Acción aplicada:  5
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  83
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  84
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  85
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  86
# Acción aplicada:  0
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  87
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  88
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  89
# Acción aplicada:  1
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=3)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  90
# Acción aplicada:  0
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(0), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  91
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  92
# Acción aplicada:  0
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  93
# Acción aplicada:  6
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  94
# Acción aplicada:  0
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  95
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  96
# Acción aplicada:  1
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  97
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  98
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  99
# Acción aplicada:  6
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(0), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  100
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(1), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  101
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(1), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  102
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  103
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  104
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  105
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  106
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  107
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  108
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  109
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  110
# Acción aplicada:  1
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  111
# Acción aplicada:  0
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  112
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  113
# Acción aplicada:  6
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  114
# Acción aplicada:  5
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  115
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  116
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  117
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  118
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  119
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  120
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  121
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  122
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  123
# Acción aplicada:  0
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  124
# Acción aplicada:  1
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  125
# Acción aplicada:  6
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  126
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  127
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  128
# Acción aplicada:  5
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  129
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  130
# Acción aplicada:  5
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  131
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  132
# Acción aplicada:  5
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  133
# Acción aplicada:  1
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  134
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(0), y=np.int64(2), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  135
# Acción aplicada:  0
# Estado resultante:  Estado(x=np.int64(0), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  136
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(0), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  137
# Acción aplicada:  6
# Estado resultante:  Estado(x=np.int64(0), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  138
# Acción aplicada:  5
# Estado resultante:  Estado(x=np.int64(0), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  139
# Acción aplicada:  1
# Estado resultante:  Estado(x=np.int64(0), y=np.int64(2), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  140
# Acción aplicada:  5
# Estado resultante:  Estado(x=np.int64(0), y=np.int64(2), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  141
# Acción aplicada:  6
# Estado resultante:  Estado(x=np.int64(0), y=np.int64(2), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  142
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(0), y=np.int64(2), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  143
# Acción aplicada:  4
# Estado resultante:  Estado(x=np.int64(0), y=np.int64(2), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  144
# Acción aplicada:  5
# Estado resultante:  Estado(x=np.int64(0), y=np.int64(2), dir=2)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  145
# Acción aplicada:  0
# Estado resultante:  Estado(x=np.int64(0), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  146
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(0), y=np.int64(2), dir=1)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  147
# Acción aplicada:  0
# Estado resultante:  Estado(x=np.int64(0), y=np.int64(2), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  148
# Acción aplicada:  3
# Estado resultante:  Estado(x=np.int64(0), y=np.int64(2), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  149
# Acción aplicada:  5
# Estado resultante:  Estado(x=np.int64(0), y=np.int64(2), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  150
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  151
# Acción aplicada:  5
# Estado resultante:  Estado(x=np.int64(1), y=np.int64(2), dir=0)
# Recompensa obtenida:  0
# Ejecución completada?  False
# Número de paso:  152
# Acción aplicada:  2
# Estado resultante:  Estado(x=np.int64(2), y=np.int64(2), dir=0)
# Recompensa obtenida:  -0.3680000000000001
# Ejecución completada?  True

# %% [markdown]
# ### Simplificación del espacio de acciones y definición de políticas
# Habrás comprobado que hay acciones que no son útiles para este problema. Vamos a simplificar la búsqueda reduciendo el espacio de acciones a tres:
#  1. left
#  2. right
#  3. forward
#
# Al hacer esto, ya no podemos generar una acción aleatoria utilizando `env.action_space.sample()`. Además, dicha función elige una acción al azar, lo cual no nos interesa. Nuestro objetivo es obtener una **política** que determine la mejor acción en cada situación, así que vamos a aprovechar el momento para definir una estructura de datos que nos permita hacer eso.
#
# La política debe indicar una probabilidad $\pi(a|s)$ de elegir la acción $a$ estando en el estado $s$ (así que $\sum_{a'}\pi(a'|s)=1$, con $s\in \mathcal{S}$ y $a\in \mathcal{A}$). Declararemos una política como un `numpy.array` que asocie a cada estado $s$ una distribución de probabilidad sobre las distintas acciones.
#
# La política aleatoria otorgará la misma probabilidad a todas las acciones para cada estado (como hay tres acciones, para cualquier par estado-acción la probabilidad será 1/3).

# %%
# Seleccionamos solo las tres acciones indicadas
ACCIONES_UTILES = [acciones.left, acciones.right, acciones.forward]


# TODO - Indica el shape de la policy
politica_aleatoria = np.zeros((3, 3, 4, 3))     # XxYxDIRXACCION

# Inicializamos todos los valores a 1/3
politica_aleatoria[:] = 1.0/3

# %% [markdown]
# Una vez hemos definido la política, podemos definir una función para sustituir a `env.action_space.sample()`. Esta función recibirá la política que debe seguir y el estado para el que seleccionar la acción. Devolverá la acción muestreada siguiendo la distribución descrita por la política para ese estado.

# %%
def muestrea_politica(estado:Estado, politica:np.ndarray) -> int:
    # Obtenemos la distribución de probabilidad
    probs = politica[estado.x, estado.y, estado.dir, :]
    # Comprobación de que la política está bien (se puede comentar cuando estemos seguros de que es así)
    np.testing.assert_almost_equal(np.sum(probs), 1.0, err_msg='La política para un estado siempre debe sumar 1')
    # Devolvemos una acción aleatoria muestreada según las probabilidades indicadas por la política
    return np.random.choice(ACCIONES_UTILES, p=probs)

# TODO - Obtén la acción muestreada de la policy_aleatoria para el estado en que el agente está en la casilla central mirando hacia abajo
estado1 = Estado(1, 1, 1)
accion = muestrea_politica(estado1, politica_aleatoria)

print(accion)
# Out:
# 0

# %% [markdown]
# ### Simulación de episodios siguiendo una política prefijada
# Al disponer ya de una definición para políticas y de una función de muestreo sobre cualquier política, podemos adaptar nuestro bucle que simula un episodio para que lo haga siguiendo una política concreta.
#
# Definiremos una función llamada `simula_episodio` para ello. La función debe recibir la política a seguir y dos parámetros que nos indicarán, respectivamente, si se mostrarán los *renders* de los pasos del episodio y si se mostrarán mensajes de texto.
#
# La función deberá devolver una tupla con el **retorno** obtenido, es decir, la suma de las recompensas recibidas en cada paso y el **número de pasos** necesarios para completar el episodio.

# %%
def simula_episodio(politica:np.ndarray, muestra_renders:bool=False, imprime:bool=False) -> tuple[float, int]:
    env.reset()
    
    # TODO - Adapta el bucle que escribiste para la primera política aleatoria 3 celdas de código más arriba para que use la nueva política para decidir qué acción tomar en cada paso
    
    # Eliminamos el límite de pasos por defecto por episodio. El episodio solo acabará al alcanzar la meta.
    env.max_steps = float('inf')

    completado = False
    contador = 0
    estado_actual = Estado(0, 0, 0)
    retorno = 0
    while not completado:
        # TODO - Completa el bucle
        accion_escogida = muestrea_politica(estado_actual, politica)
        observacion, recompensa, terminated, truncated, info = env.step(accion_escogida)
        estado_actual = get_estado(env)
        retorno += recompensa
        contador += 1
        if estado_actual.x == 2 and estado_actual.y == 2 :
            completado = True
        if imprime:
            print("Número de paso: ", contador)
            print("Acción aplicada: ", accion_escogida)
            print("Estado resultante: ", estado_actual)
            print("Recompensa obtenida: ", recompensa)
            print("Ejecución completada? ", completado)
        if muestra_renders: muestra_entorno(env)
        
    return (retorno, contador)

retorno, num_pasos = simula_episodio(politica_aleatoria, muestra_renders=False, imprime=False)
print(f'Simulado un episodio con retorno = {retorno} y pasos = {num_pasos}')
# Out:
# Simulado un episodio con retorno = 0.469 y pasos = 59

# %% [markdown]
# ### Comprobación del rendimiento de la política
#
# Hagamos un experimento para evaluar la eficacia de la política aleatoria. Simularemos 200 episodios, anotando el número de pasos necesarios para completar cada uno. No es necesario que llevemos cuenta de los retornos obtenidos porque en este problema siempre será 1 (dado que solo la última acción da recompensa, con valor 1).
#
# Mostraremos estadísticas y gráficos que nos puedan ayudar a tener una idea de cómo de bien funciona.

# %%
def comprueba_politica(politica:np.ndarray) -> None:
    episodios_pasos = []

    # TODO - Simula 200 episodios, añadiendo sus respectivos números de pasos a episodios_pasos y mostrando por cada uno un mensaje de la forma '{iteracion} - Simulado un episodio con retorno {retorno} ({num_pasos})'
    for i in range(200):
        retorno, num_pasos = simula_episodio(politica, False, False)
        episodios_pasos.append(num_pasos)
        print(f'{i} - Simulado un episodio con retorno {retorno} y número de pasos = ({num_pasos})')

    assert(len(episodios_pasos)==200)

    # Mostramos un histograma para la duración de los episodios
    plt.hist(episodios_pasos)
    plt.show()

    # Mostramos también un diagrama de caja
    plt.boxplot(episodios_pasos)
    plt.show()

    # Por último, escribimos un par de estadísticas
    print('Se han necesitado de media',np.mean(episodios_pasos),'pasos (+-',np.std(episodios_pasos),')')
    print('El episodio más corto duró',np.min(episodios_pasos),'pasos y el episodio más largo duró',np.max(episodios_pasos),'pasos')

comprueba_politica(politica_aleatoria)
# Out:
# 0 - Simulado un episodio con retorno -1.205 y número de pasos = (245)
# 1 - Simulado un episodio con retorno 0.604 y número de pasos = (44)
# 2 - Simulado un episodio con retorno 0.7929999999999999 y número de pasos = (23)
# 3 - Simulado un episodio con retorno 0.04599999999999993 y número de pasos = (106)
# 4 - Simulado un episodio con retorno 0.739 y número de pasos = (29)
# 5 - Simulado un episodio con retorno 0.595 y número de pasos = (45)
# 6 - Simulado un episodio con retorno 0.07299999999999995 y número de pasos = (103)
# 7 - Simulado un episodio con retorno -0.14300000000000002 y número de pasos = (127)
# 8 - Simulado un episodio con retorno 0.21699999999999997 y número de pasos = (87)
# 9 - Simulado un episodio con retorno 0.5049999999999999 y número de pasos = (55)
# 10 - Simulado un episodio con retorno -0.647 y número de pasos = (183)
# 11 - Simulado un episodio con retorno 0.9369999999999999 y número de pasos = (7)
# 12 - Simulado un episodio con retorno 0.45999999999999996 y número de pasos = (60)
# 13 - Simulado un episodio con retorno 0.748 y número de pasos = (28)
# 14 - Simulado un episodio con retorno 0.946 y número de pasos = (6)
# 15 - Simulado un episodio con retorno -1.0160000000000005 y número de pasos = (224)
# 16 - Simulado un episodio con retorno -0.08000000000000007 y número de pasos = (120)
# 17 - Simulado un episodio con retorno 0.595 y número de pasos = (45)
# 18 - Simulado un episodio con retorno -0.16100000000000003 y número de pasos = (129)
# 19 - Simulado un episodio con retorno -0.1160000000000001 y número de pasos = (124)
# 20 - Simulado un episodio con retorno 0.6759999999999999 y número de pasos = (36)
# 21 - Simulado un episodio con retorno 0.07299999999999995 y número de pasos = (103)
# 22 - Simulado un episodio con retorno 0.379 y número de pasos = (69)
# 23 - Simulado un episodio con retorno 0.748 y número de pasos = (28)
# 24 - Simulado un episodio con retorno 0.32499999999999996 y número de pasos = (75)
# 25 - Simulado un episodio con retorno -0.647 y número de pasos = (183)
# 26 - Simulado un episodio con retorno 0.514 y número de pasos = (54)
# 27 - Simulado un episodio con retorno 0.43299999999999994 y número de pasos = (63)
# 28 - Simulado un episodio con retorno -0.548 y número de pasos = (172)
# 29 - Simulado un episodio con retorno 0.3969999999999999 y número de pasos = (67)
# 30 - Simulado un episodio con retorno -0.5660000000000001 y número de pasos = (174)
# 31 - Simulado un episodio con retorno 0.44199999999999995 y número de pasos = (62)
# 32 - Simulado un episodio con retorno 0.5589999999999999 y número de pasos = (49)
# 33 - Simulado un episodio con retorno 0.4059999999999999 y número de pasos = (66)
# 34 - Simulado un episodio con retorno 0.379 y número de pasos = (69)
# 35 - Simulado un episodio con retorno 0.4959999999999999 y número de pasos = (56)
# 36 - Simulado un episodio con retorno 0.685 y número de pasos = (35)
# 37 - Simulado un episodio con retorno 0.55 y número de pasos = (50)
# 38 - Simulado un episodio con retorno 0.892 y número de pasos = (12)
# 39 - Simulado un episodio con retorno 0.33399999999999996 y número de pasos = (74)
# 40 - Simulado un episodio con retorno 0.685 y número de pasos = (35)
# 41 - Simulado un episodio con retorno 0.712 y número de pasos = (32)
# 42 - Simulado un episodio con retorno 0.595 y número de pasos = (45)
# 43 - Simulado un episodio con retorno 0.712 y número de pasos = (32)
# 44 - Simulado un episodio con retorno -0.359 y número de pasos = (151)
# 45 - Simulado un episodio con retorno 0.6759999999999999 y número de pasos = (36)
# 46 - Simulado un episodio con retorno -0.10699999999999998 y número de pasos = (123)
# 47 - Simulado un episodio con retorno 0.361 y número de pasos = (71)
# 48 - Simulado un episodio con retorno 0.865 y número de pasos = (15)
# 49 - Simulado un episodio con retorno 0.874 y número de pasos = (14)
# 50 - Simulado un episodio con retorno -0.242 y número de pasos = (138)
# 51 - Simulado un episodio con retorno 0.027999999999999914 y número de pasos = (108)
# 52 - Simulado un episodio con retorno 0.721 y número de pasos = (31)
# 53 - Simulado un episodio con retorno 0.7929999999999999 y número de pasos = (23)
# 54 - Simulado un episodio con retorno 0.09099999999999997 y número de pasos = (101)
# 55 - Simulado un episodio con retorno -0.14300000000000002 y número de pasos = (127)
# 56 - Simulado un episodio con retorno 0.2889999999999999 y número de pasos = (79)
# 57 - Simulado un episodio con retorno 0.55 y número de pasos = (50)
# 58 - Simulado un episodio con retorno 0.5229999999999999 y número de pasos = (53)
# 59 - Simulado un episodio con retorno 0.5229999999999999 y número de pasos = (53)
# 60 - Simulado un episodio con retorno 0.55 y número de pasos = (50)
# 61 - Simulado un episodio con retorno 0.604 y número de pasos = (44)
# 62 - Simulado un episodio con retorno 0.91 y número de pasos = (10)
# 63 - Simulado un episodio con retorno 0.739 y número de pasos = (29)
# 64 - Simulado un episodio con retorno -0.08000000000000007 y número de pasos = (120)
# 65 - Simulado un episodio con retorno 0.748 y número de pasos = (28)
# 66 - Simulado un episodio con retorno 0.6759999999999999 y número de pasos = (36)
# 67 - Simulado un episodio con retorno 0.55 y número de pasos = (50)
# 68 - Simulado un episodio con retorno -0.764 y número de pasos = (196)
# 69 - Simulado un episodio con retorno 0.244 y número de pasos = (84)
# 70 - Simulado un episodio con retorno 0.244 y número de pasos = (84)
# 71 - Simulado un episodio con retorno 0.018999999999999906 y número de pasos = (109)
# 72 - Simulado un episodio con retorno 0.487 y número de pasos = (57)
# 73 - Simulado un episodio con retorno 0.703 y número de pasos = (33)
# 74 - Simulado un episodio con retorno 0.2709999999999999 y número de pasos = (81)
# 75 - Simulado un episodio con retorno 0.07299999999999995 y número de pasos = (103)
# 76 - Simulado un episodio con retorno 0.15400000000000003 y número de pasos = (94)
# 77 - Simulado un episodio con retorno 0.3879999999999999 y número de pasos = (68)
# 78 - Simulado un episodio con retorno 0.91 y número de pasos = (10)
# 79 - Simulado un episodio con retorno 0.901 y número de pasos = (11)
# 80 - Simulado un episodio con retorno -0.09800000000000009 y número de pasos = (122)
# 81 - Simulado un episodio con retorno 0.613 y número de pasos = (43)
# 82 - Simulado un episodio con retorno 0.703 y número de pasos = (33)
# 83 - Simulado un episodio con retorno 0.847 y número de pasos = (17)
# 84 - Simulado un episodio con retorno -0.5209999999999999 y número de pasos = (169)
# 85 - Simulado un episodio con retorno 0.667 y número de pasos = (37)
# 86 - Simulado un episodio con retorno 0.919 y número de pasos = (9)
# 87 - Simulado un episodio con retorno 0.352 y número de pasos = (72)
# 88 - Simulado un episodio con retorno -0.9440000000000002 y número de pasos = (216)
# 89 - Simulado un episodio con retorno 0.5409999999999999 y número de pasos = (51)
# 90 - Simulado un episodio con retorno -0.19700000000000006 y número de pasos = (133)
# 91 - Simulado un episodio con retorno 0.469 y número de pasos = (59)
# 92 - Simulado un episodio con retorno 0.127 y número de pasos = (97)
# 93 - Simulado un episodio con retorno -2.114 y número de pasos = (346)
# 94 - Simulado un episodio con retorno 0.721 y número de pasos = (31)
# 95 - Simulado un episodio con retorno 0.901 y número de pasos = (11)
# 96 - Simulado un episodio con retorno 0.838 y número de pasos = (18)
# 97 - Simulado un episodio con retorno 0.5589999999999999 y número de pasos = (49)
# 98 - Simulado un episodio con retorno 0.379 y número de pasos = (69)
# 99 - Simulado un episodio con retorno 0.739 y número de pasos = (29)
# 100 - Simulado un episodio con retorno 0.34299999999999997 y número de pasos = (73)
# 101 - Simulado un episodio con retorno 0.82 y número de pasos = (20)
# 102 - Simulado un episodio con retorno 0.748 y número de pasos = (28)
# 103 - Simulado un episodio con retorno -0.1160000000000001 y número de pasos = (124)
# 104 - Simulado un episodio con retorno 0.82 y número de pasos = (20)
# 105 - Simulado un episodio con retorno 0.4149999999999999 y número de pasos = (65)
# 106 - Simulado un episodio con retorno 0.703 y número de pasos = (33)
# 107 - Simulado un episodio con retorno 0.2709999999999999 y número de pasos = (81)
# 108 - Simulado un episodio con retorno 0.10899999999999999 y número de pasos = (99)
# 109 - Simulado un episodio con retorno 0.577 y número de pasos = (47)
# 110 - Simulado un episodio con retorno 0.874 y número de pasos = (14)
# 111 - Simulado un episodio con retorno 0.16299999999999992 y número de pasos = (93)
# 112 - Simulado un episodio con retorno -2.357 y número de pasos = (373)
# 113 - Simulado un episodio con retorno 0.487 y número de pasos = (57)
# 114 - Simulado un episodio con retorno 0.20799999999999996 y número de pasos = (88)
# 115 - Simulado un episodio con retorno 0.06399999999999995 y número de pasos = (104)
# 116 - Simulado un episodio con retorno 0.955 y número de pasos = (5)
# 117 - Simulado un episodio con retorno 0.4059999999999999 y número de pasos = (66)
# 118 - Simulado un episodio con retorno -0.1160000000000001 y número de pasos = (124)
# 119 - Simulado un episodio con retorno 0.5589999999999999 y número de pasos = (49)
# 120 - Simulado un episodio con retorno -1.871 y número de pasos = (319)
# 121 - Simulado un episodio con retorno 0.469 y número de pasos = (59)
# 122 - Simulado un episodio con retorno -0.9530000000000001 y número de pasos = (217)
# 123 - Simulado un episodio con retorno 0.595 y número de pasos = (45)
# 124 - Simulado un episodio con retorno 0.667 y número de pasos = (37)
# 125 - Simulado un episodio con retorno 0.685 y número de pasos = (35)
# 126 - Simulado un episodio con retorno 0.6579999999999999 y número de pasos = (38)
# 127 - Simulado un episodio con retorno 0.34299999999999997 y número de pasos = (73)
# 128 - Simulado un episodio con retorno 0.8109999999999999 y número de pasos = (21)
# 129 - Simulado un episodio con retorno 0.2709999999999999 y número de pasos = (81)
# 130 - Simulado un episodio con retorno 0.775 y número de pasos = (25)
# 131 - Simulado un episodio con retorno -0.4849999999999999 y número de pasos = (165)
# 132 - Simulado un episodio con retorno 0.34299999999999997 y número de pasos = (73)
# 133 - Simulado un episodio con retorno 0.6759999999999999 y número de pasos = (36)
# 134 - Simulado un episodio con retorno -0.15200000000000014 y número de pasos = (128)
# 135 - Simulado un episodio con retorno 0.784 y número de pasos = (24)
# 136 - Simulado un episodio con retorno 0.694 y número de pasos = (34)
# 137 - Simulado un episodio con retorno 0.7929999999999999 y número de pasos = (23)
# 138 - Simulado un episodio con retorno 0.09099999999999997 y número de pasos = (101)
# 139 - Simulado un episodio con retorno 0.33399999999999996 y número de pasos = (74)
# 140 - Simulado un episodio con retorno 0.712 y número de pasos = (32)
# 141 - Simulado un episodio con retorno 0.622 y número de pasos = (42)
# 142 - Simulado un episodio con retorno 0.613 y número de pasos = (43)
# 143 - Simulado un episodio con retorno 0.45999999999999996 y número de pasos = (60)
# 144 - Simulado un episodio con retorno 0.847 y número de pasos = (17)
# 145 - Simulado un episodio con retorno 0.009999999999999898 y número de pasos = (110)
# 146 - Simulado un episodio con retorno -0.692 y número de pasos = (188)
# 147 - Simulado un episodio con retorno 0.613 y número de pasos = (43)
# 148 - Simulado un episodio con retorno -0.746 y número de pasos = (194)
# 149 - Simulado un episodio con retorno 0.487 y número de pasos = (57)
# 150 - Simulado un episodio con retorno -0.728 y número de pasos = (192)
# 151 - Simulado un episodio con retorno 0.73 y número de pasos = (30)
# 152 - Simulado un episodio con retorno 0.784 y número de pasos = (24)
# 153 - Simulado un episodio con retorno 0.802 y número de pasos = (22)
# 154 - Simulado un episodio con retorno -0.03499999999999992 y número de pasos = (115)
# 155 - Simulado un episodio con retorno 0.7929999999999999 y número de pasos = (23)
# 156 - Simulado un episodio con retorno 0.4059999999999999 y número de pasos = (66)
# 157 - Simulado un episodio con retorno -0.016999999999999904 y número de pasos = (113)
# 158 - Simulado un episodio con retorno 0.55 y número de pasos = (50)
# 159 - Simulado un episodio con retorno 0.15400000000000003 y número de pasos = (94)
# 160 - Simulado un episodio con retorno 0.03699999999999992 y número de pasos = (107)
# 161 - Simulado un episodio con retorno 0.6399999999999999 y número de pasos = (40)
# 162 - Simulado un episodio con retorno -0.494 y número de pasos = (166)
# 163 - Simulado un episodio con retorno 0.352 y número de pasos = (72)
# 164 - Simulado un episodio con retorno 0.667 y número de pasos = (37)
# 165 - Simulado un episodio con retorno 0.892 y número de pasos = (12)
# 166 - Simulado un episodio con retorno -0.062000000000000055 y número de pasos = (118)
# 167 - Simulado un episodio con retorno 0.955 y número de pasos = (5)
# 168 - Simulado un episodio con retorno -1.0699999999999998 y número de pasos = (230)
# 169 - Simulado un episodio con retorno 0.757 y número de pasos = (27)
# 170 - Simulado un episodio con retorno -0.242 y número de pasos = (138)
# 171 - Simulado un episodio con retorno -0.07099999999999995 y número de pasos = (119)
# 172 - Simulado un episodio con retorno 0.631 y número de pasos = (41)
# 173 - Simulado un episodio con retorno -0.9890000000000001 y número de pasos = (221)
# 174 - Simulado un episodio con retorno 0.685 y número de pasos = (35)
# 175 - Simulado un episodio con retorno 0.514 y número de pasos = (54)
# 176 - Simulado un episodio con retorno 0.604 y número de pasos = (44)
# 177 - Simulado un episodio con retorno 0.43299999999999994 y número de pasos = (63)
# 178 - Simulado un episodio con retorno 0.42399999999999993 y número de pasos = (64)
# 179 - Simulado un episodio con retorno 0.08199999999999996 y número de pasos = (102)
# 180 - Simulado un episodio con retorno 0.478 y número de pasos = (58)
# 181 - Simulado un episodio con retorno -1.1960000000000002 y número de pasos = (244)
# 182 - Simulado un episodio con retorno 0.685 y número de pasos = (35)
# 183 - Simulado un episodio con retorno 0.8109999999999999 y número de pasos = (21)
# 184 - Simulado un episodio con retorno 0.487 y número de pasos = (57)
# 185 - Simulado un episodio con retorno -0.6560000000000001 y número de pasos = (184)
# 186 - Simulado un episodio con retorno 0.712 y número de pasos = (32)
# 187 - Simulado un episodio con retorno 0.55 y número de pasos = (50)
# 188 - Simulado un episodio con retorno 0.874 y número de pasos = (14)
# 189 - Simulado un episodio con retorno 0.487 y número de pasos = (57)
# 190 - Simulado un episodio con retorno 0.901 y número de pasos = (11)
# 191 - Simulado un episodio con retorno 0.919 y número de pasos = (9)
# 192 - Simulado un episodio con retorno 0.901 y número de pasos = (11)
# 193 - Simulado un episodio con retorno 0.622 y número de pasos = (42)
# 194 - Simulado un episodio con retorno 0.18099999999999994 y número de pasos = (91)
# 195 - Simulado un episodio con retorno 0.649 y número de pasos = (39)
# 196 - Simulado un episodio con retorno -1.529 y número de pasos = (281)
# 197 - Simulado un episodio con retorno 0.5229999999999999 y número de pasos = (53)
# 198 - Simulado un episodio con retorno 0.469 y número de pasos = (59)
# 199 - Simulado un episodio con retorno -1.142 y número de pasos = (238)
# Se han necesitado de media 77.395 pasos (+- 65.58184943259835 )
# El episodio más corto duró 5 pasos y el episodio más largo duró 373 pasos

# %% [markdown]
# # Obtención de políticas óptimas
# ## Métodos de programación dinámica
#
# A la hora de encontrar una política óptima que guíe las acciones de nuestro agente, los métodos basados en programación dinámica son una buena opción cuando disponemos de conocimento respecto a las dinámicas del entorno.
#
# En particular, estos métodos requieren conocer $p(s',r | s,a)$, es decir, la probabilidad de acabar en un estado $s'$ recibiendo una recompensa $r$ si aplicamos la acción $a$ al estado $s$.
#
# OpenGym no nos proporciona esta información, pero en este problema sencillo podemos reconstruirla. Este entorno es determinista, lo que quiere decir que si aplicamos la acción $a$ al estado $s$ siempre obtendremos el mismo estado $s'$ y la misma recompensa $r$ con probabilidad 1 (cualquier otro estado $s_j$ o recompensa $r_j$ tendrán $p(s_j,r_j|s,a)=0$).
#
# Podemos, por tanto, representar el modelo con dos variables:
#  - `modelo_transiciones`: Para cada combinación $s,a$, almacena el estado $s'$ al que conduce aplicar la acción $a$ a $s$.
#  - `modelo_recompensas`: Para cada combinación $s,a$, almacena el valor de la recompensa obtenida al aplicar la acción $a$ a $s$.
#
# Sabiendo cómo se comporta el entorno, definimos estas dos variables con los valores adecuados.

# %%
# DEFINICIÓN DEL MODELO

# Modelo de transiciones - Almacena a qué estado lleva aplicar cada acción a cada estado
# Lo almacenamos en un array numpy en el que para cada estado almacenemos, para cada acción, el estado al que lleva.
modelo_transiciones = np.zeros((3,3,4,3,3),dtype=np.int16)
# Recorremos cada estado para completar el estado al que lleva cada una de las tres acciones posibles
for i in range(3): # Columnas (x)
    for j in range(3): # Filas (y)
        for k in range(4): # Orientaciones (dir)
            # Aplicar la acción left gira el agente a la izquierda, así que el estado resultante tendrá el mismo valor para filas y columnas pero variará la orientación
            modelo_transiciones[i,j,k,0]=[i,j,(k+4-1)%4]
            # Aplicar la acción right gira el agente a la derecha, así que el estado resultante tendrá el mismo valor para filas y columnas pero variará la orientación
            modelo_transiciones[i,j,k,1]=[i,j,(k+1)%4]
        # Aplicar la acción forward mantiene la orientación, pero cambia filas o columnas en función de hacia dónde esté orientado
        if i<2:
            modelo_transiciones[i,j,0,2]=[i+1,j,0] # Derecha
        if j<2:
            modelo_transiciones[i,j,1,2]=[i,j+1,1] # Abajo
        if i>0:
            modelo_transiciones[i,j,2,2]=[i-1,j,2] # Izquierda
        if j>0:
            modelo_transiciones[i,j,3,2]=[i,j-1,3] # Arriba

# Modelo de recompensas - Almacena qué recompensa proporciona aplicar cada acción a cada estado
# Lo almacenamos en un array numpy en el que para cada estado almacenemos, para cada acción, la recompensa.
modelo_recompensas = np.zeros((3,3,4,3))
# Será 0 siempre menos en dos casos:
# 1 - Está en la segunda columna de la tercera fila, orientado a la derecha y se usa la acción forward
modelo_recompensas[1,2,0,2] = 1
# 2 - Está en la tercera columna de la segunda fila, orientado hacia abajo y se usa la acción forward
modelo_recompensas[2,1,1,2] = 1

# Función auxiliar para consultar los estados a los que lleva cada acción para un estado dado
def get_resultados_por_accion_en(estado: Estado) -> list[Estado]:
    valores_estados_para_cada_accion = modelo_transiciones[estado.x, estado.y, estado.dir]
    return list(map(lambda x: Estado(*x), valores_estados_para_cada_accion))

# Función auxiliar para consultar las recompensas de aplicar cada acción en un estado dado
def get_recompensas_por_accion_en(estado: Estado) -> np.ndarray:
    return modelo_recompensas[estado.x, estado.y, estado.dir]

# TODO - Muestra los estados resultantes y las recompensas de aplicar las distintas acciones cuando el agente está en la tercera casilla de la segunda fila, orientado hacia abajo y se ejecuta la acción forward
print(get_resultados_por_accion_en(Estado(2, 1, 1)))
print(get_recompensas_por_accion_en(Estado(2, 1, 1)))

...
# Out:
# [Estado(x=np.int16(2), y=np.int16(1), dir=np.int16(0)), Estado(x=np.int16(2), y=np.int16(1), dir=np.int16(2)), Estado(x=np.int16(2), y=np.int16(2), dir=np.int16(1))]
# [0. 0. 1.]
# Ellipsis

# %% [markdown]
# ## Algoritmo 1: Evaluación de políticas iterativa
# El algoritmo de evaluación de políticas iterativa calcula el valor $v_\pi(s)$ para todo estado $s$ siguiendo la política $\pi$. La fórmula que utiliza, que está basada en la ecuación de Bellman para $v_\pi(s)$, es esta:
#
# $$v_\pi(s)=\mathbb{E}_\pi [R_{t+1}+\gamma v_k(S_{t+1}) | S_t=s]$$
#
# $$=\sum_a\pi(a|s)\sum_{s',r}p(s',r|s,a)[r+\gamma v_k(s')]$$
#
# Al ser este un problema determinista, la expresión se simplifica, dado que $p(s',r|s,a)$ será 0 en todos los casos menos en 1 (porque aplicar la acción $a$ al estado $s$ conduce siempre a un estado $s'$ fijo y único y otorga siempre una recompensa $r$ fija y única; ambos valores los podemos obtener del modelo).
#
# Puedes ver el algoritmo al completo aquí:
#
# ![Evaluación de políticas iterativa](https://github.com/eirasf/GCED-AA3/blob/main/lab4/img/iterative-policy-evaluation.png?raw=true)
#
# Implementemos el algoritmo para obtener los valores asignados a cada estado siguiendo una política fija.
#
# **CONSEJO: Para asegurar la convergencia, actualiza todos los valores de $V_{t+1}(s)$ a partir de los valores $V_t(s)$, es decir, crea una variable `nuevos_valores_estados` donde almacenes todos los calculados en una iteración y al completar la iteración establece `valores_estados = nuevos_valores_estados`**

# %%
GAMMA = 0.1

def iterative_policy_evaluation(politica: np.ndarray) ->np.ndarray:
    THETA = 0.00001
    valores_estados = np.random.uniform(size = (3, 3, 4))
    valores_estados[2, 2, :] = [1, 0, 0, 0]
    print(valores_estados)
    DELTA = 0.1
    while DELTA > THETA:
        DELTA = 0
        for i, s in enumerate(valores_estados.flatten()):
            


    return valores_estados

valores_estados = iterative_policy_evaluation(politica_aleatoria)
print(valores_estados)

# COMPROBACIÓN
np.testing.assert_almost_equal(valores_estados[0,0,1], 4.11522634e-07)
# Out:
# [[[0.70299762 0.48551507 0.27521972 0.55550389]
#   [0.38738576 0.55742875 0.22664435 0.09858594]
#   [0.05828483 0.13173591 0.80583207 0.34885826]]
#
#  [[0.4552059  0.2840752  0.09911196 0.84297544]
#   [0.22323178 0.4735809  0.21008815 0.19031737]
#   [0.82050326 0.98074494 0.40970382 0.67315501]]
#
#  [[0.9226373  0.66142951 0.49157655 0.3272493 ]
#   [0.56614691 0.80927783 0.03201988 0.98141332]
#   [1.         0.         0.         0.        ]]]
# 0.7029976227403544 a
# 0.4855150720999347 a
# 0.27521972199605094 a
# 0.5555038909251385 a
# 0.3873857579645843 a
# 0.5574287495046366 a
# 0.22664434804511524 a
# 0.09858593899237511 a
# 0.058284827907049475 a
# 0.1317359120323781 a
# 0.8058320702651461 a
# 0.3488582560512763 a
# 0.4552058993258121 a
# 0.28407520175049583 a
# 0.09911196246517517 a
# 0.8429754362660227 a
# 0.2232317788207332 a
# 0.47358089924483937 a
# 0.21008814989639923 a
# 0.19031736760096152 a
# 0.8205032619441508 a
# 0.9807449365041716 a
# 0.409703823098422 a
# 0.6731550058458222 a
# 0.9226372987338998 a
# 0.6614295095725498 a
# 0.4915765531866373 a
# 0.3272493004796253 a
# 0.5661469070645917 a
# 0.8092778336883275 a
# 0.03201987836231246 a
# 0.9814133238778765 a
# 1.0 a
# 0.0 a
# 0.0 a
# 0.0 a
# [[[0.70299762 0.48551507 0.27521972 0.55550389]
#   [0.38738576 0.55742875 0.22664435 0.09858594]
#   [0.05828483 0.13173591 0.80583207 0.34885826]]
#
#  [[0.4552059  0.2840752  0.09911196 0.84297544]
#   [0.22323178 0.4735809  0.21008815 0.19031737]
#   [0.82050326 0.98074494 0.40970382 0.67315501]]
#
#  [[0.9226373  0.66142951 0.49157655 0.3272493 ]
#   [0.56614691 0.80927783 0.03201988 0.98141332]
#   [1.         0.         0.         0.        ]]]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[48], line 21
#      18 print(valores_estados)
#      20 # COMPROBACIÓN
# ---> 21 np.testing.assert_almost_equal(valores_estados[0,0,1], 4.11522634e-07)
#
# File c:\Users\npanb\Documents\Entornos_python\AP\Lib\site-packages\numpy\testing\_private\utils.py:635, in assert_almost_equal(actual, desired, decimal, err_msg, verbose)
#     633     pass
#     634 if abs(desired - actual) >= np.float64(1.5 * 10.0**(-decimal)):
# --> 635     raise AssertionError(_build_err_msg())
#
# AssertionError:
# Arrays are not almost equal to 7 decimals
#  ACTUAL: np.float64(0.4855150720999347)
#  DESIRED: 4.11522634e-07

# %% [markdown]
# ### Optimización de políticas
#
# En el apartado anterior hemos obtenido un valor para cada estado del problema cuando se sigue la política $\pi$;  podemos utilizar estos valores para encontrar una nueva política $\pi'$ que sea igual o mejor que $\pi$.
#
# Cuando disponemos de $v_\pi(s)$ y del modelo que describe el funcionamiento del entorno, podemos obtener una política $\pi'\geq\pi$ simplemente seleccionando, para cada estado, la acción que nos da un mayor retorno, que podemos calcular como la recompensa inmediata más el valor del estado al que llegamos (descontado por $\gamma$).
#
# $$\pi'(s)=\arg\max_a\sum_{s',r}p(s',r|s,a)\left[r+\gamma v_\pi(s')\right]$$
#
# Escribamos un algoritmo que obtenga $\pi'$ a partir de `state_values`.

# %%
def crea_politica_avara(valores_estados: np.ndarray) -> np.ndarray:
    nueva_shape = list(valores_estados.shape)
    nueva_shape.append(3)
    # TODO - Indica la shape apropiada. Por cada par estado-acción debemos almacenar la probabilidad que da esta política de tomar esa acción estando en dicho estado
    # Como la política es determinista, para un estado concreto todas las acciones tendrán probabilidad 0 menos una que tendrá probabilidad 1
    politica = np.zeros(...)
    # TODO - Haz bucles anidados para recorrer todos los estados
    ...
                # Ahora para este estado debemos calcular, para todas las acciones a, G=(r + GAMMA*state_values[s[0],s[1],s[2]]) donde r es la recompensa de aplicar a y s es el estado resultante.
                # De todos esos valores, tomaremos el mejor (supongamos que es el i-ésimo) y pondremos probabilidad 1 en la acción i-ésima para dicho estado.
                # TODO - Recorre las acciones, calculando su G. Selecciona el mejor y pon a 1 la probabilidad de la acción correspondiente.
                ...
    return politica

politica_mejorada = crea_politica_avara(valores_estados)

# COMPROBACIÓN
assert(np.array_equal(politica_mejorada[2,1,1],[0., 0., 1.]))

# %% [markdown]
# ## Obtención de la política óptima - Policy iteration
# Ahora que podemos evaluar una política y, a partir de esos valores, obtener una política mejorada, podemos repetir el proceso para seguir mejorando nuestra política hasta que no cambie. Este procedimiento se denomina *policy iteration* y lo tienes aquí descrito:
#
# ![Policy iteration](https://github.com/eirasf/GCED-AA3/blob/main/lab4/img/policy-iteration.png?raw=true)
#
# Implementémoslo (la mayoría ya lo tenemos hecho).

# %%
def policy_iteration(politica_inicial: np.ndarray) -> np.ndarray:
    politica_actual = politica_inicial
    politica_estable = False
    # Llevaremos cuenta del paso en que estamos
    paso = 0
    while not politica_estable:
        # TODO - Calcula los valores para current_policy
        valores_actuales = ...
        # TODO - Obtén la nueva política mejorada a partir de los valores calculados
        nueva_politica = ...
        # Comprobamos si la política ha cambiado
        politica_estable = np.array_equal(politica_actual, nueva_politica)
        # Preparamos la siguiente iteración
        politica_actual = nueva_politica
        paso+=1
        print('Paso #',paso)
    # Al terminar el bucle habremos obtenido una política que ya no mejora
    return politica_actual

politica_optima = policy_iteration(politica_aleatoria)
print(politica_optima)

# COMPROBACIÓN
assert(np.array_equal(politica_optima[2,0,1], [0., 0., 1.]))

# %% [markdown]
# Comprobemos que la política obtenida funciona bien simulando un episodio siguiéndola.

# %%
simula_episodio(politica_optima, muestra_renders=True, imprime=True)

# %% [markdown]
# ## Obtención de la política óptima - Iteración de valores
# El proceso de iteración de políticas es costoso porque requiere hacer una estimación iterativa de $v_\pi(s)$ para todas las políticas por las que se pasa. Este proceso se puede simplificar y obtener una política óptima siguiendo el algoritmo de iteración de valores:
#
# ![Value iteration](https://github.com/eirasf/GCED-AA3/blob/main/lab4/img/value-iteration.png?raw=true)
#
# El algoritmo es muy similar al de evaluación de políticas iterativas. La diferencia es que, en lugar de calcular $\mathbb{E}_\pi [R_{t+1}+\gamma v_k(S_{t+1}) | S_t=s]$, se toma el valor de la mejor acción. Al final, se devuelve la política greedy derivada de los valores calculados. Implementémoslo.

# %%
def value_iteration() -> np.ndarray: # No recibe ningún parámetro. Calcula valores y política a partir del modelo del entorno.
    # TODO - Repite el algoritmo de evaluación de políticas iterativa pero tomando el G de la mejor acción para cada estado
    # Una vez tengas los state_values, devuelve la política derivada de ellos
    ...

otra_optima = value_iteration()
print(otra_optima)

# COMPROBACIÓN
assert(np.array_equal(otra_optima[2,0,1], [0., 0., 1.]))

# %% [markdown]
# Para terminar, comprobemos que la política obtenida así también funciona bien.

# %%
simula_episodio(otra_optima, muestra_renders=True, imprime=True)
env.close() # Cerramos, además, el entorno
