# %% [markdown]
# # Notebook 8: Aprendizaje por refuerzo - Métodos de Temporal Difference
#
# En este notebook seguiremos explorando métodos tabulares de aprendizaje por refuerzo que no necesitan disponer de un modelo. En particular, estudiaremos los métodos de **Temporal Difference**.
#
# Para explorar estos métodos volveremos a utilizar [Gym](https://www.gymlibrary.dev/) con un entorno GridWorld, es decir, un tablero con casillas por las que se mueve el agente. En particular, vamos a utilizar el entorno `MiniGrid-DistShift1-v0`. En este entorno el agente deberá llegar hasta la meta, pero esta vez evitando caer en la lava, que hace que se termine el episodio con recompensa 0.
#
# Carguemos el entorno y explorémoslo brevemente.

# %%
# Si los paquetes no están instalados, hay que ejecutar estas líneas:
#!pip install gymnasium
#!pip install minigrid

import gymnasium as gym
import minigrid
import numpy as np
env = gym.make('MiniGrid-DistShift1-v0', render_mode='rgb_array')

# Resetea el entorno (necesario para poder usarlo)
env.reset()

import matplotlib.pyplot as plt

def muestra_entorno(env:gym.Env) -> None:
    im = plt.imshow(env.render())
    plt.show()
# Out:
# c:\Users\npanb\Documents\Entornos_python\AP\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
NUM_COLUMNAS = 7
NUM_FILAS = 5
NUM_ORIENTACIONES = 4

# Las acciones son las mismas que en el Notebook 6. Nos quedaremos de nuevo solo con LEFT, RIGHT y FORWARD
acciones = env.get_wrapper_attr('actions')
# Seleccionamos solo las tres acciones indicadas
ACCIONES_UTILES = [acciones.left, acciones.right, acciones.forward]
NUM_ACCIONES = len(ACCIONES_UTILES)
muestra_entorno(env)

# %% [markdown]
# Comprueba el efecto de caer en la lava. El episodio debería terminarse y recibiendo el agente una recompensa de 0.

# %%
#TODO - Efectúa dos acciones para que el agente caiga en la lava y verifica que se recibe una recompensa de 0
obs, reward, terminated, truncated, info = env.step(acciones.forward)
obs, reward, terminated, truncated, info = env.step(acciones.forward)
muestra_entorno(env)
#COMPROBACIONES
assert(reward==0)
assert(terminated)
_ = env.reset()

# %% [markdown]
# # Obtención de políticas óptimas
#
# ## Métodos de Temporal Difference
#
# Los métodos basados en **Temporal Difference**, al igual que los métodos Montecarlo, carecen de información respecto a cómo funciona el modelo (no conocen $p(s',r | s,a)$). Por ello, también deben interactuar con el entorno para obtener muestras con las que después hacer estimaciones.
#
# A diferencia de los métodos Montecarlo, los métodos de Temporal Difference no esperan a terminar un episodio para actualizar los valores de los estados transitados. En su lugar, aprovechan la idea de que el valor $v(S)$ de un estado $S$ tiene relación con el valor de los estados $S'$ a los que se puede llegar desde $S$. Dicho de otra manera, los estados que pueden conducir a un estado malo serán también malos (y viceversa). Esta idea está codificada en las **ecuaciones de Bellman**:
#
# $$v_\pi(s)=\sum_{a}\pi(a|s)\sum_{s',r} p(s',r | s,a)\left[r + \gamma v_\pi(s')\right]$$
#
# La misma idea se puede aplicar a la hora de estimar el valor de ejecutar la acción $a$ estando en el estado $s$. Las acciones $a$ que lleven a estados $s'$ cuyas acciones tengan valores altos tendrán, a su vez, valores altos (y viceversa).
#
# $$q_\pi(s,a)=\sum_{s',r} p(s',r | s,a)\left[r + \gamma \sum_{a'}\pi(a'|s')q_\pi(s',a')\right]$$
#
# Aplicar esta idea nos permitirá hacer *bootstrapping* en nuestros cálculos: a la hora de calcular el valor de un estado podremos aprovechar la aproximación que tenemos para estados adyacentes.
#
# ### SARSA
# El primer método que probaremos es SARSA. Este algoritmo se denomina así por las variables involucradas en cada paso de actualización de la estimación de $Q(S,A)$. Las variables son $S_t,A_t,R_{t+1},S_{t+1},A_{t+1}$ y la actualización utiliza esta fórmula:
#
# $$Q(S_t,A_t) \leftarrow Q(S_t,A_t) + \alpha [R_{t+1} + \gamma Q(S_{t+1},A_{t+1}) - Q(S_t,A_t)]$$
#
# El algoritmo ejecutará repetidos episodios (potencialmente infinitos; es un algoritmo de control y el agente podría seguirlo utilizando durante toda su existencia) y, para cada paso del episodio hará la actualización según la ecuación indicada arriba. Esto requiere que haya decidido la siguiente acción a tomar ($A_{t+1}$) antes de actualizar el valor de la acción anterior ($A_t$).
#
# ![Sarsa](https://github.com/eirasf/GCED-AA3/blob/main/lab6/img/sarsa.png?raw=true)

# %% [markdown]
# Para facilitar la implementación, vamos primero a escribir un par de funciones auxiliares que nos permitan representar estados y muestrear acciones a partir de $Q$ siguiendo una política e-greedy.

# %%
# Fijamos el valor de la tasa de descuento gamma = 0.9, es decir, las recompensas futuras se descontarán un 10% por cada paso que sea necesario para obtenerlas.
GAMMA = 0.9
# Fijamos el número máximo de acciones por episodio a 5000, para permitir episodios largos
env.max_steps = 5000

# FUNCIONES AUXILIARES
from collections import namedtuple

# Representaremos los estados como tuplas con los siguientes campos con nombre:
#  - x: Representa la columna en que se encuentra el agente. La columna visitable más a la izquierda será la 0
#  - y: Representa la fila en que se encuentra el agente. La fila visitable más arriba será la 0
#  - dir: Representa la dirección en que apunta el agente. Respetaremos el código numérico indicado por agent_dir

Estado = namedtuple('Estado', ['x', 'y', 'dir'])


def get_estado(env:gym.Env) -> Estado:
    x, y = env.get_wrapper_attr("agent_pos")
    dir = env.get_wrapper_attr("agent_dir")
    return Estado(x-1, y-1, dir)

# COMPROBACIÓN
env.reset()
estado_actual = get_estado(env)
assert estado_actual.x == 0, f'El estado inmediatamente después de resetear debe indicar x=0 y el tuyo indica {estado_actual.x}'
assert estado_actual.y == 0, f'El estado inmediatamente después de resetear debe indicar y=0 y el tuyo indica {estado_actual.y}'
assert estado_actual.dir == 0, f'El estado inmediatamente después de resetear debe indicar dir=0 y el tuyo indica {estado_actual.dir}'

# TODO - Escribe una función que dados los valores q de las distintas acciones en un estado concreto, devuelva una acción haciendo una selección epsilon-greedy a partir de los q_valores.
def get_accion_epsilon_greedy(q_valores:np.ndarray, epsilon:float):
    '''
    Selecciona una acción basándose en los q_valores proporcionados. Una fracción de las veces (indicada por epsilon) devolverá una acción al azar

    Argumentos:
    q_valores -- Lista con los q valores de las acciones entre las q
    ue seleccionar.
    epsilon -- Fracción de las veces que se devolverá una acción al azar
    '''
    if np.random.random()<epsilon:
        return np.random.randint(0, 3)
    return np.argmax(q_valores)


# COMPROBACIÓN
assert(get_accion_epsilon_greedy([1,2,4],0)==2)

# %% [markdown]
# Para algoritmos derivados de SARSA haremos _exploring starts_, es decir, comenzarán cada vez en un estado al azar. Esto facilita la exploración, y por tanto el entrenamiento, ya que facilita que se den episodios que el agente sea capaz de resolver incluso con una política aleatoria.
#
# Deberemos crear funciones que nos permitan llevar esto a cabo.

# %%
# TODO - Escribe una función que genere la codificación para un estado válido al azar. Devolverá una lista con tres valores que indiquen columna, fila y orientación
def get_estado_aleatorio() -> Estado:
    return Estado(np.random.randint(0, NUM_COLUMNAS - 1), np.random.randint(0, NUM_FILAS - 1), np.random.randint(0, 3))
print(env.unwrapped.agent_pos)
# TODO - Escribe una función que establezca el entorno para que coincida con lo indicado por un estado dado
def set_estado(env:gym.Env, estado: Estado):
    env.unwrapped.agent_pos = (estado.x + 1, estado.y + 1)
    env.unwrapped.agent_dir = estado.dir

# COMPROBACIÓN
env.reset()
muestra_entorno(env) # Debe mostrar al agente en la casilla 0,0
set_estado(env, Estado(x=2, y=3, dir=0))
muestra_entorno(env) # Debe mostrar al agente en la casilla 2,3
# Out:
# (1, 1)

# %% [markdown]
# Ya tenemos lo necesario para implementar SARSA. Vamos a establecer un número fijo de iteraciones y hacer que devuelva los valores $Q$ al terminar. Además, incluiremos mensajes al terminar cada episodio que indiquen:
#  - El número de episodio que se ha finalizado
#  - La recompensa obtenida
#  - El número de acciones necesarias para completar el episodio
#  - La recompensa media obtenida durante los últimos 100 episodios (si se han ejecutado al menos 100)

# %%
def sarsa(num_episodios:int = 500, ALPHA:float = 0.1, EPSILON:float = 0.25) -> np.ndarray:
    # TODO - Inicializa los valores Q a cero con el shape adecuado
    q_valores = np.zeros((NUM_COLUMNAS, NUM_FILAS, NUM_ORIENTACIONES, NUM_ACCIONES))
    ultimos100retornos = []
    cnt = 0
    while cnt < num_episodios:
        cnt += 1
        retorno = 0
        num_pasos = 0
        completado = False
        env.reset()
        env.max_steps = float('inf')
        estado_actual = get_estado_aleatorio()
        set_estado(env, estado_actual)
        accion_escogida = get_accion_epsilon_greedy(q_valores[estado_actual.x, estado_actual.y, estado_actual.dir, :], EPSILON)
        while not completado:
            valores_acciones = q_valores[estado_actual.x, estado_actual.y, estado_actual.dir, :]
            observacion, recompensa, terminated, truncated, info = env.step(ACCIONES_UTILES[accion_escogida])
            nuevo_estado = get_estado(env)
            nuevos_valores_acciones = q_valores[nuevo_estado.x, nuevo_estado.y, nuevo_estado.dir, :]
            nueva_accion = get_accion_epsilon_greedy(nuevos_valores_acciones, EPSILON)
            retorno += recompensa
            num_pasos += 1
            completado = terminated
            valor_actual = valores_acciones[accion_escogida]
            nuevo_valor = nuevos_valores_acciones[nueva_accion]
            q_valores[estado_actual.x, estado_actual.y, estado_actual.dir, accion_escogida] = valor_actual + ALPHA * (recompensa + GAMMA * nuevo_valor - valor_actual)

            # print("Número de paso: ", num_pasos)
            # print("Episodio: ", cnt)
            # print("Acción aplicada: ", accion_escogida)
            # print("Estado resultante: ", estado_actual)
            # print("Recompensa obtenida: ", recompensa)
            # print("Ejecución completada? ", completado)

            estado_actual = nuevo_estado
            accion_escogida = nueva_accion

        ultimos100retornos.append(retorno)
        string_retornos100 = ''
        if len(ultimos100retornos)==101: # ... y si hay ya más de 100...
            ultimos100retornos.pop(0) # ...quitamos el más antiguo (para tener siempre 100, no más)...
            #... y preparamos el mensaje para mostrar la media de los retornos
            string_retornos100=f'(retorno medio de {np.mean(ultimos100retornos)} en los últimos 100 episodios)'
        # Mostramos el mensaje tras cada episodio
        print(f'Terminado episodio {cnt} con retorno {retorno} en {num_pasos} pasos {string_retornos100}')
    return q_valores

# Entrenamos al agente usando los parámetros por defecto de la función que acabamos de definir
q_valores_sarsa = sarsa()
# print(q_valores_sarsa)
# Out:
# Terminado episodio 1 con retorno 0 en 95 pasos
# Terminado episodio 2 con retorno 0 en 44 pasos
# Terminado episodio 3 con retorno 0 en 528 pasos
# Terminado episodio 4 con retorno 0 en 208 pasos
# Terminado episodio 5 con retorno 0 en 10 pasos
# Terminado episodio 6 con retorno 0 en 852 pasos
# Terminado episodio 7 con retorno 0 en 196 pasos
# Terminado episodio 8 con retorno 0 en 50 pasos
# Terminado episodio 9 con retorno 0 en 57 pasos
# Terminado episodio 10 con retorno 0 en 3 pasos
# Terminado episodio 11 con retorno 0 en 18 pasos
# Terminado episodio 12 con retorno 0 en 51 pasos
# Terminado episodio 13 con retorno 0 en 27 pasos
# Terminado episodio 14 con retorno 0 en 27 pasos
# Terminado episodio 15 con retorno 0 en 298 pasos
# Terminado episodio 16 con retorno -1.3285714285714287 en 652 pasos
# Terminado episodio 17 con retorno 0 en 42 pasos
# Terminado episodio 18 con retorno 0 en 57 pasos
# Terminado episodio 19 con retorno 0 en 33 pasos
# Terminado episodio 20 con retorno 0 en 86 pasos
# Terminado episodio 21 con retorno 0.9678571428571429 en 9 pasos
# Terminado episodio 22 con retorno 0 en 127 pasos
# Terminado episodio 23 con retorno 0 en 147 pasos
# Terminado episodio 24 con retorno 0 en 7 pasos
# Terminado episodio 25 con retorno 0 en 17 pasos
# Terminado episodio 26 con retorno 0.9642857142857143 en 10 pasos
# Terminado episodio 27 con retorno 0 en 11 pasos
# Terminado episodio 28 con retorno 0 en 1 pasos
# Terminado episodio 29 con retorno 0 en 249 pasos
# Terminado episodio 30 con retorno 0 en 4 pasos
# Terminado episodio 31 con retorno 0 en 170 pasos
# Terminado episodio 32 con retorno 0 en 96 pasos
# Terminado episodio 33 con retorno 0 en 8 pasos
# Terminado episodio 34 con retorno 0 en 23 pasos
# Terminado episodio 35 con retorno 0 en 501 pasos
# Terminado episodio 36 con retorno 0 en 565 pasos
# Terminado episodio 37 con retorno 0 en 466 pasos
# Terminado episodio 38 con retorno 0 en 193 pasos
# Terminado episodio 39 con retorno 0 en 39 pasos
# Terminado episodio 40 con retorno 0 en 17 pasos
# Terminado episodio 41 con retorno 0.5392857142857144 en 129 pasos
# Terminado episodio 42 con retorno 0 en 597 pasos
# Terminado episodio 43 con retorno 0.9928571428571429 en 2 pasos
# Terminado episodio 44 con retorno 0 en 367 pasos
# Terminado episodio 45 con retorno 0 en 120 pasos
# Terminado episodio 46 con retorno 0 en 84 pasos
# Terminado episodio 47 con retorno 0 en 13 pasos
# Terminado episodio 48 con retorno 0 en 66 pasos
# Terminado episodio 49 con retorno 0 en 16 pasos
# Terminado episodio 50 con retorno 0 en 539 pasos
# Terminado episodio 51 con retorno 0 en 950 pasos
# Terminado episodio 52 con retorno 0 en 243 pasos
# Terminado episodio 53 con retorno 0 en 199 pasos
# Terminado episodio 54 con retorno 0 en 9 pasos
# Terminado episodio 55 con retorno 0 en 359 pasos
# Terminado episodio 56 con retorno -4.167857142857143 en 1447 pasos
# Terminado episodio 57 con retorno 0 en 200 pasos
# Terminado episodio 58 con retorno 0 en 54 pasos
# Terminado episodio 59 con retorno 0 en 48 pasos
# Terminado episodio 60 con retorno 0 en 44 pasos
# Terminado episodio 61 con retorno 0 en 13 pasos
# Terminado episodio 62 con retorno 0 en 461 pasos
# Terminado episodio 63 con retorno 0 en 87 pasos
# Terminado episodio 64 con retorno 0.9785714285714285 en 6 pasos
# Terminado episodio 65 con retorno 0 en 170 pasos
# Terminado episodio 66 con retorno 0 en 730 pasos
# Terminado episodio 67 con retorno 0 en 24 pasos
# Terminado episodio 68 con retorno 0 en 342 pasos
# Terminado episodio 69 con retorno 0 en 6 pasos
# Terminado episodio 70 con retorno 0 en 205 pasos
# Terminado episodio 71 con retorno 0 en 139 pasos
# Terminado episodio 72 con retorno 0.8714285714285714 en 36 pasos
# Terminado episodio 73 con retorno 0 en 229 pasos
# Terminado episodio 74 con retorno 0 en 131 pasos
# Terminado episodio 75 con retorno -0.48571428571428577 en 416 pasos
# Terminado episodio 76 con retorno 0 en 239 pasos
# Terminado episodio 77 con retorno 0.9928571428571429 en 2 pasos
# Terminado episodio 78 con retorno 0 en 418 pasos
# Terminado episodio 79 con retorno 0 en 12 pasos
# Terminado episodio 80 con retorno -1.2357142857142858 en 626 pasos
# Terminado episodio 81 con retorno 0 en 403 pasos
# Terminado episodio 82 con retorno 0 en 623 pasos
# Terminado episodio 83 con retorno 0 en 19 pasos
# Terminado episodio 84 con retorno 0 en 685 pasos
# Terminado episodio 85 con retorno 0 en 87 pasos
# Terminado episodio 86 con retorno 0.9678571428571429 en 9 pasos
# Terminado episodio 87 con retorno 0 en 30 pasos
# Terminado episodio 88 con retorno 0 en 12 pasos
# Terminado episodio 89 con retorno 0 en 330 pasos
# Terminado episodio 90 con retorno 0 en 15 pasos
# Terminado episodio 91 con retorno 0 en 13 pasos
# Terminado episodio 92 con retorno 0.9785714285714285 en 6 pasos
# Terminado episodio 93 con retorno 0 en 11 pasos
# Terminado episodio 94 con retorno 0 en 35 pasos
# Terminado episodio 95 con retorno 0 en 690 pasos
# Terminado episodio 96 con retorno 0 en 71 pasos
# Terminado episodio 97 con retorno 0 en 16 pasos
# Terminado episodio 98 con retorno 0 en 239 pasos
# Terminado episodio 99 con retorno 0.3142857142857143 en 192 pasos
# Terminado episodio 100 con retorno 0 en 51 pasos
# Terminado episodio 101 con retorno 0.9321428571428572 en 19 pasos (retorno medio de 0.022821428571428576 en los últimos 100 episodios)
# Terminado episodio 102 con retorno 0 en 148 pasos (retorno medio de 0.022821428571428565 en los últimos 100 episodios)
# Terminado episodio 103 con retorno 0 en 535 pasos (retorno medio de 0.022821428571428565 en los últimos 100 episodios)
# Terminado episodio 104 con retorno 0 en 4 pasos (retorno medio de 0.022821428571428565 en los últimos 100 episodios)
# Terminado episodio 105 con retorno -0.11785714285714288 en 313 pasos (retorno medio de 0.02164285714285714 en los últimos 100 episodios)
# Terminado episodio 106 con retorno 0 en 673 pasos (retorno medio de 0.02164285714285714 en los últimos 100 episodios)
# Terminado episodio 107 con retorno 0 en 136 pasos (retorno medio de 0.021642857142857137 en los últimos 100 episodios)
# Terminado episodio 108 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.03121428571428571 en los últimos 100 episodios)
# Terminado episodio 109 con retorno 0 en 6 pasos (retorno medio de 0.031214285714285715 en los últimos 100 episodios)
# Terminado episodio 110 con retorno 0.9821428571428571 en 5 pasos (retorno medio de 0.041035714285714286 en los últimos 100 episodios)
# Terminado episodio 111 con retorno 0.12142857142857144 en 246 pasos (retorno medio de 0.042249999999999996 en los últimos 100 episodios)
# Terminado episodio 112 con retorno 0 en 31 pasos (retorno medio de 0.042249999999999996 en los últimos 100 episodios)
# Terminado episodio 113 con retorno 0 en 6 pasos (retorno medio de 0.042249999999999996 en los últimos 100 episodios)
# Terminado episodio 114 con retorno 0 en 168 pasos (retorno medio de 0.042249999999999996 en los últimos 100 episodios)
# Terminado episodio 115 con retorno 0 en 216 pasos (retorno medio de 0.042249999999999996 en los últimos 100 episodios)
# Terminado episodio 116 con retorno 0 en 311 pasos (retorno medio de 0.055535714285714285 en los últimos 100 episodios)
# Terminado episodio 117 con retorno 0 en 18 pasos (retorno medio de 0.055535714285714285 en los últimos 100 episodios)
# Terminado episodio 118 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.06532142857142857 en los últimos 100 episodios)
# Terminado episodio 119 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.07485714285714286 en los últimos 100 episodios)
# Terminado episodio 120 con retorno 0.11785714285714288 en 247 pasos (retorno medio de 0.07603571428571429 en los últimos 100 episodios)
# Terminado episodio 121 con retorno 0 en 22 pasos (retorno medio de 0.06635714285714285 en los últimos 100 episodios)
# Terminado episodio 122 con retorno 0 en 2 pasos (retorno medio de 0.06635714285714286 en los últimos 100 episodios)
# Terminado episodio 123 con retorno 0.7357142857142858 en 74 pasos (retorno medio de 0.0737142857142857 en los últimos 100 episodios)
# Terminado episodio 124 con retorno 0.975 en 7 pasos (retorno medio de 0.08346428571428571 en los últimos 100 episodios)
# Terminado episodio 125 con retorno 0 en 571 pasos (retorno medio de 0.08346428571428571 en los últimos 100 episodios)
# Terminado episodio 126 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.08360714285714285 en los últimos 100 episodios)
# Terminado episodio 127 con retorno 0.9892857142857143 en 3 pasos (retorno medio de 0.09349999999999997 en los últimos 100 episodios)
# Terminado episodio 128 con retorno 0.3678571428571429 en 177 pasos (retorno medio de 0.09717857142857142 en los últimos 100 episodios)
# Terminado episodio 129 con retorno -0.5142857142857142 en 424 pasos (retorno medio de 0.09203571428571428 en los últimos 100 episodios)
# Terminado episodio 130 con retorno 0 en 11 pasos (retorno medio de 0.09203571428571428 en los últimos 100 episodios)
# Terminado episodio 131 con retorno 0.9892857142857143 en 3 pasos (retorno medio de 0.10192857142857141 en los últimos 100 episodios)
# Terminado episodio 132 con retorno 0 en 33 pasos (retorno medio de 0.10192857142857142 en los últimos 100 episodios)
# Terminado episodio 133 con retorno 0 en 3 pasos (retorno medio de 0.10192857142857142 en los últimos 100 episodios)
# Terminado episodio 134 con retorno 0 en 5 pasos (retorno medio de 0.10192857142857142 en los últimos 100 episodios)
# Terminado episodio 135 con retorno 0.8392857142857143 en 45 pasos (retorno medio de 0.11032142857142857 en los últimos 100 episodios)
# Terminado episodio 136 con retorno 0.9821428571428571 en 5 pasos (retorno medio de 0.12014285714285715 en los últimos 100 episodios)
# Terminado episodio 137 con retorno 0.8928571428571429 en 30 pasos (retorno medio de 0.12907142857142856 en los últimos 100 episodios)
# Terminado episodio 138 con retorno 0 en 197 pasos (retorno medio de 0.12907142857142856 en los últimos 100 episodios)
# Terminado episodio 139 con retorno 0.95 en 14 pasos (retorno medio de 0.13857142857142857 en los últimos 100 episodios)
# Terminado episodio 140 con retorno 0 en 444 pasos (retorno medio de 0.13857142857142857 en los últimos 100 episodios)
# Terminado episodio 141 con retorno 0.9357142857142857 en 18 pasos (retorno medio de 0.1425357142857143 en los últimos 100 episodios)
# Terminado episodio 142 con retorno 0.9821428571428571 en 5 pasos (retorno medio de 0.15235714285714286 en los últimos 100 episodios)
# Terminado episodio 143 con retorno 0 en 5 pasos (retorno medio de 0.14242857142857143 en los últimos 100 episodios)
# Terminado episodio 144 con retorno 0 en 484 pasos (retorno medio de 0.14242857142857143 en los últimos 100 episodios)
# Terminado episodio 145 con retorno 0 en 318 pasos (retorno medio de 0.14242857142857143 en los últimos 100 episodios)
# Terminado episodio 146 con retorno 0 en 289 pasos (retorno medio de 0.14242857142857143 en los últimos 100 episodios)
# Terminado episodio 147 con retorno 0.8571428571428572 en 40 pasos (retorno medio de 0.151 en los últimos 100 episodios)
# Terminado episodio 148 con retorno 0.9714285714285714 en 8 pasos (retorno medio de 0.16071428571428573 en los últimos 100 episodios)
# Terminado episodio 149 con retorno 0.9464285714285714 en 15 pasos (retorno medio de 0.17017857142857146 en los últimos 100 episodios)
# Terminado episodio 150 con retorno 0.95 en 14 pasos (retorno medio de 0.17967857142857147 en los últimos 100 episodios)
# Terminado episodio 151 con retorno 0 en 29 pasos (retorno medio de 0.1796785714285714 en los últimos 100 episodios)
# Terminado episodio 152 con retorno 0.9964285714285714 en 1 pasos (retorno medio de 0.18964285714285714 en los últimos 100 episodios)
# Terminado episodio 153 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.19917857142857145 en los últimos 100 episodios)
# Terminado episodio 154 con retorno 0 en 43 pasos (retorno medio de 0.19917857142857145 en los últimos 100 episodios)
# Terminado episodio 155 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.20896428571428569 en los últimos 100 episodios)
# Terminado episodio 156 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.26021428571428573 en los últimos 100 episodios)
# Terminado episodio 157 con retorno 0 en 21 pasos (retorno medio de 0.26021428571428573 en los últimos 100 episodios)
# Terminado episodio 158 con retorno 0 en 116 pasos (retorno medio de 0.26021428571428573 en los últimos 100 episodios)
# Terminado episodio 159 con retorno -0.2607142857142857 en 353 pasos (retorno medio de 0.2576071428571428 en los últimos 100 episodios)
# Terminado episodio 160 con retorno 0 en 3 pasos (retorno medio de 0.25760714285714287 en los últimos 100 episodios)
# Terminado episodio 161 con retorno 0.9285714285714286 en 20 pasos (retorno medio de 0.26689285714285715 en los últimos 100 episodios)
# Terminado episodio 162 con retorno 0.9892857142857143 en 3 pasos (retorno medio de 0.2767857142857143 en los últimos 100 episodios)
# Terminado episodio 163 con retorno 0 en 9 pasos (retorno medio de 0.27678571428571425 en los últimos 100 episodios)
# Terminado episodio 164 con retorno 0.9321428571428572 en 19 pasos (retorno medio de 0.27632142857142855 en los últimos 100 episodios)
# Terminado episodio 165 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.2859642857142857 en los últimos 100 episodios)
# Terminado episodio 166 con retorno 0 en 3 pasos (retorno medio de 0.2859642857142857 en los últimos 100 episodios)
# Terminado episodio 167 con retorno 0.9714285714285714 en 8 pasos (retorno medio de 0.29567857142857146 en los últimos 100 episodios)
# Terminado episodio 168 con retorno 0 en 174 pasos (retorno medio de 0.29567857142857146 en los últimos 100 episodios)
# Terminado episodio 169 con retorno 0 en 443 pasos (retorno medio de 0.29567857142857146 en los últimos 100 episodios)
# Terminado episodio 170 con retorno 0 en 24 pasos (retorno medio de 0.29567857142857146 en los últimos 100 episodios)
# Terminado episodio 171 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.30525 en los últimos 100 episodios)
# Terminado episodio 172 con retorno 0.8357142857142857 en 46 pasos (retorno medio de 0.30489285714285713 en los últimos 100 episodios)
# Terminado episodio 173 con retorno 0 en 302 pasos (retorno medio de 0.30489285714285713 en los últimos 100 episodios)
# Terminado episodio 174 con retorno 0.6642857142857143 en 94 pasos (retorno medio de 0.3115357142857143 en los últimos 100 episodios)
# Terminado episodio 175 con retorno 0.9892857142857143 en 3 pasos (retorno medio de 0.32628571428571435 en los últimos 100 episodios)
# Terminado episodio 176 con retorno 0.8821428571428571 en 33 pasos (retorno medio de 0.33510714285714294 en los últimos 100 episodios)
# Terminado episodio 177 con retorno 0.8071428571428572 en 54 pasos (retorno medio de 0.33325000000000005 en los últimos 100 episodios)
# Terminado episodio 178 con retorno 0 en 1 pasos (retorno medio de 0.33325000000000005 en los últimos 100 episodios)
# Terminado episodio 179 con retorno 0 en 1 pasos (retorno medio de 0.33325000000000005 en los últimos 100 episodios)
# Terminado episodio 180 con retorno 0.8785714285714286 en 34 pasos (retorno medio de 0.3543928571428572 en los últimos 100 episodios)
# Terminado episodio 181 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.3640714285714285 en los últimos 100 episodios)
# Terminado episodio 182 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.37371428571428567 en los últimos 100 episodios)
# Terminado episodio 183 con retorno 0.9714285714285714 en 8 pasos (retorno medio de 0.38342857142857134 en los últimos 100 episodios)
# Terminado episodio 184 con retorno 0 en 2 pasos (retorno medio de 0.3834285714285714 en los últimos 100 episodios)
# Terminado episodio 185 con retorno 0 en 21 pasos (retorno medio de 0.3834285714285714 en los últimos 100 episodios)
# Terminado episodio 186 con retorno 0.9392857142857143 en 17 pasos (retorno medio de 0.3831428571428571 en los últimos 100 episodios)
# Terminado episodio 187 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.39292857142857146 en los últimos 100 episodios)
# Terminado episodio 188 con retorno 0.9392857142857143 en 17 pasos (retorno medio de 0.4023214285714286 en los últimos 100 episodios)
# Terminado episodio 189 con retorno 0.9714285714285714 en 8 pasos (retorno medio de 0.4120357142857143 en los últimos 100 episodios)
# Terminado episodio 190 con retorno 0 en 16 pasos (retorno medio de 0.4120357142857143 en los últimos 100 episodios)
# Terminado episodio 191 con retorno 0 en 3 pasos (retorno medio de 0.4120357142857143 en los últimos 100 episodios)
# Terminado episodio 192 con retorno 0.925 en 21 pasos (retorno medio de 0.4114999999999999 en los últimos 100 episodios)
# Terminado episodio 193 con retorno 0 en 5 pasos (retorno medio de 0.4114999999999999 en los últimos 100 episodios)
# Terminado episodio 194 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.4211071428571428 en los últimos 100 episodios)
# Terminado episodio 195 con retorno 0.9714285714285714 en 8 pasos (retorno medio de 0.4308214285714286 en los últimos 100 episodios)
# Terminado episodio 196 con retorno 0 en 13 pasos (retorno medio de 0.4308214285714286 en los últimos 100 episodios)
# Terminado episodio 197 con retorno 0 en 3 pasos (retorno medio de 0.4308214285714286 en los últimos 100 episodios)
# Terminado episodio 198 con retorno 0.9178571428571428 en 23 pasos (retorno medio de 0.43999999999999995 en los últimos 100 episodios)
# Terminado episodio 199 con retorno 0.9428571428571428 en 16 pasos (retorno medio de 0.4462857142857143 en los últimos 100 episodios)
# Terminado episodio 200 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.45596428571428566 en los últimos 100 episodios)
# Terminado episodio 201 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.4564285714285714 en los últimos 100 episodios)
# Terminado episodio 202 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.46603571428571433 en los últimos 100 episodios)
# Terminado episodio 203 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.47560714285714284 en los últimos 100 episodios)
# Terminado episodio 204 con retorno 0.9 en 28 pasos (retorno medio de 0.4846071428571428 en los últimos 100 episodios)
# Terminado episodio 205 con retorno 0.9142857142857143 en 24 pasos (retorno medio de 0.4949285714285714 en los últimos 100 episodios)
# Terminado episodio 206 con retorno 0.9428571428571428 en 16 pasos (retorno medio de 0.5043571428571428 en los últimos 100 episodios)
# Terminado episodio 207 con retorno 0.9214285714285715 en 22 pasos (retorno medio de 0.5135714285714286 en los últimos 100 episodios)
# Terminado episodio 208 con retorno 0.9321428571428572 en 19 pasos (retorno medio de 0.5133214285714285 en los últimos 100 episodios)
# Terminado episodio 209 con retorno 0 en 17 pasos (retorno medio de 0.5133214285714286 en los últimos 100 episodios)
# Terminado episodio 210 con retorno 0.9285714285714286 en 20 pasos (retorno medio de 0.5127857142857143 en los últimos 100 episodios)
# Terminado episodio 211 con retorno 0 en 12 pasos (retorno medio de 0.5115714285714286 en los últimos 100 episodios)
# Terminado episodio 212 con retorno 0.975 en 7 pasos (retorno medio de 0.5213214285714286 en los últimos 100 episodios)
# Terminado episodio 213 con retorno 0.975 en 7 pasos (retorno medio de 0.5310714285714286 en los últimos 100 episodios)
# Terminado episodio 214 con retorno 0 en 1 pasos (retorno medio de 0.5310714285714286 en los últimos 100 episodios)
# Terminado episodio 215 con retorno 0 en 6 pasos (retorno medio de 0.5310714285714286 en los últimos 100 episodios)
# Terminado episodio 216 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.54075 en los últimos 100 episodios)
# Terminado episodio 217 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.5504285714285715 en los últimos 100 episodios)
# Terminado episodio 218 con retorno 0 en 5 pasos (retorno medio de 0.5406428571428571 en los últimos 100 episodios)
# Terminado episodio 219 con retorno 0.9357142857142857 en 18 pasos (retorno medio de 0.5404642857142856 en los últimos 100 episodios)
# Terminado episodio 220 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.5488571428571428 en los últimos 100 episodios)
# Terminado episodio 221 con retorno 0 en 2 pasos (retorno medio de 0.5488571428571428 en los últimos 100 episodios)
# Terminado episodio 222 con retorno 0 en 5 pasos (retorno medio de 0.5488571428571428 en los últimos 100 episodios)
# Terminado episodio 223 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.5511071428571429 en los últimos 100 episodios)
# Terminado episodio 224 con retorno 0.95 en 14 pasos (retorno medio de 0.5508571428571429 en los últimos 100 episodios)
# Terminado episodio 225 con retorno 0 en 3 pasos (retorno medio de 0.5508571428571429 en los últimos 100 episodios)
# Terminado episodio 226 con retorno 0 en 9 pasos (retorno medio de 0.5410714285714286 en los últimos 100 episodios)
# Terminado episodio 227 con retorno 0 en 2 pasos (retorno medio de 0.5311785714285715 en los últimos 100 episodios)
# Terminado episodio 228 con retorno 0 en 2 pasos (retorno medio de 0.5275 en los últimos 100 episodios)
# Terminado episodio 229 con retorno 0 en 2 pasos (retorno medio de 0.5326428571428571 en los últimos 100 episodios)
# Terminado episodio 230 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.5421785714285714 en los últimos 100 episodios)
# Terminado episodio 231 con retorno 0.9714285714285714 en 8 pasos (retorno medio de 0.542 en los últimos 100 episodios)
# Terminado episodio 232 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.5517857142857142 en los últimos 100 episodios)
# Terminado episodio 233 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.5614285714285714 en los últimos 100 episodios)
# Terminado episodio 234 con retorno 0.85 en 42 pasos (retorno medio de 0.5699285714285715 en los últimos 100 episodios)
# Terminado episodio 235 con retorno 0.9285714285714286 en 20 pasos (retorno medio de 0.5708214285714286 en los últimos 100 episodios)
# Terminado episodio 236 con retorno 0 en 2 pasos (retorno medio de 0.561 en los últimos 100 episodios)
# Terminado episodio 237 con retorno 0 en 3 pasos (retorno medio de 0.5520714285714287 en los últimos 100 episodios)
# Terminado episodio 238 con retorno 0.925 en 21 pasos (retorno medio de 0.5613214285714285 en los últimos 100 episodios)
# Terminado episodio 239 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.5616785714285714 en los últimos 100 episodios)
# Terminado episodio 240 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.5712142857142857 en los últimos 100 episodios)
# Terminado episodio 241 con retorno 0.9928571428571429 en 2 pasos (retorno medio de 0.5717857142857142 en los últimos 100 episodios)
# Terminado episodio 242 con retorno 0 en 1 pasos (retorno medio de 0.5619642857142857 en los últimos 100 episodios)
# Terminado episodio 243 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.5715357142857143 en los últimos 100 episodios)
# Terminado episodio 244 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.5811785714285714 en los últimos 100 episodios)
# Terminado episodio 245 con retorno 0.925 en 21 pasos (retorno medio de 0.5904285714285714 en los últimos 100 episodios)
# Terminado episodio 246 con retorno 0 en 8 pasos (retorno medio de 0.5904285714285714 en los últimos 100 episodios)
# Terminado episodio 247 con retorno 0 en 7 pasos (retorno medio de 0.5818571428571429 en los últimos 100 episodios)
# Terminado episodio 248 con retorno 0.9892857142857143 en 3 pasos (retorno medio de 0.5820357142857142 en los últimos 100 episodios)
# Terminado episodio 249 con retorno 0.9464285714285714 en 15 pasos (retorno medio de 0.5820357142857143 en los últimos 100 episodios)
# Terminado episodio 250 con retorno 0.9928571428571429 en 2 pasos (retorno medio de 0.5824642857142857 en los últimos 100 episodios)
# Terminado episodio 251 con retorno 0.9464285714285714 en 15 pasos (retorno medio de 0.5919285714285714 en los últimos 100 episodios)
# Terminado episodio 252 con retorno 0.95 en 14 pasos (retorno medio de 0.5914642857142857 en los últimos 100 episodios)
# Terminado episodio 253 con retorno 0 en 2 pasos (retorno medio de 0.5819285714285715 en los últimos 100 episodios)
# Terminado episodio 254 con retorno 0 en 23 pasos (retorno medio de 0.5819285714285714 en los últimos 100 episodios)
# Terminado episodio 255 con retorno 0 en 4 pasos (retorno medio de 0.5721428571428572 en los últimos 100 episodios)
# Terminado episodio 256 con retorno 0 en 51 pasos (retorno medio de 0.5625714285714285 en los últimos 100 episodios)
# Terminado episodio 257 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.57225 en los últimos 100 episodios)
# Terminado episodio 258 con retorno 0.9392857142857143 en 17 pasos (retorno medio de 0.5816428571428571 en los últimos 100 episodios)
# Terminado episodio 259 con retorno 0 en 1 pasos (retorno medio de 0.5842499999999999 en los últimos 100 episodios)
# Terminado episodio 260 con retorno 0 en 2 pasos (retorno medio de 0.5842499999999999 en los últimos 100 episodios)
# Terminado episodio 261 con retorno 0.95 en 14 pasos (retorno medio de 0.5844642857142858 en los últimos 100 episodios)
# Terminado episodio 262 con retorno 0 en 11 pasos (retorno medio de 0.5745714285714285 en los últimos 100 episodios)
# Terminado episodio 263 con retorno 0 en 6 pasos (retorno medio de 0.5745714285714285 en los últimos 100 episodios)
# Terminado episodio 264 con retorno 0 en 10 pasos (retorno medio de 0.56525 en los últimos 100 episodios)
# Terminado episodio 265 con retorno 0.9821428571428571 en 5 pasos (retorno medio de 0.5654285714285714 en los últimos 100 episodios)
# Terminado episodio 266 con retorno 0 en 1 pasos (retorno medio de 0.5654285714285714 en los últimos 100 episodios)
# Terminado episodio 267 con retorno 0.7892857142857143 en 59 pasos (retorno medio de 0.5636071428571428 en los últimos 100 episodios)
# Terminado episodio 268 con retorno 0.9928571428571429 en 2 pasos (retorno medio de 0.5735357142857143 en los últimos 100 episodios)
# Terminado episodio 269 con retorno 0.9178571428571428 en 23 pasos (retorno medio de 0.5827142857142856 en los últimos 100 episodios)
# Terminado episodio 270 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.5924999999999999 en los últimos 100 episodios)
# Terminado episodio 271 con retorno 0.9142857142857143 en 24 pasos (retorno medio de 0.5920714285714285 en los últimos 100 episodios)
# Terminado episodio 272 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.5933214285714286 en los últimos 100 episodios)
# Terminado episodio 273 con retorno 0 en 2 pasos (retorno medio de 0.5933214285714286 en los últimos 100 episodios)
# Terminado episodio 274 con retorno 0.975 en 7 pasos (retorno medio de 0.5964285714285714 en los últimos 100 episodios)
# Terminado episodio 275 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.5961071428571428 en los últimos 100 episodios)
# Terminado episodio 276 con retorno 0 en 5 pasos (retorno medio de 0.5872857142857143 en los últimos 100 episodios)
# Terminado episodio 277 con retorno 0 en 1 pasos (retorno medio de 0.5792142857142857 en los últimos 100 episodios)
# Terminado episodio 278 con retorno 0.9714285714285714 en 8 pasos (retorno medio de 0.5889285714285714 en los últimos 100 episodios)
# Terminado episodio 279 con retorno 0 en 15 pasos (retorno medio de 0.5889285714285714 en los últimos 100 episodios)
# Terminado episodio 280 con retorno 0 en 1 pasos (retorno medio de 0.5801428571428571 en los últimos 100 episodios)
# Terminado episodio 281 con retorno 0 en 4 pasos (retorno medio de 0.5704642857142856 en los últimos 100 episodios)
# Terminado episodio 282 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.5703928571428571 en los últimos 100 episodios)
# Terminado episodio 283 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.5702142857142857 en los últimos 100 episodios)
# Terminado episodio 284 con retorno 0 en 4 pasos (retorno medio de 0.5702142857142857 en los últimos 100 episodios)
# Terminado episodio 285 con retorno 0.9928571428571429 en 2 pasos (retorno medio de 0.5801428571428571 en los últimos 100 episodios)
# Terminado episodio 286 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.5802857142857143 en los últimos 100 episodios)
# Terminado episodio 287 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.5801071428571428 en los últimos 100 episodios)
# Terminado episodio 288 con retorno 0.9428571428571428 en 16 pasos (retorno medio de 0.5801428571428571 en los últimos 100 episodios)
# Terminado episodio 289 con retorno 0 en 2 pasos (retorno medio de 0.5704285714285714 en los últimos 100 episodios)
# Terminado episodio 290 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.5800000000000001 en los últimos 100 episodios)
# Terminado episodio 291 con retorno 0.9928571428571429 en 2 pasos (retorno medio de 0.5899285714285714 en los últimos 100 episodios)
# Terminado episodio 292 con retorno 0.9357142857142857 en 18 pasos (retorno medio de 0.5900357142857142 en los últimos 100 episodios)
# Terminado episodio 293 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.599642857142857 en los últimos 100 episodios)
# Terminado episodio 294 con retorno 0 en 15 pasos (retorno medio de 0.5900357142857142 en los últimos 100 episodios)
# Terminado episodio 295 con retorno 0.9035714285714286 en 27 pasos (retorno medio de 0.5893571428571429 en los últimos 100 episodios)
# Terminado episodio 296 con retorno 0.95 en 14 pasos (retorno medio de 0.598857142857143 en los últimos 100 episodios)
# Terminado episodio 297 con retorno 0.95 en 14 pasos (retorno medio de 0.6083571428571429 en los últimos 100 episodios)
# Terminado episodio 298 con retorno 0.9892857142857143 en 3 pasos (retorno medio de 0.6090714285714287 en los últimos 100 episodios)
# Terminado episodio 299 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.6092142857142858 en los últimos 100 episodios)
# Terminado episodio 300 con retorno 0.9285714285714286 en 20 pasos (retorno medio de 0.6088214285714285 en los últimos 100 episodios)
# Terminado episodio 301 con retorno 0.9464285714285714 en 15 pasos (retorno medio de 0.6084999999999999 en los últimos 100 episodios)
# Terminado episodio 302 con retorno 0.9428571428571428 en 16 pasos (retorno medio de 0.6083214285714285 en los últimos 100 episodios)
# Terminado episodio 303 con retorno 0 en 3 pasos (retorno medio de 0.5987499999999999 en los últimos 100 episodios)
# Terminado episodio 304 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.5993571428571428 en los últimos 100 episodios)
# Terminado episodio 305 con retorno 0 en 4 pasos (retorno medio de 0.5902142857142857 en los últimos 100 episodios)
# Terminado episodio 306 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.5903928571428572 en los últimos 100 episodios)
# Terminado episodio 307 con retorno 0 en 3 pasos (retorno medio de 0.5811785714285714 en los últimos 100 episodios)
# Terminado episodio 308 con retorno 0.9464285714285714 en 15 pasos (retorno medio de 0.5813214285714285 en los últimos 100 episodios)
# Terminado episodio 309 con retorno 0.9285714285714286 en 20 pasos (retorno medio de 0.5906071428571429 en los últimos 100 episodios)
# Terminado episodio 310 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.5911071428571428 en los últimos 100 episodios)
# Terminado episodio 311 con retorno 0.9928571428571429 en 2 pasos (retorno medio de 0.6010357142857142 en los últimos 100 episodios)
# Terminado episodio 312 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.6008214285714285 en los últimos 100 episodios)
# Terminado episodio 313 con retorno 0 en 4 pasos (retorno medio de 0.5910714285714285 en los últimos 100 episodios)
# Terminado episodio 314 con retorno 0 en 7 pasos (retorno medio de 0.5910714285714285 en los últimos 100 episodios)
# Terminado episodio 315 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.6008571428571429 en los últimos 100 episodios)
# Terminado episodio 316 con retorno 0.975 en 7 pasos (retorno medio de 0.6009285714285714 en los últimos 100 episodios)
# Terminado episodio 317 con retorno 0 en 9 pasos (retorno medio de 0.59125 en los últimos 100 episodios)
# Terminado episodio 318 con retorno 0.9821428571428571 en 5 pasos (retorno medio de 0.6010714285714286 en los últimos 100 episodios)
# Terminado episodio 319 con retorno 0.9321428571428572 en 19 pasos (retorno medio de 0.6010357142857142 en los últimos 100 episodios)
# Terminado episodio 320 con retorno 0.9464285714285714 en 15 pasos (retorno medio de 0.6009285714285714 en los últimos 100 episodios)
# Terminado episodio 321 con retorno 0.925 en 21 pasos (retorno medio de 0.6101785714285713 en los últimos 100 episodios)
# Terminado episodio 322 con retorno 0 en 13 pasos (retorno medio de 0.6101785714285713 en los últimos 100 episodios)
# Terminado episodio 323 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.61025 en los últimos 100 episodios)
# Terminado episodio 324 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.6105357142857142 en los últimos 100 episodios)
# Terminado episodio 325 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.6200714285714285 en los últimos 100 episodios)
# Terminado episodio 326 con retorno 0 en 9 pasos (retorno medio de 0.6200714285714286 en los últimos 100 episodios)
# Terminado episodio 327 con retorno 0 en 2 pasos (retorno medio de 0.6200714285714285 en los últimos 100 episodios)
# Terminado episodio 328 con retorno 0.8678571428571429 en 37 pasos (retorno medio de 0.62875 en los últimos 100 episodios)
# Terminado episodio 329 con retorno 0.95 en 14 pasos (retorno medio de 0.63825 en los últimos 100 episodios)
# Terminado episodio 330 con retorno 0 en 4 pasos (retorno medio de 0.6287142857142858 en los últimos 100 episodios)
# Terminado episodio 331 con retorno 0.95 en 14 pasos (retorno medio de 0.6285000000000001 en los últimos 100 episodios)
# Terminado episodio 332 con retorno 0 en 5 pasos (retorno medio de 0.6187142857142858 en los últimos 100 episodios)
# Terminado episodio 333 con retorno 0.9821428571428571 en 5 pasos (retorno medio de 0.6188928571428571 en los últimos 100 episodios)
# Terminado episodio 334 con retorno 0.975 en 7 pasos (retorno medio de 0.6201428571428571 en los últimos 100 episodios)
# Terminado episodio 335 con retorno 0 en 4 pasos (retorno medio de 0.6108571428571428 en los últimos 100 episodios)
# Terminado episodio 336 con retorno 0 en 4 pasos (retorno medio de 0.6108571428571428 en los últimos 100 episodios)
# Terminado episodio 337 con retorno 0 en 3 pasos (retorno medio de 0.6108571428571428 en los últimos 100 episodios)
# Terminado episodio 338 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.6112142857142857 en los últimos 100 episodios)
# Terminado episodio 339 con retorno 0 en 1 pasos (retorno medio de 0.6013571428571428 en los últimos 100 episodios)
# Terminado episodio 340 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.6013928571428572 en los últimos 100 episodios)
# Terminado episodio 341 con retorno 0.9464285714285714 en 15 pasos (retorno medio de 0.6009285714285714 en los últimos 100 episodios)
# Terminado episodio 342 con retorno 0 en 6 pasos (retorno medio de 0.6009285714285714 en los últimos 100 episodios)
# Terminado episodio 343 con retorno 0.975 en 7 pasos (retorno medio de 0.6011071428571427 en los últimos 100 episodios)
# Terminado episodio 344 con retorno 0 en 2 pasos (retorno medio de 0.5914642857142857 en los últimos 100 episodios)
# Terminado episodio 345 con retorno 0.8892857142857142 en 31 pasos (retorno medio de 0.5911071428571428 en los últimos 100 episodios)
# Terminado episodio 346 con retorno 0.9392857142857143 en 17 pasos (retorno medio de 0.6004999999999999 en los últimos 100 episodios)
# Terminado episodio 347 con retorno 0.9214285714285715 en 22 pasos (retorno medio de 0.6097142857142857 en los últimos 100 episodios)
# Terminado episodio 348 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.6094285714285714 en los últimos 100 episodios)
# Terminado episodio 349 con retorno 0 en 8 pasos (retorno medio de 0.5999642857142857 en los últimos 100 episodios)
# Terminado episodio 350 con retorno 0.9428571428571428 en 16 pasos (retorno medio de 0.5994642857142857 en los últimos 100 episodios)
# Terminado episodio 351 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.5995357142857144 en los últimos 100 episodios)
# Terminado episodio 352 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.5996785714285715 en los últimos 100 episodios)
# Terminado episodio 353 con retorno 0 en 3 pasos (retorno medio de 0.5996785714285715 en los últimos 100 episodios)
# Terminado episodio 354 con retorno 0.9464285714285714 en 15 pasos (retorno medio de 0.6091428571428571 en los últimos 100 episodios)
# Terminado episodio 355 con retorno 0 en 12 pasos (retorno medio de 0.6091428571428572 en los últimos 100 episodios)
# Terminado episodio 356 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.6187142857142857 en los últimos 100 episodios)
# Terminado episodio 357 con retorno 0 en 2 pasos (retorno medio de 0.6090357142857143 en los últimos 100 episodios)
# Terminado episodio 358 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.6092142857142856 en los últimos 100 episodios)
# Terminado episodio 359 con retorno 0.9464285714285714 en 15 pasos (retorno medio de 0.6186785714285714 en los últimos 100 episodios)
# Terminado episodio 360 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.6283214285714286 en los últimos 100 episodios)
# Terminado episodio 361 con retorno 0.9821428571428571 en 5 pasos (retorno medio de 0.6286428571428571 en los últimos 100 episodios)
# Terminado episodio 362 con retorno 0.7642857142857142 en 66 pasos (retorno medio de 0.6362857142857142 en los últimos 100 episodios)
# Terminado episodio 363 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.6458214285714285 en los últimos 100 episodios)
# Terminado episodio 364 con retorno 0 en 3 pasos (retorno medio de 0.6458214285714284 en los últimos 100 episodios)
# Terminado episodio 365 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.6455357142857142 en los últimos 100 episodios)
# Terminado episodio 366 con retorno 0.8964285714285715 en 29 pasos (retorno medio de 0.6545000000000001 en los últimos 100 episodios)
# Terminado episodio 367 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.6564642857142856 en los últimos 100 episodios)
# Terminado episodio 368 con retorno 0 en 6 pasos (retorno medio de 0.6465357142857142 en los últimos 100 episodios)
# Terminado episodio 369 con retorno 0 en 2 pasos (retorno medio de 0.6373571428571428 en los últimos 100 episodios)
# Terminado episodio 370 con retorno 0.9464285714285714 en 15 pasos (retorno medio de 0.6370357142857143 en los últimos 100 episodios)
# Terminado episodio 371 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.6374285714285715 en los últimos 100 episodios)
# Terminado episodio 372 con retorno 0.9464285714285714 en 15 pasos (retorno medio de 0.6372857142857142 en los últimos 100 episodios)
# Terminado episodio 373 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.6469642857142857 en los últimos 100 episodios)
# Terminado episodio 374 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.6467857142857143 en los últimos 100 episodios)
# Terminado episodio 375 con retorno 0.95 en 14 pasos (retorno medio de 0.6467142857142857 en los últimos 100 episodios)
# Terminado episodio 376 con retorno 0.9928571428571429 en 2 pasos (retorno medio de 0.6566428571428571 en los últimos 100 episodios)
# Terminado episodio 377 con retorno 0.95 en 14 pasos (retorno medio de 0.6661428571428571 en los últimos 100 episodios)
# Terminado episodio 378 con retorno 0 en 1 pasos (retorno medio de 0.6564285714285716 en los últimos 100 episodios)
# Terminado episodio 379 con retorno 0.9285714285714286 en 20 pasos (retorno medio de 0.6657142857142857 en los últimos 100 episodios)
# Terminado episodio 380 con retorno 0.9142857142857143 en 24 pasos (retorno medio de 0.6748571428571428 en los últimos 100 episodios)
# Terminado episodio 381 con retorno 0.925 en 21 pasos (retorno medio de 0.6841071428571428 en los últimos 100 episodios)
# Terminado episodio 382 con retorno 0 en 4 pasos (retorno medio de 0.6745357142857142 en los últimos 100 episodios)
# Terminado episodio 383 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.6746071428571427 en los últimos 100 episodios)
# Terminado episodio 384 con retorno 0 en 1 pasos (retorno medio de 0.6746071428571427 en los últimos 100 episodios)
# Terminado episodio 385 con retorno 0.9464285714285714 en 15 pasos (retorno medio de 0.6741428571428572 en los últimos 100 episodios)
# Terminado episodio 386 con retorno 0.95 en 14 pasos (retorno medio de 0.6741071428571428 en los últimos 100 episodios)
# Terminado episodio 387 con retorno 0 en 1 pasos (retorno medio de 0.6645 en los últimos 100 episodios)
# Terminado episodio 388 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.6647500000000001 en los últimos 100 episodios)
# Terminado episodio 389 con retorno 0 en 7 pasos (retorno medio de 0.66475 en los últimos 100 episodios)
# Terminado episodio 390 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.6647142857142856 en los últimos 100 episodios)
# Terminado episodio 391 con retorno 0 en 2 pasos (retorno medio de 0.6547857142857143 en los últimos 100 episodios)
# Terminado episodio 392 con retorno 0 en 13 pasos (retorno medio de 0.6454285714285715 en los últimos 100 episodios)
# Terminado episodio 393 con retorno 0.9892857142857143 en 3 pasos (retorno medio de 0.6457142857142858 en los últimos 100 episodios)
# Terminado episodio 394 con retorno 0 en 3 pasos (retorno medio de 0.6457142857142857 en los últimos 100 episodios)
# Terminado episodio 395 con retorno 0.9714285714285714 en 8 pasos (retorno medio de 0.6463928571428572 en los últimos 100 episodios)
# Terminado episodio 396 con retorno 0.9428571428571428 en 16 pasos (retorno medio de 0.6463214285714285 en los últimos 100 episodios)
# Terminado episodio 397 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.6463571428571429 en los últimos 100 episodios)
# Terminado episodio 398 con retorno 0.9892857142857143 en 3 pasos (retorno medio de 0.6463571428571429 en los últimos 100 episodios)
# Terminado episodio 399 con retorno 0.975 en 7 pasos (retorno medio de 0.6465357142857142 en los últimos 100 episodios)
# Terminado episodio 400 con retorno 0.9714285714285714 en 8 pasos (retorno medio de 0.6469642857142857 en los últimos 100 episodios)
# Terminado episodio 401 con retorno 0.9107142857142857 en 25 pasos (retorno medio de 0.6466071428571429 en los últimos 100 episodios)
# Terminado episodio 402 con retorno 0.9892857142857143 en 3 pasos (retorno medio de 0.6470714285714285 en los últimos 100 episodios)
# Terminado episodio 403 con retorno 0 en 2 pasos (retorno medio de 0.6470714285714285 en los últimos 100 episodios)
# Terminado episodio 404 con retorno 0 en 1 pasos (retorno medio de 0.6374642857142856 en los últimos 100 episodios)
# Terminado episodio 405 con retorno 0.975 en 7 pasos (retorno medio de 0.6472142857142856 en los últimos 100 episodios)
# Terminado episodio 406 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.6471785714285714 en los últimos 100 episodios)
# Terminado episodio 407 con retorno 0.7214285714285714 en 78 pasos (retorno medio de 0.6543928571428573 en los últimos 100 episodios)
# Terminado episodio 408 con retorno 0.95 en 14 pasos (retorno medio de 0.6544285714285714 en los últimos 100 episodios)
# Terminado episodio 409 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.6548214285714284 en los últimos 100 episodios)
# Terminado episodio 410 con retorno 0 en 2 pasos (retorno medio de 0.6450357142857144 en los últimos 100 episodios)
# Terminado episodio 411 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.6447857142857143 en los últimos 100 episodios)
# Terminado episodio 412 con retorno 0 en 1 pasos (retorno medio de 0.63525 en los últimos 100 episodios)
# Terminado episodio 413 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.6447857142857143 en los últimos 100 episodios)
# Terminado episodio 414 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.6545714285714286 en los últimos 100 episodios)
# Terminado episodio 415 con retorno 0.9357142857142857 en 18 pasos (retorno medio de 0.6541428571428571 en los últimos 100 episodios)
# Terminado episodio 416 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.6539642857142858 en los últimos 100 episodios)
# Terminado episodio 417 con retorno 0.9428571428571428 en 16 pasos (retorno medio de 0.6633928571428571 en los últimos 100 episodios)
# Terminado episodio 418 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.6632142857142855 en los últimos 100 episodios)
# Terminado episodio 419 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.6634642857142855 en los últimos 100 episodios)
# Terminado episodio 420 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.6635357142857141 en los últimos 100 episodios)
# Terminado episodio 421 con retorno 0 en 2 pasos (retorno medio de 0.6542857142857141 en los últimos 100 episodios)
# Terminado episodio 422 con retorno 0.9714285714285714 en 8 pasos (retorno medio de 0.6639999999999999 en los últimos 100 episodios)
# Terminado episodio 423 con retorno 0 en 2 pasos (retorno medio de 0.6543214285714285 en los últimos 100 episodios)
# Terminado episodio 424 con retorno 0.9142857142857143 en 24 pasos (retorno medio de 0.6536785714285713 en los últimos 100 episodios)
# Terminado episodio 425 con retorno 0 en 1 pasos (retorno medio de 0.6441428571428571 en los últimos 100 episodios)
# Terminado episodio 426 con retorno 0.9714285714285714 en 8 pasos (retorno medio de 0.6538571428571429 en los últimos 100 episodios)
# Terminado episodio 427 con retorno 0.9464285714285714 en 15 pasos (retorno medio de 0.6633214285714285 en los últimos 100 episodios)
# Terminado episodio 428 con retorno 0 en 1 pasos (retorno medio de 0.6546428571428571 en los últimos 100 episodios)
# Terminado episodio 429 con retorno 0.8892857142857142 en 31 pasos (retorno medio de 0.6540357142857143 en los últimos 100 episodios)
# Terminado episodio 430 con retorno 0 en 5 pasos (retorno medio de 0.6540357142857144 en los últimos 100 episodios)
# Terminado episodio 431 con retorno 0.925 en 21 pasos (retorno medio de 0.6537857142857143 en los últimos 100 episodios)
# Terminado episodio 432 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.6633928571428572 en los últimos 100 episodios)
# Terminado episodio 433 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.6632142857142856 en los últimos 100 episodios)
# Terminado episodio 434 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.6630714285714285 en los últimos 100 episodios)
# Terminado episodio 435 con retorno 0.95 en 14 pasos (retorno medio de 0.6725714285714285 en los últimos 100 episodios)
# Terminado episodio 436 con retorno 0.95 en 14 pasos (retorno medio de 0.6820714285714286 en los últimos 100 episodios)
# Terminado episodio 437 con retorno 0 en 7 pasos (retorno medio de 0.6820714285714286 en los últimos 100 episodios)
# Terminado episodio 438 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.6823214285714285 en los últimos 100 episodios)
# Terminado episodio 439 con retorno 0.975 en 7 pasos (retorno medio de 0.6920714285714286 en los últimos 100 episodios)
# Terminado episodio 440 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.6923571428571427 en los últimos 100 episodios)
# Terminado episodio 441 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.6924642857142855 en los últimos 100 episodios)
# Terminado episodio 442 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.7022499999999998 en los últimos 100 episodios)
# Terminado episodio 443 con retorno 0.8964285714285715 en 29 pasos (retorno medio de 0.7014642857142855 en los últimos 100 episodios)
# Terminado episodio 444 con retorno 0 en 2 pasos (retorno medio de 0.7014642857142858 en los últimos 100 episodios)
# Terminado episodio 445 con retorno 0 en 1 pasos (retorno medio de 0.6925714285714286 en los últimos 100 episodios)
# Terminado episodio 446 con retorno 0.95 en 14 pasos (retorno medio de 0.6926785714285714 en los últimos 100 episodios)
# Terminado episodio 447 con retorno 0.9392857142857143 en 17 pasos (retorno medio de 0.692857142857143 en los últimos 100 episodios)
# Terminado episodio 448 con retorno 0.925 en 21 pasos (retorno medio de 0.6925 en los últimos 100 episodios)
# Terminado episodio 449 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.7020714285714286 en los últimos 100 episodios)
# Terminado episodio 450 con retorno 0 en 1 pasos (retorno medio de 0.6926428571428572 en los últimos 100 episodios)
# Terminado episodio 451 con retorno 0 en 1 pasos (retorno medio de 0.6831071428571428 en los últimos 100 episodios)
# Terminado episodio 452 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.6831428571428572 en los últimos 100 episodios)
# Terminado episodio 453 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.6927500000000001 en los últimos 100 episodios)
# Terminado episodio 454 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.692857142857143 en los últimos 100 episodios)
# Terminado episodio 455 con retorno 0.9071428571428571 en 26 pasos (retorno medio de 0.7019285714285715 en los últimos 100 episodios)
# Terminado episodio 456 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.7021428571428572 en los últimos 100 episodios)
# Terminado episodio 457 con retorno 0.9142857142857143 en 24 pasos (retorno medio de 0.7112857142857142 en los últimos 100 episodios)
# Terminado episodio 458 con retorno 0.975 en 7 pasos (retorno medio de 0.7114642857142855 en los últimos 100 episodios)
# Terminado episodio 459 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.7116071428571428 en los últimos 100 episodios)
# Terminado episodio 460 con retorno 0.9214285714285715 en 22 pasos (retorno medio de 0.7111785714285713 en los últimos 100 episodios)
# Terminado episodio 461 con retorno 0 en 2 pasos (retorno medio de 0.7013571428571429 en los últimos 100 episodios)
# Terminado episodio 462 con retorno 0.9464285714285714 en 15 pasos (retorno medio de 0.7031785714285715 en los últimos 100 episodios)
# Terminado episodio 463 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.70325 en los últimos 100 episodios)
# Terminado episodio 464 con retorno 0 en 3 pasos (retorno medio de 0.70325 en los últimos 100 episodios)
# Terminado episodio 465 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.7033214285714285 en los últimos 100 episodios)
# Terminado episodio 466 con retorno 0.9464285714285714 en 15 pasos (retorno medio de 0.7038214285714287 en los últimos 100 episodios)
# Terminado episodio 467 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.7037499999999999 en los últimos 100 episodios)
# Terminado episodio 468 con retorno 0.925 en 21 pasos (retorno medio de 0.713 en los últimos 100 episodios)
# Terminado episodio 469 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.7225357142857141 en los últimos 100 episodios)
# Terminado episodio 470 con retorno 0.9928571428571429 en 2 pasos (retorno medio de 0.723 en los últimos 100 episodios)
# Terminado episodio 471 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.723142857142857 en los últimos 100 episodios)
# Terminado episodio 472 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.7234642857142856 en los últimos 100 episodios)
# Terminado episodio 473 con retorno 0.9392857142857143 en 17 pasos (retorno medio de 0.7231785714285714 en los últimos 100 episodios)
# Terminado episodio 474 con retorno 0 en 2 pasos (retorno medio de 0.7136071428571428 en los últimos 100 episodios)
# Terminado episodio 475 con retorno 0 en 5 pasos (retorno medio de 0.7041071428571428 en los últimos 100 episodios)
# Terminado episodio 476 con retorno 0.9285714285714286 en 20 pasos (retorno medio de 0.7034642857142858 en los últimos 100 episodios)
# Terminado episodio 477 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.7036428571428571 en los últimos 100 episodios)
# Terminado episodio 478 con retorno 0.9357142857142857 en 18 pasos (retorno medio de 0.713 en los últimos 100 episodios)
# Terminado episodio 479 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.7135714285714285 en los últimos 100 episodios)
# Terminado episodio 480 con retorno 0 en 1 pasos (retorno medio de 0.7044285714285712 en los últimos 100 episodios)
# Terminado episodio 481 con retorno 0 en 1 pasos (retorno medio de 0.6951785714285714 en los últimos 100 episodios)
# Terminado episodio 482 con retorno 0.9428571428571428 en 16 pasos (retorno medio de 0.7046071428571428 en los últimos 100 episodios)
# Terminado episodio 483 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.704535714285714 en los últimos 100 episodios)
# Terminado episodio 484 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.7142142857142855 en los últimos 100 episodios)
# Terminado episodio 485 con retorno 0.9 en 28 pasos (retorno medio de 0.7137499999999999 en los últimos 100 episodios)
# Terminado episodio 486 con retorno 0.95 en 14 pasos (retorno medio de 0.71375 en los últimos 100 episodios)
# Terminado episodio 487 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.7232857142857142 en los últimos 100 episodios)
# Terminado episodio 488 con retorno 0.95 en 14 pasos (retorno medio de 0.7231071428571428 en los últimos 100 episodios)
# Terminado episodio 489 con retorno 0 en 2 pasos (retorno medio de 0.7231071428571428 en los últimos 100 episodios)
# Terminado episodio 490 con retorno 0 en 1 pasos (retorno medio de 0.7135714285714285 en los últimos 100 episodios)
# Terminado episodio 491 con retorno 0 en 2 pasos (retorno medio de 0.7135714285714286 en los últimos 100 episodios)
# Terminado episodio 492 con retorno 0.95 en 14 pasos (retorno medio de 0.7230714285714285 en los últimos 100 episodios)
# Terminado episodio 493 con retorno 0.9178571428571428 en 23 pasos (retorno medio de 0.7223571428571428 en los últimos 100 episodios)
# Terminado episodio 494 con retorno 0.9821428571428571 en 5 pasos (retorno medio de 0.7321785714285715 en los últimos 100 episodios)
# Terminado episodio 495 con retorno 0.9321428571428572 en 19 pasos (retorno medio de 0.7317857142857145 en los últimos 100 episodios)
# Terminado episodio 496 con retorno 0.95 en 14 pasos (retorno medio de 0.731857142857143 en los últimos 100 episodios)
# Terminado episodio 497 con retorno 0.95 en 14 pasos (retorno medio de 0.7318214285714286 en los últimos 100 episodios)
# Terminado episodio 498 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.7315714285714285 en los últimos 100 episodios)
# Terminado episodio 499 con retorno 0.9178571428571428 en 23 pasos (retorno medio de 0.731 en los últimos 100 episodios)
# Terminado episodio 500 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.7308214285714285 en los últimos 100 episodios)

# %% [markdown]
# El proceso de aprendizaje tiene una componente aleatoria importante, por lo que dos ejecuciones consecutivas pueden aprender valores $Q$ diferentes de las que se deriven políticas $\pi$ también diferentes. No obstante, si has implementado bien el algoritmo, deberías haber observado lo siguiente:
#   1. Inicialmente hay muchos episodios con retorno 0 (el agente acaba en la lava). La duración de estos episodios es muy variable. Además, si imprimiésemos `q_values` tras cada uno de estos episodios, ¡veríamos que $Q$ no se modifica! Cada paso utiliza $R$ y $Q(S',A')$ para actualizar $Q(S,A)$, pero si tanto $R$ como $Q(S',A')$ son cero, el valor de $Q(S,A)$ no cambiará.
#   1. Con el tiempo, y por pura casualidad, el agente terminará algún episodio llegando a la meta. Esto le reportará una recompensa de 1, lo que hará que $Q(S_t,A_t)$ se actualice a un valor positivo.
#   1. La próxima vez que el agente esté en $S_t$, elegirá la acción $A_t$ (salvo que toque acción aleatoria por el $\epsilon$), lo que hará que termine el episodio con recompensa 1. **¡Habrá aprendido una política útil para la última casilla!** Pero, además, el estado $S_{t-1}$ que llevó a $S_t$ (usando la acción $A_{t-1}$) verá su $Q(S_{t-1},A_{t-1})$ actualizado a un valor positivo. **¡Ya sabrá una política útil para las dos últimas casillas!**
#   1. Mediante este proceso, la información respecto a qué política es útil se irá propagando desde las casillas aledañas a la meta a sus vecinas, y de estas a sus vecinas y así sucesivamente hasta cubrir el tablero entero. A esto hay que añadir que, también por pura casualidad, el agente puede encontrar otros caminos que conducen a la meta y lanzar este mismo proceso de propagación pero siguiendo otro camino que conduzca a la meta.
#   1. El efecto de esto es que, a medida que transcurren los episodios ocurren dos cosas:
#     - El número de episodios con retorno positivo aumenta
#     - La duración de los episodios con retorno positivos disminuye (el agente va más tiempo por "camino conocido")
#   1. Esto repercute en el retorno medio de los 100 últimos episodios: comenzará siendo minúsculo, pero llegado un punto subirá con gran velocidad.
#   1. El retorno de los últimos 100 episodios alcanzará un punto máximo en torno al cual oscilará hacia el final.

# %% [markdown]
# Visualicemos la política aprendida. Vamos a mostrar, para cada casilla, la orientación que tiene el agente cuando la acción preferida (la que tiene mayor valor $Q$) sea `FORWARD`.
#
# >**Recordatorio**
# >
# > Las orientaciones se codifican así:
# > - 0 $\rightarrow$ derecha
# > - 1 $\rightarrow$ abajo
# > - 2 $\rightarrow$ izquierda
# > - 3 $\rightarrow$ arriba

# %%
# Esta función devuelve un carácter de flecha que representa la orientación del agente para la cual los q valores recomiendan la acción forward
def get_flecha_direccion_maximo_valor(q_values:np.ndarray) -> str:
    accion_preferida_por_orientacion = q_values.argmax(axis=1) # Para cada una de las cuatro orientaciones, calculamos qué acción se prefiere
    direccion = np.argmax(accion_preferida_por_orientacion == 2) # De las orientaciones que prefieran FORWARD, tomamos una (la primera)
    # En función de la orientación, devolvemos la flecha apropiada.
    if direccion==0:
        return '⮕'
    if direccion==1:
        return '⬇'
    if direccion==2:
        return '⬅'
    if direccion==3:
        return '⬆'
    return '?'

# Muestra la política por pantalla
def dibuja_politica(q_valores:np.ndarray) -> None:
    # Recorre las filas del tablero...
    for i in range(q_valores.shape[1]):
        # ... componiendo una línea por fila...
        linea = ''
        for j in range(q_valores.shape[0]): # Recorre las columnas
            if i==0 and j==6: # Pintamos la meta
                    linea+='🟥'
            elif (i==0 or i==1)and j>1 and j<5: # Pintamos la lava
                    linea+='🟧'
            else:
                linea+=get_flecha_direccion_maximo_valor(q_valores[j,i]) # Pintamos la flecha apropiada para esta casilla
        # ...que finalmente imprime
        print(linea)

dibuja_politica(q_valores_sarsa)
# Out:
# ⮕⮕🟧🟧🟧⮕🟥
# ⮕⬇🟧🟧🟧⬇⬅
# ⮕⮕⮕⮕⮕⬆⬅
# ⮕⮕⮕⮕⮕⬆⬅
# ⬆⮕⮕⮕⬆⬆⮕

# %% [markdown]
# Hemos comprobado que nuestro agente tiene que hacer muchos episodios que no le llevan a aprender porque no le dan ninguna recompensa, lo cual provoca que no pueda actualizar $Q(S,A)$ para ninguno de los pares $S,A$ por los que transita.
#
# **¿Qué crees que ocurriría si diésemos una recompensa negativa a caer en la lava? ¿Cambiaría la velocidad a la que aprende el agente?**
#
# Haz la prueba añadiendo esto después de cada paso:
# ```python
#     if terminated and reward==0:
#         reward = -1
# ```
#
# Modifica la función `sarsa` y ejecuta la celda siguiente. **¿Qué observas?**

# %%
q_valores_sarsa_con_lava_negativa = sarsa() # Sarsa debe haberse modificado para que caer a la lava proporcione recompensa -1
dibuja_politica(q_valores_sarsa_con_lava_negativa) #el agente se vuelve inseguro y comienza a girar en lugar de avanzar por lo que tarda mas en completar cada episodio
# Out:
# Terminado episodio 1 con retorno 0 en 145 pasos
# Terminado episodio 2 con retorno 0 en 8 pasos
# Terminado episodio 3 con retorno 0 en 1185 pasos
# Terminado episodio 4 con retorno -1.125 en 595 pasos
# Terminado episodio 5 con retorno 0 en 11 pasos
# Terminado episodio 6 con retorno 0 en 50 pasos
# Terminado episodio 7 con retorno 0.4178571428571428 en 163 pasos
# Terminado episodio 8 con retorno 0 en 3 pasos
# Terminado episodio 9 con retorno 0 en 149 pasos
# Terminado episodio 10 con retorno 0 en 21 pasos
# Terminado episodio 11 con retorno 0 en 6 pasos
# Terminado episodio 12 con retorno 0.625 en 105 pasos
# Terminado episodio 13 con retorno 0 en 228 pasos
# Terminado episodio 14 con retorno 0 en 11 pasos
# Terminado episodio 15 con retorno 0 en 24 pasos
# Terminado episodio 16 con retorno 0 en 16 pasos
# Terminado episodio 17 con retorno 0 en 37 pasos
# Terminado episodio 18 con retorno 0 en 87 pasos
# Terminado episodio 19 con retorno 0 en 6 pasos
# Terminado episodio 20 con retorno 0 en 60 pasos
# Terminado episodio 21 con retorno 0 en 39 pasos
# Terminado episodio 22 con retorno 0 en 460 pasos
# Terminado episodio 23 con retorno 0 en 63 pasos
# Terminado episodio 24 con retorno 0 en 125 pasos
# Terminado episodio 25 con retorno 0 en 184 pasos
# Terminado episodio 26 con retorno 0 en 12 pasos
# Terminado episodio 27 con retorno 0.12857142857142856 en 244 pasos
# Terminado episodio 28 con retorno 0 en 18 pasos
# Terminado episodio 29 con retorno 0 en 1051 pasos
# Terminado episodio 30 con retorno 0 en 166 pasos
# Terminado episodio 31 con retorno 0 en 25 pasos
# Terminado episodio 32 con retorno 0 en 3 pasos
# Terminado episodio 33 con retorno 0 en 457 pasos
# Terminado episodio 34 con retorno 0.875 en 35 pasos
# Terminado episodio 35 con retorno 0 en 89 pasos
# Terminado episodio 36 con retorno 0 en 94 pasos
# Terminado episodio 37 con retorno 0 en 591 pasos
# Terminado episodio 38 con retorno 0 en 34 pasos
# Terminado episodio 39 con retorno 0 en 2 pasos
# Terminado episodio 40 con retorno 0.7571428571428571 en 68 pasos
# Terminado episodio 41 con retorno 0 en 104 pasos
# Terminado episodio 42 con retorno 0 en 1 pasos
# Terminado episodio 43 con retorno 0 en 261 pasos
# Terminado episodio 44 con retorno 0 en 363 pasos
# Terminado episodio 45 con retorno 0.9714285714285714 en 8 pasos
# Terminado episodio 46 con retorno 0 en 65 pasos
# Terminado episodio 47 con retorno 0 en 560 pasos
# Terminado episodio 48 con retorno 0.46071428571428574 en 151 pasos
# Terminado episodio 49 con retorno 0 en 330 pasos
# Terminado episodio 50 con retorno 0 en 261 pasos
# Terminado episodio 51 con retorno 0 en 1 pasos
# Terminado episodio 52 con retorno 0.9785714285714285 en 6 pasos
# Terminado episodio 53 con retorno 0.9928571428571429 en 2 pasos
# Terminado episodio 54 con retorno 0 en 812 pasos
# Terminado episodio 55 con retorno 0.9964285714285714 en 1 pasos
# Terminado episodio 56 con retorno 0 en 12 pasos
# Terminado episodio 57 con retorno 0 en 92 pasos
# Terminado episodio 58 con retorno 0 en 98 pasos
# Terminado episodio 59 con retorno 0.9928571428571429 en 2 pasos
# Terminado episodio 60 con retorno 0 en 354 pasos
# Terminado episodio 61 con retorno 0 en 224 pasos
# Terminado episodio 62 con retorno 0 en 124 pasos
# Terminado episodio 63 con retorno 0 en 10 pasos
# Terminado episodio 64 con retorno 0 en 22 pasos
# Terminado episodio 65 con retorno 0 en 434 pasos
# Terminado episodio 66 con retorno 0.9857142857142858 en 4 pasos
# Terminado episodio 67 con retorno 0.9892857142857143 en 3 pasos
# Terminado episodio 68 con retorno 0 en 9 pasos
# Terminado episodio 69 con retorno 0 en 4 pasos
# Terminado episodio 70 con retorno 0 en 18 pasos
# Terminado episodio 71 con retorno 0 en 1 pasos
# Terminado episodio 72 con retorno 0 en 33 pasos
# Terminado episodio 73 con retorno 0.9892857142857143 en 3 pasos
# Terminado episodio 74 con retorno 0 en 13 pasos
# Terminado episodio 75 con retorno 0.1071428571428571 en 250 pasos
# Terminado episodio 76 con retorno 0 en 19 pasos
# Terminado episodio 77 con retorno 0 en 231 pasos
# Terminado episodio 78 con retorno 0 en 22 pasos
# Terminado episodio 79 con retorno 0.9928571428571429 en 2 pasos
# Terminado episodio 80 con retorno 0 en 493 pasos
# Terminado episodio 81 con retorno 0 en 851 pasos
# Terminado episodio 82 con retorno 0 en 32 pasos
# Terminado episodio 83 con retorno 0 en 89 pasos
# Terminado episodio 84 con retorno 0 en 5 pasos
# Terminado episodio 85 con retorno 0.9928571428571429 en 2 pasos
# Terminado episodio 86 con retorno 0 en 61 pasos
# Terminado episodio 87 con retorno 0 en 14 pasos
# Terminado episodio 88 con retorno 0 en 68 pasos
# Terminado episodio 89 con retorno 0.23571428571428577 en 214 pasos
# Terminado episodio 90 con retorno 0 en 514 pasos
# Terminado episodio 91 con retorno 0 en 23 pasos
# Terminado episodio 92 con retorno 0 en 448 pasos
# Terminado episodio 93 con retorno 0 en 23 pasos
# Terminado episodio 94 con retorno 0 en 6 pasos
# Terminado episodio 95 con retorno 0 en 169 pasos
# Terminado episodio 96 con retorno 0 en 390 pasos
# Terminado episodio 97 con retorno 0 en 40 pasos
# Terminado episodio 98 con retorno 0 en 15 pasos
# Terminado episodio 99 con retorno 0 en 11 pasos
# Terminado episodio 100 con retorno 0 en 123 pasos
# Terminado episodio 101 con retorno 0.9928571428571429 en 2 pasos (retorno medio de 0.13357142857142856 en los últimos 100 episodios)
# Terminado episodio 102 con retorno 0 en 184 pasos (retorno medio de 0.13357142857142856 en los últimos 100 episodios)
# Terminado episodio 103 con retorno 0 en 639 pasos (retorno medio de 0.13357142857142856 en los últimos 100 episodios)
# Terminado episodio 104 con retorno 0 en 29 pasos (retorno medio de 0.14482142857142857 en los últimos 100 episodios)
# Terminado episodio 105 con retorno 0 en 30 pasos (retorno medio de 0.14482142857142857 en los últimos 100 episodios)
# Terminado episodio 106 con retorno 0.7071428571428571 en 82 pasos (retorno medio de 0.15189285714285716 en los últimos 100 episodios)
# Terminado episodio 107 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.15757142857142858 en los últimos 100 episodios)
# Terminado episodio 108 con retorno 0 en 8 pasos (retorno medio de 0.15757142857142858 en los últimos 100 episodios)
# Terminado episodio 109 con retorno 0 en 22 pasos (retorno medio de 0.15757142857142858 en los últimos 100 episodios)
# Terminado episodio 110 con retorno 0 en 1 pasos (retorno medio de 0.15757142857142858 en los últimos 100 episodios)
# Terminado episodio 111 con retorno 0 en 782 pasos (retorno medio de 0.15757142857142858 en los últimos 100 episodios)
# Terminado episodio 112 con retorno 0 en 3 pasos (retorno medio de 0.15132142857142855 en los últimos 100 episodios)
# Terminado episodio 113 con retorno 0 en 154 pasos (retorno medio de 0.15132142857142858 en los últimos 100 episodios)
# Terminado episodio 114 con retorno 0.3678571428571429 en 177 pasos (retorno medio de 0.155 en los últimos 100 episodios)
# Terminado episodio 115 con retorno 0 en 6 pasos (retorno medio de 0.155 en los últimos 100 episodios)
# Terminado episodio 116 con retorno 0.8857142857142857 en 32 pasos (retorno medio de 0.16385714285714287 en los últimos 100 episodios)
# Terminado episodio 117 con retorno 0 en 93 pasos (retorno medio de 0.16385714285714287 en los últimos 100 episodios)
# Terminado episodio 118 con retorno 0 en 559 pasos (retorno medio de 0.16385714285714287 en los últimos 100 episodios)
# Terminado episodio 119 con retorno 0 en 22 pasos (retorno medio de 0.16385714285714287 en los últimos 100 episodios)
# Terminado episodio 120 con retorno 0 en 333 pasos (retorno medio de 0.16385714285714287 en los últimos 100 episodios)
# Terminado episodio 121 con retorno 0 en 2 pasos (retorno medio de 0.16385714285714287 en los últimos 100 episodios)
# Terminado episodio 122 con retorno 0 en 245 pasos (retorno medio de 0.16385714285714287 en los últimos 100 episodios)
# Terminado episodio 123 con retorno 0 en 2 pasos (retorno medio de 0.16385714285714287 en los últimos 100 episodios)
# Terminado episodio 124 con retorno 0 en 11 pasos (retorno medio de 0.16385714285714287 en los últimos 100 episodios)
# Terminado episodio 125 con retorno 0 en 137 pasos (retorno medio de 0.16385714285714287 en los últimos 100 episodios)
# Terminado episodio 126 con retorno 0 en 121 pasos (retorno medio de 0.16385714285714287 en los últimos 100 episodios)
# Terminado episodio 127 con retorno 0.9357142857142857 en 18 pasos (retorno medio de 0.17192857142857146 en los últimos 100 episodios)
# Terminado episodio 128 con retorno 0 en 285 pasos (retorno medio de 0.17192857142857146 en los últimos 100 episodios)
# Terminado episodio 129 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.18171428571428574 en los últimos 100 episodios)
# Terminado episodio 130 con retorno 0 en 43 pasos (retorno medio de 0.18171428571428574 en los últimos 100 episodios)
# Terminado episodio 131 con retorno 0 en 36 pasos (retorno medio de 0.18171428571428572 en los últimos 100 episodios)
# Terminado episodio 132 con retorno 0 en 38 pasos (retorno medio de 0.18171428571428572 en los últimos 100 episodios)
# Terminado episodio 133 con retorno 0 en 4 pasos (retorno medio de 0.18171428571428572 en los últimos 100 episodios)
# Terminado episodio 134 con retorno 0 en 58 pasos (retorno medio de 0.1729642857142857 en los últimos 100 episodios)
# Terminado episodio 135 con retorno 0 en 246 pasos (retorno medio de 0.1729642857142857 en los últimos 100 episodios)
# Terminado episodio 136 con retorno 0 en 29 pasos (retorno medio de 0.1729642857142857 en los últimos 100 episodios)
# Terminado episodio 137 con retorno 0 en 17 pasos (retorno medio de 0.1729642857142857 en los últimos 100 episodios)
# Terminado episodio 138 con retorno 0 en 2 pasos (retorno medio de 0.1729642857142857 en los últimos 100 episodios)
# Terminado episodio 139 con retorno 0 en 342 pasos (retorno medio de 0.1729642857142857 en los últimos 100 episodios)
# Terminado episodio 140 con retorno 0.9928571428571429 en 2 pasos (retorno medio de 0.17532142857142857 en los últimos 100 episodios)
# Terminado episodio 141 con retorno 0.9821428571428571 en 5 pasos (retorno medio de 0.18514285714285716 en los últimos 100 episodios)
# Terminado episodio 142 con retorno 0 en 9 pasos (retorno medio de 0.1851428571428572 en los últimos 100 episodios)
# Terminado episodio 143 con retorno 0.7071428571428571 en 82 pasos (retorno medio de 0.19221428571428573 en los últimos 100 episodios)
# Terminado episodio 144 con retorno 0.9464285714285714 en 15 pasos (retorno medio de 0.20167857142857146 en los últimos 100 episodios)
# Terminado episodio 145 con retorno 0 en 32 pasos (retorno medio de 0.19196428571428573 en los últimos 100 episodios)
# Terminado episodio 146 con retorno 0 en 7 pasos (retorno medio de 0.19196428571428573 en los últimos 100 episodios)
# Terminado episodio 147 con retorno 0 en 215 pasos (retorno medio de 0.19196428571428573 en los últimos 100 episodios)
# Terminado episodio 148 con retorno 0 en 47 pasos (retorno medio de 0.1873571428571429 en los últimos 100 episodios)
# Terminado episodio 149 con retorno 0 en 100 pasos (retorno medio de 0.1873571428571429 en los últimos 100 episodios)
# Terminado episodio 150 con retorno 0 en 402 pasos (retorno medio de 0.18735714285714283 en los últimos 100 episodios)
# Terminado episodio 151 con retorno 0 en 65 pasos (retorno medio de 0.1873571428571429 en los últimos 100 episodios)
# Terminado episodio 152 con retorno 0 en 3 pasos (retorno medio de 0.1775714285714286 en los últimos 100 episodios)
# Terminado episodio 153 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.17732142857142857 en los últimos 100 episodios)
# Terminado episodio 154 con retorno 0.9821428571428571 en 5 pasos (retorno medio de 0.1871428571428571 en los últimos 100 episodios)
# Terminado episodio 155 con retorno 0.8892857142857142 en 31 pasos (retorno medio de 0.1860714285714286 en los últimos 100 episodios)
# Terminado episodio 156 con retorno 0 en 518 pasos (retorno medio de 0.1860714285714286 en los últimos 100 episodios)
# Terminado episodio 157 con retorno 0 en 90 pasos (retorno medio de 0.1860714285714286 en los últimos 100 episodios)
# Terminado episodio 158 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.1958571428571429 en los últimos 100 episodios)
# Terminado episodio 159 con retorno 0 en 345 pasos (retorno medio de 0.18592857142857142 en los últimos 100 episodios)
# Terminado episodio 160 con retorno 0 en 17 pasos (retorno medio de 0.18592857142857142 en los últimos 100 episodios)
# Terminado episodio 161 con retorno 0 en 108 pasos (retorno medio de 0.18592857142857142 en los últimos 100 episodios)
# Terminado episodio 162 con retorno 0 en 3 pasos (retorno medio de 0.18592857142857142 en los últimos 100 episodios)
# Terminado episodio 163 con retorno 0 en 42 pasos (retorno medio de 0.18592857142857142 en los últimos 100 episodios)
# Terminado episodio 164 con retorno 0.9821428571428571 en 5 pasos (retorno medio de 0.19574999999999998 en los últimos 100 episodios)
# Terminado episodio 165 con retorno 0 en 24 pasos (retorno medio de 0.19574999999999998 en los últimos 100 episodios)
# Terminado episodio 166 con retorno 0 en 584 pasos (retorno medio de 0.18589285714285717 en los últimos 100 episodios)
# Terminado episodio 167 con retorno 0 en 7 pasos (retorno medio de 0.17600000000000002 en los últimos 100 episodios)
# Terminado episodio 168 con retorno 0 en 127 pasos (retorno medio de 0.17600000000000002 en los últimos 100 episodios)
# Terminado episodio 169 con retorno 0.4928571428571429 en 142 pasos (retorno medio de 0.18092857142857144 en los últimos 100 episodios)
# Terminado episodio 170 con retorno 0 en 200 pasos (retorno medio de 0.18092857142857144 en los últimos 100 episodios)
# Terminado episodio 171 con retorno -2.057142857142857 en 856 pasos (retorno medio de 0.1603571428571429 en los últimos 100 episodios)
# Terminado episodio 172 con retorno 0 en 48 pasos (retorno medio de 0.1603571428571429 en los últimos 100 episodios)
# Terminado episodio 173 con retorno 0.9928571428571429 en 2 pasos (retorno medio de 0.16039285714285714 en los últimos 100 episodios)
# Terminado episodio 174 con retorno 0 en 115 pasos (retorno medio de 0.16039285714285714 en los últimos 100 episodios)
# Terminado episodio 175 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.16917857142857146 en los últimos 100 episodios)
# Terminado episodio 176 con retorno 0 en 262 pasos (retorno medio de 0.16917857142857146 en los últimos 100 episodios)
# Terminado episodio 177 con retorno 0 en 2 pasos (retorno medio de 0.16917857142857146 en los últimos 100 episodios)
# Terminado episodio 178 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.17885714285714285 en los últimos 100 episodios)
# Terminado episodio 179 con retorno 0.9285714285714286 en 20 pasos (retorno medio de 0.1782142857142857 en los últimos 100 episodios)
# Terminado episodio 180 con retorno 0 en 10 pasos (retorno medio de 0.1782142857142857 en los últimos 100 episodios)
# Terminado episodio 181 con retorno 0 en 40 pasos (retorno medio de 0.1782142857142857 en los últimos 100 episodios)
# Terminado episodio 182 con retorno 0.9821428571428571 en 5 pasos (retorno medio de 0.18803571428571428 en los últimos 100 episodios)
# Terminado episodio 183 con retorno 0 en 4 pasos (retorno medio de 0.1880357142857143 en los últimos 100 episodios)
# Terminado episodio 184 con retorno 0.06785714285714273 en 261 pasos (retorno medio de 0.1887142857142857 en los últimos 100 episodios)
# Terminado episodio 185 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.18846428571428572 en los últimos 100 episodios)
# Terminado episodio 186 con retorno 0 en 242 pasos (retorno medio de 0.18846428571428572 en los últimos 100 episodios)
# Terminado episodio 187 con retorno 0 en 3 pasos (retorno medio de 0.18846428571428572 en los últimos 100 episodios)
# Terminado episodio 188 con retorno 0 en 3 pasos (retorno medio de 0.18846428571428567 en los últimos 100 episodios)
# Terminado episodio 189 con retorno 0.975 en 7 pasos (retorno medio de 0.1958571428571429 en los últimos 100 episodios)
# Terminado episodio 190 con retorno 0.8821428571428571 en 33 pasos (retorno medio de 0.20467857142857146 en los últimos 100 episodios)
# Terminado episodio 191 con retorno 0.5249999999999999 en 133 pasos (retorno medio de 0.20992857142857144 en los últimos 100 episodios)
# Terminado episodio 192 con retorno 0.06428571428571417 en 262 pasos (retorno medio de 0.21057142857142858 en los últimos 100 episodios)
# Terminado episodio 193 con retorno 0 en 902 pasos (retorno medio de 0.21057142857142852 en los últimos 100 episodios)
# Terminado episodio 194 con retorno 0.9107142857142857 en 25 pasos (retorno medio de 0.2196785714285714 en los últimos 100 episodios)
# Terminado episodio 195 con retorno 0 en 335 pasos (retorno medio de 0.21967857142857142 en los últimos 100 episodios)
# Terminado episodio 196 con retorno 0 en 1 pasos (retorno medio de 0.21967857142857142 en los últimos 100 episodios)
# Terminado episodio 197 con retorno 0 en 103 pasos (retorno medio de 0.21967857142857142 en los últimos 100 episodios)
# Terminado episodio 198 con retorno 0 en 102 pasos (retorno medio de 0.21967857142857142 en los últimos 100 episodios)
# Terminado episodio 199 con retorno 0 en 101 pasos (retorno medio de 0.21967857142857142 en los últimos 100 episodios)
# Terminado episodio 200 con retorno 0.975 en 7 pasos (retorno medio de 0.22942857142857143 en los últimos 100 episodios)
# Terminado episodio 201 con retorno 0.9 en 28 pasos (retorno medio de 0.2285 en los últimos 100 episodios)
# Terminado episodio 202 con retorno 0 en 19 pasos (retorno medio de 0.2285 en los últimos 100 episodios)
# Terminado episodio 203 con retorno 0 en 25 pasos (retorno medio de 0.2285 en los últimos 100 episodios)
# Terminado episodio 204 con retorno 0 en 6 pasos (retorno medio de 0.22849999999999998 en los últimos 100 episodios)
# Terminado episodio 205 con retorno 0.8 en 56 pasos (retorno medio de 0.23650000000000002 en los últimos 100 episodios)
# Terminado episodio 206 con retorno 0.975 en 7 pasos (retorno medio de 0.2391785714285715 en los últimos 100 episodios)
# Terminado episodio 207 con retorno 0 en 75 pasos (retorno medio de 0.2293214285714286 en los últimos 100 episodios)
# Terminado episodio 208 con retorno 0 en 196 pasos (retorno medio de 0.2293214285714286 en los últimos 100 episodios)
# Terminado episodio 209 con retorno 0.4464285714285714 en 155 pasos (retorno medio de 0.23378571428571435 en los últimos 100 episodios)
# Terminado episodio 210 con retorno 0.2607142857142857 en 207 pasos (retorno medio de 0.23639285714285715 en los últimos 100 episodios)
# Terminado episodio 211 con retorno 0 en 145 pasos (retorno medio de 0.23639285714285715 en los últimos 100 episodios)
# Terminado episodio 212 con retorno 0 en 126 pasos (retorno medio de 0.23639285714285715 en los últimos 100 episodios)
# Terminado episodio 213 con retorno 0 en 335 pasos (retorno medio de 0.23639285714285715 en los últimos 100 episodios)
# Terminado episodio 214 con retorno 0.9928571428571429 en 2 pasos (retorno medio de 0.24264285714285716 en los últimos 100 episodios)
# Terminado episodio 215 con retorno 0.5892857142857143 en 115 pasos (retorno medio de 0.2485357142857143 en los últimos 100 episodios)
# Terminado episodio 216 con retorno 0.8428571428571429 en 44 pasos (retorno medio de 0.24810714285714286 en los últimos 100 episodios)
# Terminado episodio 217 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.2576428571428572 en los últimos 100 episodios)
# Terminado episodio 218 con retorno 0 en 139 pasos (retorno medio de 0.2576428571428571 en los últimos 100 episodios)
# Terminado episodio 219 con retorno 0 en 124 pasos (retorno medio de 0.2576428571428571 en los últimos 100 episodios)
# Terminado episodio 220 con retorno 0 en 8 pasos (retorno medio de 0.2576428571428571 en los últimos 100 episodios)
# Terminado episodio 221 con retorno 0 en 148 pasos (retorno medio de 0.2576428571428571 en los últimos 100 episodios)
# Terminado episodio 222 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.2674285714285714 en los últimos 100 episodios)
# Terminado episodio 223 con retorno 0.9714285714285714 en 8 pasos (retorno medio de 0.27714285714285714 en los últimos 100 episodios)
# Terminado episodio 224 con retorno 0 en 31 pasos (retorno medio de 0.27714285714285714 en los últimos 100 episodios)
# Terminado episodio 225 con retorno 0 en 15 pasos (retorno medio de 0.27714285714285714 en los últimos 100 episodios)
# Terminado episodio 226 con retorno 0 en 2 pasos (retorno medio de 0.27714285714285714 en los últimos 100 episodios)
# Terminado episodio 227 con retorno 0 en 3 pasos (retorno medio de 0.26778571428571424 en los últimos 100 episodios)
# Terminado episodio 228 con retorno 0 en 6 pasos (retorno medio de 0.2677857142857143 en los últimos 100 episodios)
# Terminado episodio 229 con retorno 0.975 en 7 pasos (retorno medio de 0.26775000000000004 en los últimos 100 episodios)
# Terminado episodio 230 con retorno 0 en 50 pasos (retorno medio de 0.26775 en los últimos 100 episodios)
# Terminado episodio 231 con retorno 0 en 3 pasos (retorno medio de 0.26775 en los últimos 100 episodios)
# Terminado episodio 232 con retorno 0 en 30 pasos (retorno medio de 0.26775000000000004 en los últimos 100 episodios)
# Terminado episodio 233 con retorno 0.8928571428571429 en 30 pasos (retorno medio de 0.2766785714285714 en los últimos 100 episodios)
# Terminado episodio 234 con retorno 0.9535714285714285 en 13 pasos (retorno medio de 0.2862142857142857 en los últimos 100 episodios)
# Terminado episodio 235 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.29607142857142854 en los últimos 100 episodios)
# Terminado episodio 236 con retorno 0 en 13 pasos (retorno medio de 0.29607142857142854 en los últimos 100 episodios)
# Terminado episodio 237 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.3058571428571428 en los últimos 100 episodios)
# Terminado episodio 238 con retorno 0 en 4 pasos (retorno medio de 0.3058571428571429 en los últimos 100 episodios)
# Terminado episodio 239 con retorno 0 en 73 pasos (retorno medio de 0.3058571428571428 en los últimos 100 episodios)
# Terminado episodio 240 con retorno 0.9892857142857143 en 3 pasos (retorno medio de 0.3058214285714286 en los últimos 100 episodios)
# Terminado episodio 241 con retorno 0.975 en 7 pasos (retorno medio de 0.30575 en los últimos 100 episodios)
# Terminado episodio 242 con retorno 0 en 1 pasos (retorno medio de 0.30575 en los últimos 100 episodios)
# Terminado episodio 243 con retorno 0 en 3 pasos (retorno medio de 0.29867857142857146 en los últimos 100 episodios)
# Terminado episodio 244 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.2990714285714286 en los últimos 100 episodios)
# Terminado episodio 245 con retorno 0.9285714285714286 en 20 pasos (retorno medio de 0.30835714285714283 en los últimos 100 episodios)
# Terminado episodio 246 con retorno 0.9892857142857143 en 3 pasos (retorno medio de 0.31825 en los últimos 100 episodios)
# Terminado episodio 247 con retorno 0 en 32 pasos (retorno medio de 0.31825 en los últimos 100 episodios)
# Terminado episodio 248 con retorno 0 en 2 pasos (retorno medio de 0.31825 en los últimos 100 episodios)
# Terminado episodio 249 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.3280357142857143 en los últimos 100 episodios)
# Terminado episodio 250 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.3376071428571429 en los últimos 100 episodios)
# Terminado episodio 251 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.34725 en los últimos 100 episodios)
# Terminado episodio 252 con retorno 0 en 12 pasos (retorno medio de 0.34725 en los últimos 100 episodios)
# Terminado episodio 253 con retorno 0.9892857142857143 en 3 pasos (retorno medio de 0.3474642857142857 en los últimos 100 episodios)
# Terminado episodio 254 con retorno 0 en 3 pasos (retorno medio de 0.33764285714285713 en los últimos 100 episodios)
# Terminado episodio 255 con retorno 0 en 1 pasos (retorno medio de 0.32875 en los últimos 100 episodios)
# Terminado episodio 256 con retorno 0.8428571428571429 en 44 pasos (retorno medio de 0.33717857142857144 en los últimos 100 episodios)
# Terminado episodio 257 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.34682142857142856 en los últimos 100 episodios)
# Terminado episodio 258 con retorno 0 en 5 pasos (retorno medio de 0.33703571428571427 en los últimos 100 episodios)
# Terminado episodio 259 con retorno 0.975 en 7 pasos (retorno medio de 0.3467857142857143 en los últimos 100 episodios)
# Terminado episodio 260 con retorno 0 en 33 pasos (retorno medio de 0.3467857142857143 en los últimos 100 episodios)
# Terminado episodio 261 con retorno 0 en 2 pasos (retorno medio de 0.3467857142857143 en los últimos 100 episodios)
# Terminado episodio 262 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.3564285714285715 en los últimos 100 episodios)
# Terminado episodio 263 con retorno 0 en 25 pasos (retorno medio de 0.3564285714285715 en los últimos 100 episodios)
# Terminado episodio 264 con retorno 0 en 3 pasos (retorno medio de 0.34660714285714284 en los últimos 100 episodios)
# Terminado episodio 265 con retorno 0 en 11 pasos (retorno medio de 0.34660714285714284 en los últimos 100 episodios)
# Terminado episodio 266 con retorno 0 en 7 pasos (retorno medio de 0.34660714285714284 en los últimos 100 episodios)
# Terminado episodio 267 con retorno 0.9035714285714286 en 27 pasos (retorno medio de 0.35564285714285726 en los últimos 100 episodios)
# Terminado episodio 268 con retorno 0 en 10 pasos (retorno medio de 0.35564285714285715 en los últimos 100 episodios)
# Terminado episodio 269 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.36057142857142865 en los últimos 100 episodios)
# Terminado episodio 270 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.3702142857142858 en los últimos 100 episodios)
# Terminado episodio 271 con retorno 0.85 en 42 pasos (retorno medio de 0.39928571428571435 en los últimos 100 episodios)
# Terminado episodio 272 con retorno 0 en 1 pasos (retorno medio de 0.3992857142857143 en los últimos 100 episodios)
# Terminado episodio 273 con retorno 0 en 12 pasos (retorno medio de 0.3893571428571429 en los últimos 100 episodios)
# Terminado episodio 274 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.3992142857142858 en los últimos 100 episodios)
# Terminado episodio 275 con retorno 0 en 2 pasos (retorno medio de 0.3893571428571429 en los últimos 100 episodios)
# Terminado episodio 276 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.3991428571428572 en los últimos 100 episodios)
# Terminado episodio 277 con retorno 0.9214285714285715 en 22 pasos (retorno medio de 0.40835714285714286 en los últimos 100 episodios)
# Terminado episodio 278 con retorno 0 en 1 pasos (retorno medio de 0.3986785714285714 en los últimos 100 episodios)
# Terminado episodio 279 con retorno 0 en 9 pasos (retorno medio de 0.38939285714285715 en los últimos 100 episodios)
# Terminado episodio 280 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.3990000000000001 en los últimos 100 episodios)
# Terminado episodio 281 con retorno 0 en 1 pasos (retorno medio de 0.3990000000000001 en los últimos 100 episodios)
# Terminado episodio 282 con retorno 0 en 1 pasos (retorno medio de 0.38917857142857143 en los últimos 100 episodios)
# Terminado episodio 283 con retorno 0.7357142857142858 en 74 pasos (retorno medio de 0.3965357142857144 en los últimos 100 episodios)
# Terminado episodio 284 con retorno 0 en 14 pasos (retorno medio de 0.3958571428571429 en los últimos 100 episodios)
# Terminado episodio 285 con retorno 0 en 38 pasos (retorno medio de 0.3861785714285715 en los últimos 100 episodios)
# Terminado episodio 286 con retorno 0.9428571428571428 en 16 pasos (retorno medio de 0.3956071428571428 en los últimos 100 episodios)
# Terminado episodio 287 con retorno 0.9928571428571429 en 2 pasos (retorno medio de 0.40553571428571433 en los últimos 100 episodios)
# Terminado episodio 288 con retorno 0 en 3 pasos (retorno medio de 0.40553571428571433 en los últimos 100 episodios)
# Terminado episodio 289 con retorno 0 en 3 pasos (retorno medio de 0.39578571428571424 en los últimos 100 episodios)
# Terminado episodio 290 con retorno 0.975 en 7 pasos (retorno medio de 0.3967142857142857 en los últimos 100 episodios)
# Terminado episodio 291 con retorno 0 en 2 pasos (retorno medio de 0.3914642857142857 en los últimos 100 episodios)
# Terminado episodio 292 con retorno 0 en 3 pasos (retorno medio de 0.39082142857142865 en los últimos 100 episodios)
# Terminado episodio 293 con retorno 0.9714285714285714 en 8 pasos (retorno medio de 0.40053571428571433 en los últimos 100 episodios)
# Terminado episodio 294 con retorno 0 en 4 pasos (retorno medio de 0.39142857142857146 en los últimos 100 episodios)
# Terminado episodio 295 con retorno 0 en 2 pasos (retorno medio de 0.3914285714285714 en los últimos 100 episodios)
# Terminado episodio 296 con retorno 0 en 10 pasos (retorno medio de 0.3914285714285714 en los últimos 100 episodios)
# Terminado episodio 297 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.40121428571428575 en los últimos 100 episodios)
# Terminado episodio 298 con retorno 0 en 10 pasos (retorno medio de 0.40121428571428575 en los últimos 100 episodios)
# Terminado episodio 299 con retorno 0 en 2 pasos (retorno medio de 0.40121428571428575 en los últimos 100 episodios)
# Terminado episodio 300 con retorno 0 en 4 pasos (retorno medio de 0.3914642857142857 en los últimos 100 episodios)
# Terminado episodio 301 con retorno 0 en 23 pasos (retorno medio de 0.38246428571428576 en los últimos 100 episodios)
# Terminado episodio 302 con retorno 0 en 1 pasos (retorno medio de 0.38246428571428576 en los últimos 100 episodios)
# Terminado episodio 303 con retorno 0 en 7 pasos (retorno medio de 0.38246428571428576 en los últimos 100 episodios)
# Terminado episodio 304 con retorno 0 en 135 pasos (retorno medio de 0.38246428571428576 en los últimos 100 episodios)
# Terminado episodio 305 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.3843214285714286 en los últimos 100 episodios)
# Terminado episodio 306 con retorno 0 en 1 pasos (retorno medio de 0.3745714285714286 en los últimos 100 episodios)
# Terminado episodio 307 con retorno 0.9964285714285714 en 1 pasos (retorno medio de 0.38453571428571437 en los últimos 100 episodios)
# Terminado episodio 308 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.3943928571428572 en los últimos 100 episodios)
# Terminado episodio 309 con retorno 0 en 11 pasos (retorno medio de 0.38992857142857146 en los últimos 100 episodios)
# Terminado episodio 310 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.397 en los últimos 100 episodios)
# Terminado episodio 311 con retorno 0 en 8 pasos (retorno medio de 0.397 en los últimos 100 episodios)
# Terminado episodio 312 con retorno 0 en 22 pasos (retorno medio de 0.397 en los últimos 100 episodios)
# Terminado episodio 313 con retorno 0 en 12 pasos (retorno medio de 0.397 en los últimos 100 episodios)
# Terminado episodio 314 con retorno 0 en 1 pasos (retorno medio de 0.38707142857142857 en los últimos 100 episodios)
# Terminado episodio 315 con retorno 0 en 1 pasos (retorno medio de 0.3811785714285714 en los últimos 100 episodios)
# Terminado episodio 316 con retorno 0 en 4 pasos (retorno medio de 0.3727500000000001 en los últimos 100 episodios)
# Terminado episodio 317 con retorno 0 en 2 pasos (retorno medio de 0.3632142857142857 en los últimos 100 episodios)
# Terminado episodio 318 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.3728214285714286 en los últimos 100 episodios)
# Terminado episodio 319 con retorno 0.9714285714285714 en 8 pasos (retorno medio de 0.38253571428571426 en los últimos 100 episodios)
# Terminado episodio 320 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.3922142857142857 en los últimos 100 episodios)
# Terminado episodio 321 con retorno 0 en 37 pasos (retorno medio de 0.3922142857142857 en los últimos 100 episodios)
# Terminado episodio 322 con retorno 0 en 25 pasos (retorno medio de 0.3824285714285714 en los últimos 100 episodios)
# Terminado episodio 323 con retorno 0.9928571428571429 en 2 pasos (retorno medio de 0.3826428571428571 en los últimos 100 episodios)
# Terminado episodio 324 con retorno 0 en 5 pasos (retorno medio de 0.3826428571428571 en los últimos 100 episodios)
# Terminado episodio 325 con retorno 0 en 26 pasos (retorno medio de 0.3826428571428571 en los últimos 100 episodios)
# Terminado episodio 326 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.3925 en los últimos 100 episodios)
# Terminado episodio 327 con retorno 0.95 en 14 pasos (retorno medio de 0.4020000000000001 en los últimos 100 episodios)
# Terminado episodio 328 con retorno 0 en 30 pasos (retorno medio de 0.4020000000000001 en los últimos 100 episodios)
# Terminado episodio 329 con retorno 0 en 13 pasos (retorno medio de 0.39225 en los últimos 100 episodios)
# Terminado episodio 330 con retorno 0 en 15 pasos (retorno medio de 0.3922500000000001 en los últimos 100 episodios)
# Terminado episodio 331 con retorno 0.9714285714285714 en 8 pasos (retorno medio de 0.4019642857142858 en los últimos 100 episodios)
# Terminado episodio 332 con retorno 0 en 3 pasos (retorno medio de 0.4019642857142858 en los últimos 100 episodios)
# Terminado episodio 333 con retorno 0 en 2 pasos (retorno medio de 0.3930357142857142 en los últimos 100 episodios)
# Terminado episodio 334 con retorno 0 en 2 pasos (retorno medio de 0.3835 en los últimos 100 episodios)
# Terminado episodio 335 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.38325000000000004 en los últimos 100 episodios)
# Terminado episodio 336 con retorno 0 en 16 pasos (retorno medio de 0.38325000000000004 en los últimos 100 episodios)
# Terminado episodio 337 con retorno 0 en 3 pasos (retorno medio de 0.37346428571428575 en los últimos 100 episodios)
# Terminado episodio 338 con retorno 0 en 14 pasos (retorno medio de 0.37346428571428575 en los últimos 100 episodios)
# Terminado episodio 339 con retorno 0 en 8 pasos (retorno medio de 0.37346428571428575 en los últimos 100 episodios)
# Terminado episodio 340 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.3731785714285715 en los últimos 100 episodios)
# Terminado episodio 341 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.37307142857142866 en los últimos 100 episodios)
# Terminado episodio 342 con retorno 0 en 1 pasos (retorno medio de 0.37307142857142855 en los últimos 100 episodios)
# Terminado episodio 343 con retorno 0 en 2 pasos (retorno medio de 0.37307142857142866 en los últimos 100 episodios)
# Terminado episodio 344 con retorno 0 en 3 pasos (retorno medio de 0.36321428571428577 en los últimos 100 episodios)
# Terminado episodio 345 con retorno 0 en 10 pasos (retorno medio de 0.3539285714285715 en los últimos 100 episodios)
# Terminado episodio 346 con retorno 0.9714285714285714 en 8 pasos (retorno medio de 0.35375 en los últimos 100 episodios)
# Terminado episodio 347 con retorno 0.975 en 7 pasos (retorno medio de 0.3635 en los últimos 100 episodios)
# Terminado episodio 348 con retorno 0.9428571428571428 en 16 pasos (retorno medio de 0.3729285714285714 en los últimos 100 episodios)
# Terminado episodio 349 con retorno 0 en 24 pasos (retorno medio de 0.3631428571428571 en los últimos 100 episodios)
# Terminado episodio 350 con retorno 0 en 3 pasos (retorno medio de 0.3535714285714286 en los últimos 100 episodios)
# Terminado episodio 351 con retorno 0 en 6 pasos (retorno medio de 0.3439285714285715 en los últimos 100 episodios)
# Terminado episodio 352 con retorno 0.975 en 7 pasos (retorno medio de 0.3536785714285714 en los últimos 100 episodios)
# Terminado episodio 353 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.35364285714285715 en los últimos 100 episodios)
# Terminado episodio 354 con retorno 0.975 en 7 pasos (retorno medio de 0.36339285714285713 en los últimos 100 episodios)
# Terminado episodio 355 con retorno 0 en 3 pasos (retorno medio de 0.36339285714285713 en los últimos 100 episodios)
# Terminado episodio 356 con retorno 0 en 2 pasos (retorno medio de 0.35496428571428573 en los últimos 100 episodios)
# Terminado episodio 357 con retorno 0 en 1 pasos (retorno medio de 0.34532142857142856 en los últimos 100 episodios)
# Terminado episodio 358 con retorno 0 en 6 pasos (retorno medio de 0.34532142857142856 en los últimos 100 episodios)
# Terminado episodio 359 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.3452142857142857 en los últimos 100 episodios)
# Terminado episodio 360 con retorno 0.975 en 7 pasos (retorno medio de 0.35496428571428573 en los últimos 100 episodios)
# Terminado episodio 361 con retorno 0 en 6 pasos (retorno medio de 0.35496428571428573 en los últimos 100 episodios)
# Terminado episodio 362 con retorno 0 en 1 pasos (retorno medio de 0.34532142857142856 en los últimos 100 episodios)
# Terminado episodio 363 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.35517857142857145 en los últimos 100 episodios)
# Terminado episodio 364 con retorno 0 en 8 pasos (retorno medio de 0.35517857142857145 en los últimos 100 episodios)
# Terminado episodio 365 con retorno 0 en 12 pasos (retorno medio de 0.35517857142857145 en los últimos 100 episodios)
# Terminado episodio 366 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.36475 en los últimos 100 episodios)
# Terminado episodio 367 con retorno 0 en 11 pasos (retorno medio de 0.3557142857142857 en los últimos 100 episodios)
# Terminado episodio 368 con retorno 0 en 7 pasos (retorno medio de 0.3557142857142857 en los últimos 100 episodios)
# Terminado episodio 369 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.35564285714285715 en los últimos 100 episodios)
# Terminado episodio 370 con retorno 0 en 7 pasos (retorno medio de 0.3459999999999999 en los últimos 100 episodios)
# Terminado episodio 371 con retorno 0 en 13 pasos (retorno medio de 0.3375 en los últimos 100 episodios)
# Terminado episodio 372 con retorno 0 en 5 pasos (retorno medio de 0.3375 en los últimos 100 episodios)
# Terminado episodio 373 con retorno 0 en 2 pasos (retorno medio de 0.3375 en los últimos 100 episodios)
# Terminado episodio 374 con retorno 0 en 2 pasos (retorno medio de 0.3276428571428571 en los últimos 100 episodios)
# Terminado episodio 375 con retorno 0.9892857142857143 en 3 pasos (retorno medio de 0.3375357142857143 en los últimos 100 episodios)
# Terminado episodio 376 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.33732142857142855 en los últimos 100 episodios)
# Terminado episodio 377 con retorno 0 en 22 pasos (retorno medio de 0.3281071428571428 en los últimos 100 episodios)
# Terminado episodio 378 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.33778571428571424 en los últimos 100 episodios)
# Terminado episodio 379 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.34757142857142853 en los últimos 100 episodios)
# Terminado episodio 380 con retorno 0 en 4 pasos (retorno medio de 0.3379642857142857 en los últimos 100 episodios)
# Terminado episodio 381 con retorno 0 en 9 pasos (retorno medio de 0.3379642857142857 en los últimos 100 episodios)
# Terminado episodio 382 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.3475714285714286 en los últimos 100 episodios)
# Terminado episodio 383 con retorno 0.9892857142857143 en 3 pasos (retorno medio de 0.35010714285714284 en los últimos 100 episodios)
# Terminado episodio 384 con retorno 0 en 9 pasos (retorno medio de 0.35010714285714284 en los últimos 100 episodios)
# Terminado episodio 385 con retorno 0 en 2 pasos (retorno medio de 0.35010714285714284 en los últimos 100 episodios)
# Terminado episodio 386 con retorno 0.9214285714285715 en 22 pasos (retorno medio de 0.3498928571428571 en los últimos 100 episodios)
# Terminado episodio 387 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.34957142857142864 en los últimos 100 episodios)
# Terminado episodio 388 con retorno 0 en 9 pasos (retorno medio de 0.34957142857142864 en los últimos 100 episodios)
# Terminado episodio 389 con retorno 0 en 2 pasos (retorno medio de 0.34957142857142864 en los últimos 100 episodios)
# Terminado episodio 390 con retorno 0 en 2 pasos (retorno medio de 0.3398214285714286 en los últimos 100 episodios)
# Terminado episodio 391 con retorno 0 en 9 pasos (retorno medio de 0.3398214285714286 en los últimos 100 episodios)
# Terminado episodio 392 con retorno 0.9571428571428572 en 12 pasos (retorno medio de 0.3493928571428571 en los últimos 100 episodios)
# Terminado episodio 393 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.3495357142857143 en los últimos 100 episodios)
# Terminado episodio 394 con retorno 0 en 3 pasos (retorno medio de 0.3495357142857143 en los últimos 100 episodios)
# Terminado episodio 395 con retorno 0 en 2 pasos (retorno medio de 0.3495357142857143 en los últimos 100 episodios)
# Terminado episodio 396 con retorno 0 en 3 pasos (retorno medio de 0.3495357142857143 en los últimos 100 episodios)
# Terminado episodio 397 con retorno 0 en 2 pasos (retorno medio de 0.33974999999999994 en los últimos 100 episodios)
# Terminado episodio 398 con retorno 0 en 13 pasos (retorno medio de 0.33974999999999994 en los últimos 100 episodios)
# Terminado episodio 399 con retorno 0 en 3 pasos (retorno medio de 0.33975 en los últimos 100 episodios)
# Terminado episodio 400 con retorno 0.95 en 14 pasos (retorno medio de 0.34925000000000006 en los últimos 100 episodios)
# Terminado episodio 401 con retorno 0 en 2 pasos (retorno medio de 0.34924999999999995 en los últimos 100 episodios)
# Terminado episodio 402 con retorno 0 en 4 pasos (retorno medio de 0.34924999999999995 en los últimos 100 episodios)
# Terminado episodio 403 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.3589285714285715 en los últimos 100 episodios)
# Terminado episodio 404 con retorno 0 en 11 pasos (retorno medio de 0.3589285714285714 en los últimos 100 episodios)
# Terminado episodio 405 con retorno 0 en 2 pasos (retorno medio de 0.3490714285714286 en los últimos 100 episodios)
# Terminado episodio 406 con retorno 0 en 1 pasos (retorno medio de 0.3490714285714286 en los últimos 100 episodios)
# Terminado episodio 407 con retorno 0 en 4 pasos (retorno medio de 0.33910714285714283 en los últimos 100 episodios)
# Terminado episodio 408 con retorno 0 en 12 pasos (retorno medio de 0.32925 en los últimos 100 episodios)
# Terminado episodio 409 con retorno 0.9821428571428571 en 5 pasos (retorno medio de 0.3390714285714285 en los últimos 100 episodios)
# Terminado episodio 410 con retorno 0 en 1 pasos (retorno medio de 0.3293928571428571 en los últimos 100 episodios)
# Terminado episodio 411 con retorno 0 en 12 pasos (retorno medio de 0.3293928571428571 en los últimos 100 episodios)
# Terminado episodio 412 con retorno 0 en 15 pasos (retorno medio de 0.3293928571428571 en los últimos 100 episodios)
# Terminado episodio 413 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.33903571428571433 en los últimos 100 episodios)
# Terminado episodio 414 con retorno 0 en 9 pasos (retorno medio de 0.33903571428571433 en los últimos 100 episodios)
# Terminado episodio 415 con retorno 0 en 4 pasos (retorno medio de 0.33903571428571433 en los últimos 100 episodios)
# Terminado episodio 416 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.3486428571428572 en los últimos 100 episodios)
# Terminado episodio 417 con retorno 0 en 1 pasos (retorno medio de 0.34864285714285714 en los últimos 100 episodios)
# Terminado episodio 418 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.34867857142857145 en los últimos 100 episodios)
# Terminado episodio 419 con retorno 0 en 3 pasos (retorno medio de 0.3389642857142857 en los últimos 100 episodios)
# Terminado episodio 420 con retorno 0 en 1 pasos (retorno medio de 0.32928571428571424 en los últimos 100 episodios)
# Terminado episodio 421 con retorno 0 en 6 pasos (retorno medio de 0.3292857142857143 en los últimos 100 episodios)
# Terminado episodio 422 con retorno 0 en 2 pasos (retorno medio de 0.3292857142857143 en los últimos 100 episodios)
# Terminado episodio 423 con retorno 0 en 5 pasos (retorno medio de 0.31935714285714284 en los últimos 100 episodios)
# Terminado episodio 424 con retorno 0 en 8 pasos (retorno medio de 0.3193571428571429 en los últimos 100 episodios)
# Terminado episodio 425 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.32899999999999996 en los últimos 100 episodios)
# Terminado episodio 426 con retorno 0.9928571428571429 en 2 pasos (retorno medio de 0.32907142857142857 en los últimos 100 episodios)
# Terminado episodio 427 con retorno 0 en 10 pasos (retorno medio de 0.31957142857142856 en los últimos 100 episodios)
# Terminado episodio 428 con retorno 0 en 5 pasos (retorno medio de 0.3195714285714286 en los últimos 100 episodios)
# Terminado episodio 429 con retorno 0 en 8 pasos (retorno medio de 0.3195714285714286 en los últimos 100 episodios)
# Terminado episodio 430 con retorno 0 en 2 pasos (retorno medio de 0.31957142857142856 en los últimos 100 episodios)
# Terminado episodio 431 con retorno 0 en 11 pasos (retorno medio de 0.30985714285714283 en los últimos 100 episodios)
# Terminado episodio 432 con retorno 0 en 9 pasos (retorno medio de 0.3098571428571429 en los últimos 100 episodios)
# Terminado episodio 433 con retorno 0 en 13 pasos (retorno medio de 0.3098571428571429 en los últimos 100 episodios)
# Terminado episodio 434 con retorno 0 en 14 pasos (retorno medio de 0.30985714285714283 en los últimos 100 episodios)
# Terminado episodio 435 con retorno 0.975 en 7 pasos (retorno medio de 0.31 en los últimos 100 episodios)
# Terminado episodio 436 con retorno 0 en 15 pasos (retorno medio de 0.31 en los últimos 100 episodios)
# Terminado episodio 437 con retorno 0 en 6 pasos (retorno medio de 0.31 en los últimos 100 episodios)
# Terminado episodio 438 con retorno 0 en 4 pasos (retorno medio de 0.31 en los últimos 100 episodios)
# Terminado episodio 439 con retorno 0 en 4 pasos (retorno medio de 0.31 en los últimos 100 episodios)
# Terminado episodio 440 con retorno 0 en 17 pasos (retorno medio de 0.30039285714285713 en los últimos 100 episodios)
# Terminado episodio 441 con retorno 0 en 1 pasos (retorno medio de 0.29075 en los últimos 100 episodios)
# Terminado episodio 442 con retorno 0 en 2 pasos (retorno medio de 0.29074999999999995 en los últimos 100 episodios)
# Terminado episodio 443 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.3003571428571428 en los últimos 100 episodios)
# Terminado episodio 444 con retorno 0 en 11 pasos (retorno medio de 0.3003571428571428 en los últimos 100 episodios)
# Terminado episodio 445 con retorno 0 en 7 pasos (retorno medio de 0.3003571428571428 en los últimos 100 episodios)
# Terminado episodio 446 con retorno 0 en 23 pasos (retorno medio de 0.29064285714285715 en los últimos 100 episodios)
# Terminado episodio 447 con retorno 0.9964285714285714 en 1 pasos (retorno medio de 0.2908571428571428 en los últimos 100 episodios)
# Terminado episodio 448 con retorno 0 en 6 pasos (retorno medio de 0.28142857142857136 en los últimos 100 episodios)
# Terminado episodio 449 con retorno 0 en 4 pasos (retorno medio de 0.28142857142857136 en los últimos 100 episodios)
# Terminado episodio 450 con retorno 0 en 9 pasos (retorno medio de 0.28142857142857136 en los últimos 100 episodios)
# Terminado episodio 451 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.2910714285714286 en los últimos 100 episodios)
# Terminado episodio 452 con retorno 0 en 3 pasos (retorno medio de 0.28132142857142856 en los últimos 100 episodios)
# Terminado episodio 453 con retorno 0 en 5 pasos (retorno medio de 0.2714642857142857 en los últimos 100 episodios)
# Terminado episodio 454 con retorno 0.95 en 14 pasos (retorno medio de 0.27121428571428574 en los últimos 100 episodios)
# Terminado episodio 455 con retorno 0.975 en 7 pasos (retorno medio de 0.2809642857142858 en los últimos 100 episodios)
# Terminado episodio 456 con retorno 0 en 2 pasos (retorno medio de 0.2809642857142857 en los últimos 100 episodios)
# Terminado episodio 457 con retorno 0.9928571428571429 en 2 pasos (retorno medio de 0.2908928571428572 en los últimos 100 episodios)
# Terminado episodio 458 con retorno 0 en 16 pasos (retorno medio de 0.2908928571428572 en los últimos 100 episodios)
# Terminado episodio 459 con retorno 0 en 10 pasos (retorno medio de 0.28125000000000006 en los últimos 100 episodios)
# Terminado episodio 460 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.28135714285714286 en los últimos 100 episodios)
# Terminado episodio 461 con retorno 0 en 7 pasos (retorno medio de 0.28135714285714286 en los últimos 100 episodios)
# Terminado episodio 462 con retorno 0.975 en 7 pasos (retorno medio de 0.2911071428571429 en los últimos 100 episodios)
# Terminado episodio 463 con retorno 0 en 1 pasos (retorno medio de 0.28125 en los últimos 100 episodios)
# Terminado episodio 464 con retorno 0.9928571428571429 en 2 pasos (retorno medio de 0.29117857142857145 en los últimos 100 episodios)
# Terminado episodio 465 con retorno 0 en 2 pasos (retorno medio de 0.29117857142857145 en los últimos 100 episodios)
# Terminado episodio 466 con retorno 0 en 1 pasos (retorno medio de 0.28160714285714283 en los últimos 100 episodios)
# Terminado episodio 467 con retorno 0 en 8 pasos (retorno medio de 0.28160714285714283 en los últimos 100 episodios)
# Terminado episodio 468 con retorno 0 en 4 pasos (retorno medio de 0.28160714285714283 en los últimos 100 episodios)
# Terminado episodio 469 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.28167857142857144 en los últimos 100 episodios)
# Terminado episodio 470 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.29135714285714287 en los últimos 100 episodios)
# Terminado episodio 471 con retorno 0.9678571428571429 en 9 pasos (retorno medio de 0.3010357142857143 en los últimos 100 episodios)
# Terminado episodio 472 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.31089285714285714 en los últimos 100 episodios)
# Terminado episodio 473 con retorno 0 en 3 pasos (retorno medio de 0.31089285714285714 en los últimos 100 episodios)
# Terminado episodio 474 con retorno 0 en 7 pasos (retorno medio de 0.31089285714285714 en los últimos 100 episodios)
# Terminado episodio 475 con retorno 0 en 13 pasos (retorno medio de 0.301 en los últimos 100 episodios)
# Terminado episodio 476 con retorno 0 en 7 pasos (retorno medio de 0.2914285714285715 en los últimos 100 episodios)
# Terminado episodio 477 con retorno 0 en 3 pasos (retorno medio de 0.2914285714285715 en los últimos 100 episodios)
# Terminado episodio 478 con retorno 0 en 10 pasos (retorno medio de 0.28175 en los últimos 100 episodios)
# Terminado episodio 479 con retorno 0 en 10 pasos (retorno medio de 0.2719642857142857 en los últimos 100 episodios)
# Terminado episodio 480 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.2815714285714286 en los últimos 100 episodios)
# Terminado episodio 481 con retorno 0.9892857142857143 en 3 pasos (retorno medio de 0.29146428571428573 en los últimos 100 episodios)
# Terminado episodio 482 con retorno 0 en 1 pasos (retorno medio de 0.28185714285714286 en los últimos 100 episodios)
# Terminado episodio 483 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.28174999999999994 en los últimos 100 episodios)
# Terminado episodio 484 con retorno 0.9071428571428571 en 26 pasos (retorno medio de 0.29082142857142856 en los últimos 100 episodios)
# Terminado episodio 485 con retorno 0 en 10 pasos (retorno medio de 0.29082142857142856 en los últimos 100 episodios)
# Terminado episodio 486 con retorno 0 en 6 pasos (retorno medio de 0.2816071428571429 en los últimos 100 episodios)
# Terminado episodio 487 con retorno 0.9857142857142858 en 4 pasos (retorno medio de 0.2818571428571428 en los últimos 100 episodios)
# Terminado episodio 488 con retorno 0 en 9 pasos (retorno medio de 0.2818571428571429 en los últimos 100 episodios)
# Terminado episodio 489 con retorno 0.9785714285714285 en 6 pasos (retorno medio de 0.2916428571428572 en los últimos 100 episodios)
# Terminado episodio 490 con retorno 0.9607142857142857 en 11 pasos (retorno medio de 0.30125 en los últimos 100 episodios)
# Terminado episodio 491 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.31089285714285714 en los últimos 100 episodios)
# Terminado episodio 492 con retorno 0.9642857142857143 en 10 pasos (retorno medio de 0.3109642857142857 en los últimos 100 episodios)
# Terminado episodio 493 con retorno 0 en 11 pasos (retorno medio de 0.30110714285714285 en los últimos 100 episodios)
# Terminado episodio 494 con retorno 0 en 15 pasos (retorno medio de 0.30110714285714285 en los últimos 100 episodios)
# Terminado episodio 495 con retorno 0.9464285714285714 en 15 pasos (retorno medio de 0.3105714285714286 en los últimos 100 episodios)
# Terminado episodio 496 con retorno 0 en 13 pasos (retorno medio de 0.31057142857142855 en los últimos 100 episodios)
# Terminado episodio 497 con retorno 0 en 2 pasos (retorno medio de 0.3105714285714286 en los últimos 100 episodios)
# Terminado episodio 498 con retorno 0 en 21 pasos (retorno medio de 0.3105714285714286 en los últimos 100 episodios)
# Terminado episodio 499 con retorno 0 en 4 pasos (retorno medio de 0.31057142857142855 en los últimos 100 episodios)
# Terminado episodio 500 con retorno 0 en 6 pasos (retorno medio de 0.30107142857142855 en los últimos 100 episodios)
# ⮕⮕🟧🟧🟧⮕🟥
# ⬆⮕🟧🟧🟧⮕⬆
# ⬆⬅⬇⬅⮕⬆⬇
# ⬆⬇⮕⮕⮕⬆⮕
# ⬆⮕⮕⮕⮕⬆⬅

# %% [markdown]
# ### Q-learning
# El algoritmo Q-learning es de los más populares dentro del Aprendizaje por Refuerzo. Es muy similar a SARSA, pero tiene una importante diferencia: es *off-policy*. Si SARSA hacía las actualizaciones de $Q(S_t,A_t)$ en función de la acción $A_{t+1}$ que tomaba, Q-learning va a hacer dichas actualizaciones independientemente de la acción que finalmente tome. Por tanto, estará utilizando una política para explorar pero otra para actualizar. En concreto, Q-learning actualiza según esta fórmula:
#
# $$Q(S_t,A_t) \leftarrow Q(S_t,A_t) + \alpha [R_{t+1} + \gamma \max_aQ(S_{t+1},a) - Q(S_t,A_t)]$$
#
# Q-learning no actualiza en función de la acción que va a tomar, sino en función de la mejor acción posible. El algoritmo completo aparece descrito a continuación.
#
# ![Q-learning](https://github.com/eirasf/GCED-AA3/blob/main/lab6/img/q-learning.png?raw=true)
#
# Implementemos Q-learning mostrando los mismos mensajes a cada paso que mostrábamos con SARSA. Mantén las recompensas negativas para cuando el agente caiga en la lava.

# %%
# TODO - Implementa q_learning
#  Utiliza el mismo código que para sarsa pero cambiando la actualización
#  Recuerda mantener las recompensas negativas para cuando el agente caiga en la lava y mostrar los mensajes
def q_learning(num_episodios:int = 500, ALPHA:float = 0.1, EPSILON:float = 0.25) -> np.ndarray:
    ...

q_valores_q = q_learning()
dibuja_politica(q_valores_q)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 8
#       5     ...
#       7 q_valores_q = q_learning()
# ----> 8 dibuja_politica(q_valores_q)
#
# Cell In[8], line 19, in dibuja_politica(q_valores)
#      17 def dibuja_politica(q_valores:np.ndarray) -> None:
#      18     # Recorre las filas del tablero...
# ---> 19     for i in range(q_valores.shape[1]):
#      20         # ... componiendo una línea por fila...
#      21         linea = ''
#      22         for j in range(q_valores.shape[0]): # Recorre las columnas
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# ### Comparativa SARSA vs Q-Learning
# Compara los resultados obtenidos por ambos algoritmos. Deberías observar lo siguiente:
#   - La política obtenida por SARSA es más conservadora (no quiere estar cerca de la lava), mientras que la de Q-learning es más optimista (no le importa estar cerca de la lava; confía en su política).
#   - Por tanto, los episodios de Q-learning son más cortos que los de SARSA.
#   - Sin embargo, al seguir una política $\epsilon$-greedy, estar en una casilla contigua a la lava desemboca en una recompensa de -1 (caer a la lava) un $\frac{\epsilon}{4}$ de las veces, por lo que el retorno medio de Q-learning es más bajo.
#
# Completa la siguiente celda para comprobarlo.

# %%
def comprueba_politica_derivada(q_values:np.ndarray, epsilon:float) -> None:
    env.reset()
    # TODO - Escribe un bucle que simule un episodio completo siguiendo una política COMPLETAMENTE GREEDY respecto a q_values
    # y muestra su duración y su retorno
    ...
    print(f'La política greedy hace un episodio de {contador} pasos con un retorno de {retorno}')

    env.reset()
    # TODO - Escribe otro bucle que simule 500 episodios siguiendo una política epsilon-greedy respecto a q_values
    # y muestra su duración media y su retorno medio
    ...
    print(f'La política greedy hace episodios de {np.mean(duraciones)} pasos de media con un retorno de {np.mean(retornos)} de media')

print('SARSA')
comprueba_politica_derivada(q_valores_sarsa_con_lava_negativa, 0.25)
dibuja_politica(q_valores_sarsa_con_lava_negativa)
print('\nQ-LEARNING')
comprueba_politica_derivada(q_valores_q, 0.25)
dibuja_politica(q_valores_q)
