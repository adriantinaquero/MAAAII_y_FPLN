# %% [markdown]
# ## PRÁCTICA 2: Aprendizaje Semi-supervisado y en Una Clase

# %% [markdown]
# ##### Trabajaremos con el conjunto de datos CIFAR-100 (50.000 instancias para entrenamiento y 10.000 para test), en el cual eliminaremos el 80% de sus etiquetas y realizaremos las siguientes particiones:
#
# #####    40.000 instancias de entrenamiento no etiquetadas
# #####    10.000 instancias de entrenamiento etiquetadas
# #####    10.000 instancias de test etiquetadas

# %% [markdown]
# ### Cargar librerías y dataset

# %%
import tensorflow as tf
import numpy as np

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar100.load_data()
# Out:
# 2026-04-10 22:46:51.684132: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-10 22:46:52.641125: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-10 22:47:36.169389: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# #### Preprocesado de los datos

# %%
# convertimos de uint8 a float32 y normalizamos en rango [0, 1]
x_train = x_train.reshape(-1, 32, 32, 3).astype("float32") / 255.0
x_test = x_test.reshape(-1, 32, 32, 3).astype("float32") / 255.0

# restamos media y dividimos entre desviación típica para estandarizar los datos
mean = np.mean(x_train, axis=(0, 1, 2))    # [media_canalR, media_canalG, media_canalB]
std = np.std(x_train, axis=(0, 1, 2))

x_train = (x_train - mean) / std
x_test = (x_test - mean) / std

# No es necesario aplicar PCA, ya que sería redundante puesto que los autoencoders ya se encargan de hacer una
# reducción de dimensionalidad.

# %% [markdown]
# #### Dividimos datos no etiquetados

# %%
labeled_data = 0.2 # Vamos a usar el etiquetado de sólo el 20% de los datos
np.random.seed(42)

indexes = np.arange(len(x_train))
np.random.shuffle(indexes)
ntrain_data = int(labeled_data*len(x_train))
unlabeled_train = x_train[indexes[ntrain_data:]]
x_train = x_train[indexes[:ntrain_data]]
y_train = y_train[indexes[:ntrain_data]]

# %%
print(x_train.shape)
print(unlabeled_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (10000, 32, 32, 3)
# (40000, 32, 32, 3)
# (10000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %% [markdown]
# #### 1. Entrena un modelo, creado sobre TensorFlow, haciendo uso únicamente de las instancias etiquetadas de entrenamiento. Dicho modelo debe de tener al menos cuatro capas densas y/o convolucionales.

# %%
miCNN = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(64, (3, 3), activation="relu", padding='same', input_shape=(32, 32, 3)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Conv2D(64, (3, 3), activation="relu", padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Dropout(0.2),

        tf.keras.layers.Conv2D(128, (3, 3), activation="relu", padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Conv2D(128, (3, 3), activation="relu", padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Dropout(0.3),

        tf.keras.layers.Conv2D(256, (3, 3), activation="relu", padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Dropout(0.4),

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation="relu"),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(100, activation="softmax")
    ])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

miCNN.compile(
            loss="sparse_categorical_crossentropy",
            optimizer=optimizer,
            metrics=["accuracy"]
        )

miCNN.fit(x_train, y_train, epochs=50, batch_size=64, verbose=1)

_, test_acc = miCNN.evaluate(x_test, y_test, verbose=2)

print("Test accuracy: ", test_acc)
# Out:
# Epoch 1/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 15s 40ms/step - accuracy: 0.0586 - loss: 4.7633
# Epoch 2/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.1182 - loss: 4.0299
# Epoch 3/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.1686 - loss: 3.6099
# Epoch 4/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.2223 - loss: 3.2458
# Epoch 5/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.2740 - loss: 2.9433
# Epoch 6/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.3124 - loss: 2.7304
# Epoch 7/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.3640 - loss: 2.4619
# Epoch 8/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.4075 - loss: 2.2521
# Epoch 9/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.4406 - loss: 2.1150
# Epoch 10/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.4780 - loss: 1.9121
# Epoch 11/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5266 - loss: 1.7267
# Epoch 12/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5578 - loss: 1.5948
# Epoch 13/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5890 - loss: 1.4660
# Epoch 14/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6233 - loss: 1.3308
# Epoch 15/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6510 - loss: 1.2183
# Epoch 16/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6720 - loss: 1.1092
# Epoch 17/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7027 - loss: 1.0065
# Epoch 18/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7106 - loss: 0.9689
# Epoch 19/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.7411 - loss: 0.8659
# Epoch 20/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7678 - loss: 0.7720
# Epoch 21/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7818 - loss: 0.7294
# Epoch 22/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.7887 - loss: 0.6966
# Epoch 23/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7957 - loss: 0.6504
# Epoch 24/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8088 - loss: 0.6062
# Epoch 25/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8189 - loss: 0.5815
# Epoch 26/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8313 - loss: 0.5443
# Epoch 27/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8472 - loss: 0.4895
# Epoch 28/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8495 - loss: 0.4798
# Epoch 29/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8536 - loss: 0.4723
# Epoch 30/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8561 - loss: 0.4605
# Epoch 31/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8629 - loss: 0.4312
# Epoch 32/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8730 - loss: 0.3978
# Epoch 33/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8799 - loss: 0.3804
# Epoch 34/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8759 - loss: 0.3942
# Epoch 35/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8716 - loss: 0.3961
# Epoch 36/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8791 - loss: 0.3760
# Epoch 37/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8885 - loss: 0.3542
# Epoch 38/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8816 - loss: 0.3625
# Epoch 39/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8880 - loss: 0.3448
# Epoch 40/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8964 - loss: 0.3186
# Epoch 41/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8919 - loss: 0.3355
# Epoch 42/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8933 - loss: 0.3287
# Epoch 43/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9045 - loss: 0.3029
# Epoch 44/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9072 - loss: 0.2908
# Epoch 45/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9015 - loss: 0.3080
# Epoch 46/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9108 - loss: 0.2789
# Epoch 47/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9108 - loss: 0.2853
# Epoch 48/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9064 - loss: 0.2806
# Epoch 49/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9095 - loss: 0.2841
# Epoch 50/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9108 - loss: 0.2774
# 313/313 - 2s - 8ms/step - accuracy: 0.4148 - loss: 3.2197
# Test accuracy:  0.4147999882698059

# %% [markdown]
# #### Responde las siguientes preguntas:
# ####    a. ¿Qué red has escogido? ¿Por qué? ¿Cómo la has entrenado?
# ####    b. ¿Cuál es el rendimiento del modelo en entrenamiento? ¿Y en prueba?
# ####    c. ¿Qué conclusiones sacas de los resultados detallados en el punto anterior?

# %% [markdown]
# #### 2. Entrena el mismo modelo, incorporando las instancias no etiquetadas de entrenamiento mediante la técnica de auto-aprendizaje. Opcionalmente, se ponderará cada instancia de entrada en función de su calidad (o certeza).

# %%
def miCNN_func():
    miCNN = tf.keras.models.Sequential([
            tf.keras.layers.Conv2D(64, (3, 3), activation="relu", padding='same', input_shape=(32, 32, 3)),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Conv2D(64, (3, 3), activation="relu", padding='same'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
            tf.keras.layers.Dropout(0.2),

            tf.keras.layers.Conv2D(128, (3, 3), activation="relu", padding='same'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Conv2D(128, (3, 3), activation="relu", padding='same'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
            tf.keras.layers.Dropout(0.3),

            tf.keras.layers.Conv2D(256, (3, 3), activation="relu", padding='same'),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
            tf.keras.layers.Dropout(0.4),

            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(512, activation="relu"),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(100, activation="softmax")
        ])

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

    miCNN.compile(
                loss="sparse_categorical_crossentropy",
                optimizer=optimizer,
                metrics=["accuracy"]
            )
    
    return miCNN

# %%
def self_training(model_func, x_train, y_train, unlabeled_data, x_test, y_test, thresh=0.5, train_epochs=3):
    train_data = x_train.copy()
    train_label = y_train.copy()

    for i in range(train_epochs):
        model = model_func()
        print("Train Epoch: ", (i+1))
        model.fit(train_data, train_label, epochs=20,
                  batch_size=128, verbose=1)

        y_pred = model.predict(unlabeled_data)

        y_class = np.argmax(y_pred, axis=1)
        y_value = np.max(y_pred, axis=1)

        train_data = x_train.copy()
        train_label = y_train.copy()

        for x_u, y_c, y_v in zip(unlabeled_data, y_class, y_value):
            if y_v > thresh:
                x_u = x_u[np.newaxis, ...]   # pasamos de (32,32,3) a (1,32,32,3)
                train_data = np.concatenate((train_data, x_u), axis=0)
                train_label = np.append(train_label, y_c)

    return model

# %%
model = self_training(
    miCNN_func,
    x_train,
    y_train,
    unlabeled_train,
    x_test,
    y_test,
    thresh=0.9,
    train_epochs=5
)

_, test_accuracy = model.evaluate(x_test, y_test, verbose=1)

print("Test accuracy: ", test_accuracy)
# Out:
# Train Epoch:  1
# Epoch 1/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 12s 72ms/step - accuracy: 0.0536 - loss: 4.8769
# Epoch 2/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.1216 - loss: 4.0675
# Epoch 3/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.1639 - loss: 3.6913
# Epoch 4/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.2070 - loss: 3.3794
# Epoch 5/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.2455 - loss: 3.0946
# Epoch 6/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.2901 - loss: 2.8502
# Epoch 7/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3270 - loss: 2.6179
# Epoch 8/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3750 - loss: 2.3933
# Epoch 9/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4121 - loss: 2.2334
# Epoch 10/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.4632 - loss: 2.0164
# Epoch 11/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.4933 - loss: 1.8644
# Epoch 12/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.5232 - loss: 1.7440
# Epoch 13/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5624 - loss: 1.5852
# Epoch 14/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.5781 - loss: 1.5114
# Epoch 15/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6208 - loss: 1.3403
# Epoch 16/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6532 - loss: 1.2300
# Epoch 17/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6712 - loss: 1.1436
# Epoch 18/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7024 - loss: 1.0337
# Epoch 19/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7164 - loss: 0.9697
# Epoch 20/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7412 - loss: 0.8828
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step
# Train Epoch:  2
# Epoch 1/20
# 118/121 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1174 - loss: 4.6360
# 2026-04-10 18:29:02.275991: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-04-10 18:29:02.826334: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3868', 116 bytes spill stores, 116 bytes spill loads
#
# 2026-04-10 18:29:02.886087: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3885', 116 bytes spill stores, 116 bytes spill loads
#
# 2026-04-10 18:29:03.178822: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2672', 60 bytes spill stores, 60 bytes spill loads
#
# 2026-04-10 18:29:03.527386: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2672', 11756 bytes spill stores, 11088 bytes spill loads
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 16s 78ms/step - accuracy: 0.1831 - loss: 4.0013
# Epoch 2/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.3276 - loss: 2.9369
# Epoch 3/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.4209 - loss: 2.4536
# Epoch 4/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.4938 - loss: 2.0927
# Epoch 5/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.5439 - loss: 1.8421
# Epoch 6/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.5774 - loss: 1.6363
# Epoch 7/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6234 - loss: 1.4645
# Epoch 8/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6492 - loss: 1.3320
# Epoch 9/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6685 - loss: 1.2286
# Epoch 10/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6918 - loss: 1.1253
# Epoch 11/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7231 - loss: 1.0016
# Epoch 12/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7397 - loss: 0.9222
# Epoch 13/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7612 - loss: 0.8431
# Epoch 14/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7828 - loss: 0.7582
# Epoch 15/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8026 - loss: 0.6795
# Epoch 16/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8092 - loss: 0.6409
# Epoch 17/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.8294 - loss: 0.5743
# Epoch 18/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8387 - loss: 0.5367
# Epoch 19/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8524 - loss: 0.4832
# Epoch 20/20
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8571 - loss: 0.4636
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step
# Train Epoch:  3
# Epoch 1/20
# 167/168 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1528 - loss: 4.2423
# 2026-04-10 18:36:46.446598: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-04-10 18:36:47.284125: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2672', 60 bytes spill stores, 60 bytes spill loads
#
# 2026-04-10 18:36:47.594963: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3868', 104 bytes spill stores, 104 bytes spill loads
#
# 2026-04-10 18:36:47.703193: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3885', 104 bytes spill stores, 104 bytes spill loads
#
# 2026-04-10 18:36:47.742193: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2672', 11756 bytes spill stores, 11088 bytes spill loads
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 21s 80ms/step - accuracy: 0.2347 - loss: 3.5717
# Epoch 2/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.4213 - loss: 2.4258
# Epoch 3/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.5303 - loss: 1.9160
# Epoch 4/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.5997 - loss: 1.5902
# Epoch 5/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.6481 - loss: 1.3825
# Epoch 6/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.6795 - loss: 1.2284
# Epoch 7/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7076 - loss: 1.1029
# Epoch 8/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.7256 - loss: 1.0187
# Epoch 9/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7512 - loss: 0.9086
# Epoch 10/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7667 - loss: 0.8292
# Epoch 11/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7764 - loss: 0.7815
# Epoch 12/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8014 - loss: 0.6985
# Epoch 13/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8081 - loss: 0.6515
# Epoch 14/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8228 - loss: 0.5922
# Epoch 15/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8364 - loss: 0.5420
# Epoch 16/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.8431 - loss: 0.5132
# Epoch 17/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8520 - loss: 0.4818
# Epoch 18/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8641 - loss: 0.4333
# Epoch 19/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8780 - loss: 0.4019
# Epoch 20/20
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8819 - loss: 0.3771
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# Train Epoch:  4
# Epoch 1/20
# 200/201 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.1516 - loss: 4.2132
# 2026-04-10 18:48:07.209317: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-04-10 18:48:07.209490: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-04-10 18:48:07.636232: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2672', 20 bytes spill stores, 20 bytes spill loads
#
# 2026-04-10 18:48:07.900643: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2672', 856 bytes spill stores, 720 bytes spill loads
#
# 2026-04-10 18:48:07.969611: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3351', 12 bytes spill stores, 12 bytes spill loads
#
# 2026-04-10 18:48:08.001377: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3351', 4 bytes spill stores, 4 bytes spill loads
#
# 2026-04-10 18:48:08.075214: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3885', 108 bytes spill stores, 108 bytes spill loads
#
# 2026-04-10 18:48:08.351984: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3351', 8 bytes spill stores, 8 bytes spill loads
#
# 2026-04-10 18:48:08.448641: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3868', 100 bytes spill stores, 100 bytes spill loads
#
# 2026-04-10 18:48:08.482846: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3351', 12 bytes spill stores, 12 bytes spill loads
#
# 2026-04-10 18:48:08.497361: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3885', 168 bytes spill stores, 168 bytes spill loads
#
# 2026-04-10 18:48:11.593014: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng2{k2=1,k3=0} for conv (f32[62,64,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[62,64,32,32]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2026-04-10 18:48:11.601388: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.950283785s
# Trying algorithm eng2{k2=1,k3=0} for conv (f32[62,64,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[62,64,32,32]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 20s 65ms/step - accuracy: 0.2316 - loss: 3.5345
# Epoch 2/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.4385 - loss: 2.2856
# Epoch 3/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.5593 - loss: 1.7437
# Epoch 4/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.6273 - loss: 1.4575
# Epoch 5/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.6698 - loss: 1.2738
# Epoch 6/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.6979 - loss: 1.1475
# Epoch 7/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7218 - loss: 1.0424
# Epoch 8/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.7378 - loss: 0.9483
# Epoch 9/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7573 - loss: 0.8844
# Epoch 10/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7791 - loss: 0.7902
# Epoch 11/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7906 - loss: 0.7365
# Epoch 12/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7997 - loss: 0.6880
# Epoch 13/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8131 - loss: 0.6415
# Epoch 14/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8292 - loss: 0.5858
# Epoch 15/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.8379 - loss: 0.5359
# Epoch 16/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8479 - loss: 0.5013
# Epoch 17/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.8521 - loss: 0.4803
# Epoch 18/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.8622 - loss: 0.4494
# Epoch 19/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8735 - loss: 0.4069
# Epoch 20/20
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8737 - loss: 0.3999
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Train Epoch:  5
# Epoch 1/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 18s 39ms/step - accuracy: 0.2461 - loss: 3.4065
# Epoch 2/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.4267 - loss: 2.3267
# Epoch 3/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.5412 - loss: 1.8189
# Epoch 4/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.5898 - loss: 1.5884
# Epoch 5/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5414 - loss: 1.8022
# Epoch 6/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.5581 - loss: 1.7239
# Epoch 7/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6571 - loss: 1.3146
# Epoch 8/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6544 - loss: 1.3030
# Epoch 9/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6578 - loss: 1.2888
# Epoch 10/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.6084 - loss: 1.5045
# Epoch 11/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.6460 - loss: 1.3295
# Epoch 12/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - accuracy: 0.6229 - loss: 1.4137
# Epoch 13/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7015 - loss: 1.1025
# Epoch 14/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.6354 - loss: 1.3777
# Epoch 15/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.6964 - loss: 1.1151
# Epoch 16/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7209 - loss: 1.0209
# Epoch 17/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7370 - loss: 0.9474
# Epoch 18/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7416 - loss: 0.9271
# Epoch 19/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.7697 - loss: 0.8237
# Epoch 20/20
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7687 - loss: 0.8092
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4221 - loss: 2.6144
# Test accuracy:  0.4221000075340271

# %% [markdown]
# #### Responde las siguientes preguntas:
# ####    a. ¿Qué parámetros has definido para el entrenamiento?
# ####    b. ¿Cuál es el rendimiento del modelo en entrenamiento? ¿Y en prueba?
# ####    c. ¿Se mejoran los resultados obtenidos en el Ejercicio 1?
# ####    d. ¿Qué conclusiones sacas de los resultados detallados en los puntos anteriores?

# %% [markdown]
# #### 3. Entrena un modelo de aprendizaje semisupervisado de tipo autoencoder en dos pasos (primero el autoencoder, después el clasificador). La arquitectura del encoder debe ser exactamente la misma que la definida en los Ejercicios 1 y 2, a excepción del último bloque de capas.

# %%
class MiAutoencoder:
    def __init__(self, input_shape):
        # encoder
        input_layer = tf.keras.layers.Input(shape=input_shape)
        x = tf.keras.layers.Conv2D(64, (3, 3), activation="relu", padding='same')(input_layer)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Conv2D(64, (3, 3), activation="relu", padding='same')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
        x = tf.keras.layers.Dropout(0.2)(x)

        x = tf.keras.layers.Conv2D(128, (3, 3), activation="relu", padding='same')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Conv2D(128, (3, 3), activation="relu", padding='same')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
        x = tf.keras.layers.Dropout(0.3)(x)

        x = tf.keras.layers.Conv2D(256, (3, 3), activation="relu", padding='same')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        code = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
        
        # decoder
        x = tf.keras.layers.UpSampling2D((2, 2))(code)
        x = tf.keras.layers.Conv2D(256, (3, 3), activation="relu", padding='same')(x)
        x = tf.keras.layers.BatchNormalization()(x)

        x = tf.keras.layers.UpSampling2D((2, 2))(x)
        x = tf.keras.layers.Conv2D(128, (3, 3), activation="relu", padding='same')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Conv2D(128, (3, 3), activation="relu", padding='same')(x)
        x = tf.keras.layers.BatchNormalization()(x)

        x = tf.keras.layers.UpSampling2D((2, 2))(x)
        x = tf.keras.layers.Conv2D(64, (3, 3), activation="relu", padding='same')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Conv2D(64, (3, 3), activation="relu", padding='same')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        output_layer = tf.keras.layers.Conv2D(3, (3, 3), activation="sigmoid", padding="same")(x)

        self.autoencoder = tf.keras.Model(input_layer, output_layer)
        self.encoder = tf.keras.Model(input_layer, code)
        self.decoder = tf.keras.Model(code, output_layer)

        self.autoencoder.compile(optimizer="adam", loss="mse")

    def fit(self, X, y=None, sample_weight=None):
        self.autoencoder.fit(
            X, X,
            epochs=5,
            batch_size=128,
            shuffle=True,
            sample_weight=sample_weight,
            verbose=1
        )

    def get_encoded_data(self, X):
        return self.encoder.predict(X)

    def __del__(self):
        tf.keras.backend.clear_session()

# %%
class MiClasificador:

    def __init__(self, input_shape):
        self.model = tf.keras.Sequential([
            tf.keras.layers.Flatten(input_shape=(4, 4, 256)),
            tf.keras.layers.Dense(512, activation="relu"),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(100, activation="softmax")
        ])

        self.model.compile(
            optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

    def fit(self, X, y, sample_weight=None):
        self.model.fit(
            X, y,
            epochs=10,
            batch_size=128,
            shuffle=True,
            sample_weight=sample_weight,
            verbose=1
        )

    def predict(self, X):
        probs = self.model.predict(X)
        return np.argmax(probs, axis=1)

    def predict_proba(self, X):
        return self.model.predict(X)

    def score(self, X, y):
        loss, acc = self.model.evaluate(X, y, verbose=0)
        return acc

    def __del__(self):
        tf.keras.backend.clear_session()

# %%
def semisupervised_training(autoencoder, classifier, x_train, y_train, unlabeled_data):

    all_data = np.concatenate((x_train, unlabeled_data), axis=0)
    autoencoder.fit(all_data)
    code = autoencoder.get_encoded_data(x_train)
    classifier.fit(code, y_train)

    return autoencoder, classifier

# %%
autoencoder = MiAutoencoder(input_shape=x_train.shape[1:])
classifier = MiClasificador(input_shape=256)  # tamaño del code

autoencoder, classifier = semisupervised_training(
    autoencoder,
    classifier,
    x_train,
    y_train,
    unlabeled_train
)

pred_data = autoencoder.get_encoded_data(x_test)
print("Test accuracy :", classifier.score(pred_data, y_test))
# Out:
# c:\Users\Usuario\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 452s 1s/step - loss: 0.5834
# Epoch 2/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 468s 1s/step - loss: 0.5571
# Epoch 3/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 462s 1s/step - loss: 0.5519
# Epoch 4/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 463s 1s/step - loss: 0.5496
# Epoch 5/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 799s 2s/step - loss: 0.5480
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step
# Epoch 1/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.0795 - loss: 4.6410
# Epoch 2/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.1845 - loss: 3.5607
# Epoch 3/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.2737 - loss: 3.0881
# Epoch 4/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3395 - loss: 2.6911
# Epoch 5/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4083 - loss: 2.3767
# Epoch 6/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4720 - loss: 2.1014
# Epoch 7/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5265 - loss: 1.8284
# Epoch 8/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5805 - loss: 1.6238
# Epoch 9/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6264 - loss: 1.4574
# Epoch 10/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6682 - loss: 1.2564
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step
# Test accuracy : 0.2337000072002411

# %% [markdown]
# #### Responde las siguientes preguntas:
# ####    a. ¿Cuál es la arquitectura del modelo? ¿Y sus hiperparámetros?
# ####    b. ¿Cuál es el rendimiento del modelo en entrenamiento? ¿Y en prueba?
# ####    c. ¿Se mejoran los resultados obtenidos en los Ejercicios 1 y 2?
# ####    d. ¿Qué conclusiones sacas de los resultados detallados en los puntos anteriores?

# %% [markdown]
# #### 4. Entrena un modelo de aprendizaje semisupervisado de tipo autoencoder en un paso (autoencoder y clasificador al mismo tiempo). La arquitectura del autoencoder será la misma que la definida en el Ejercicio 3, y la combinación de encoder y clasificador será igual a la arquitectura definida en el Ejercicio 1.

# %%
class MiClasificadorSemisupervisado:
    def __init__(self, input_shape):
        inputs = tf.keras.layers.Input(shape=input_shape)
        # encoder
        x = tf.keras.layers.Conv2D(64, (3, 3), activation="relu", padding='same')(inputs)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Conv2D(64, (3, 3), activation="relu", padding='same')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
        x = tf.keras.layers.Dropout(0.2)(x)

        x = tf.keras.layers.Conv2D(128, (3, 3), activation="relu", padding='same')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Conv2D(128, (3, 3), activation="relu", padding='same')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
        x = tf.keras.layers.Dropout(0.3)(x)

        x = tf.keras.layers.Conv2D(256, (3, 3), activation="relu", padding='same')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        code = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
        
        # decoder
        x_decoder = tf.keras.layers.UpSampling2D((2, 2))(code)
        x_decoder = tf.keras.layers.Conv2D(256, (3, 3), activation="relu", padding='same')(x_decoder)
        x_decoder = tf.keras.layers.BatchNormalization()(x_decoder)

        x_decoder = tf.keras.layers.UpSampling2D((2, 2))(x_decoder)
        x_decoder = tf.keras.layers.Conv2D(128, (3, 3), activation="relu", padding='same')(x_decoder)
        x_decoder = tf.keras.layers.BatchNormalization()(x_decoder)
        x_decoder = tf.keras.layers.Conv2D(128, (3, 3), activation="relu", padding='same')(x_decoder)
        x_decoder = tf.keras.layers.BatchNormalization()(x_decoder)

        x_decoder = tf.keras.layers.UpSampling2D((2, 2))(x_decoder)
        x_decoder = tf.keras.layers.Conv2D(64, (3, 3), activation="relu", padding='same')(x_decoder)
        x_decoder = tf.keras.layers.BatchNormalization()(x_decoder)
        x_decoder = tf.keras.layers.Conv2D(64, (3, 3), activation="relu", padding='same')(x_decoder)
        x_decoder = tf.keras.layers.BatchNormalization()(x_decoder)
        decoding = tf.keras.layers.Conv2D(3, (3, 3), activation="sigmoid", padding="same", name="decoding")(x_decoder)

        # clasificador
        x_classifier = tf.keras.layers.GlobalAveragePooling2D()(code)
        x_classifier = tf.keras.layers.Dense(512, activation="relu")(x_classifier)
        x_classifier = tf.keras.layers.BatchNormalization()(x_classifier)
        x_classifier = tf.keras.layers.Dropout(0.5)(x_classifier)
        classification = tf.keras.layers.Dense(100, activation="softmax", name="classification")(x_classifier)

        self.model = tf.keras.Model(inputs=inputs, outputs=[decoding, classification])

        self.model.compile(
            optimizer="adam",
            loss={"decoding": "mse", "classification": "sparse_categorical_crossentropy"},
            loss_weights={"decoding": 0.5, "classification": 5.0},
            metrics={"classification": "accuracy"}
        )

    def fit(self, X, y, unlabeled_data):
        X_all = np.concatenate((X, unlabeled_data), axis=0)

        y_decoding = X_all    # la etiqueta es la propia entrada
        y_classification = np.concatenate((y.reshape(-1), np.zeros(len(unlabeled_data))))

        w_classification = np.concatenate((np.ones(len(X))*2.0, np.zeros(len(unlabeled_data))))     # le damos peso=2 a los etiquetados ya que son muy pocos datos

        self.model.fit(
            X_all,
            [y_decoding, y_classification],
            sample_weight=[None, w_classification],
            epochs=15,
            batch_size=256,
            shuffle=True,
            verbose=1
        )

    def predict(self, X):
        _, probs = self.model.predict(X)
        return np.argmax(probs, axis=1)

    def predict_proba(self, X):
        _, probs = self.model.predict(X)
        return probs

    def score(self, X, y):
        preds = self.predict(X)
        return np.mean(preds == y)

    def __del__(self):
        tf.keras.backend.clear_session()

# %%
def semisupervised_training_v2(model, x_train, y_train, unlabeled_data):
    model.fit(x_train, y_train, unlabeled_data)
    return model

# %%
model = MiClasificadorSemisupervisado(input_shape=x_train.shape[1:])

model = semisupervised_training_v2(
    model,
    x_train,
    y_train,
    unlabeled_train
)

print("Test accuracy :", model.score(x_test, y_test))
# Out:
# Epoch 1/15
# 2026-04-10 20:33:31.888580: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5317', 4 bytes spill stores, 4 bytes spill loads
# 195/196 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - classification_accuracy: 0.0157 - classification_loss: 2.0315 - decoding_loss: 0.6933 - loss: 10.5042
# 2026-04-10 20:34:09.866056: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-04-10 20:34:09.866124: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 55s 170ms/step - classification_accuracy: 0.0194 - classification_loss: 1.9353 - decoding_loss: 0.6379 - loss: 9.9962
# Epoch 2/15
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - classification_accuracy: 0.0236 - classification_loss: 1.7210 - decoding_loss: 0.6053 - loss: 8.9062
# Epoch 3/15
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 24s 122ms/step - classification_accuracy: 0.0307 - classification_loss: 1.6067 - decoding_loss: 0.5990 - loss: 8.3286
# Epoch 4/15
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 43s 119ms/step - classification_accuracy: 0.0337 - classification_loss: 1.5099 - decoding_loss: 0.5974 - loss: 7.8482
# Epoch 5/15
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 24s 121ms/step - classification_accuracy: 0.0450 - classification_loss: 1.4168 - decoding_loss: 0.5953 - loss: 7.3797
# Epoch 6/15
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 21s 106ms/step - classification_accuracy: 0.0520 - classification_loss: 1.3270 - decoding_loss: 0.5937 - loss: 6.9337
# Epoch 7/15
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 25s 128ms/step - classification_accuracy: 0.0544 - classification_loss: 1.2740 - decoding_loss: 0.5923 - loss: 6.6649
# Epoch 8/15
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 22s 114ms/step - classification_accuracy: 0.0621 - classification_loss: 1.1924 - decoding_loss: 0.5908 - loss: 6.2595
# Epoch 9/15
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 23s 118ms/step - classification_accuracy: 0.0676 - classification_loss: 1.1083 - decoding_loss: 0.5903 - loss: 5.8353
# Epoch 10/15
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - classification_accuracy: 0.0735 - classification_loss: 1.0487 - decoding_loss: 0.5893 - loss: 5.5381
# Epoch 11/15
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 22s 110ms/step - classification_accuracy: 0.0791 - classification_loss: 0.9882 - decoding_loss: 0.5914 - loss: 5.2461
# Epoch 12/15
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - classification_accuracy: 0.0861 - classification_loss: 0.9192 - decoding_loss: 0.5905 - loss: 4.8899
# Epoch 13/15
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 43s 109ms/step - classification_accuracy: 0.0933 - classification_loss: 0.8469 - decoding_loss: 0.5905 - loss: 4.5243
# Epoch 14/15
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 24s 120ms/step - classification_accuracy: 0.1002 - classification_loss: 0.7852 - decoding_loss: 0.5908 - loss: 4.2165
# Epoch 15/15
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - classification_accuracy: 0.1063 - classification_loss: 0.7239 - decoding_loss: 0.5898 - loss: 3.9138
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step
# Test accuracy : 0.01

# %% [markdown]
# #### Responde las siguientes preguntas:
# ####    a. ¿Cuál es la arquitectura del modelo? ¿Y sus hiperparámetros?
# ####    b. ¿Cuál es el rendimiento del modelo en entrenamiento? ¿Y en prueba?
# ####    c. ¿Se mejoran los resultados obtenidos en los ejercicios anteriores?
# ####    d. ¿Qué conclusiones sacas de los resultados detallados en los puntos anteriores?

# %% [markdown]
# #### 5. Repite el mismo entrenamiento de los Ejercicios 2-4, pero eliminando las instancias no etiquetadas más atípicas con respecto a los datos etiquetados. Se cumplirán los siguientes puntos:

# %% [markdown]
# #### · La arquitectura de la red de clasificación en una clase será la misma a la utilizada en el clasificador del Ejercicio 1, a excepción de la capa de salida.
#
# #### ·  Utiliza la técnica explicada en el Notebook 5, usando un valor de 𝑣 = 0,9.

# %%
class ChangeRCallback(tf.keras.callbacks.Callback):
   def __init__(self, train_data, delta=.25, steps=3):
       super().__init__()
       self.train_data = train_data
       self.delta = delta
       self.steps = steps
       self.cont = 0

   def on_epoch_end(self, epoch, logs=None):
       sorted_values = np.sort(self.model.predict(self.train_data).flatten())
       new_value = sorted_values[int(len(sorted_values) * (1. - self.model.nu))]
       old_value = self.model.r.numpy()
       print('Cambiando r a', new_value, ', max:', sorted_values.max(), ', min:', sorted_values.min())
       self.model.r.assign(new_value)
       if np.abs(old_value - new_value) < self.delta:
            self.cont += 1
            if self.cont >= self.steps:
                print('Convergencia obtenida. Finalizando el entrenamiento.')
                self.model.stop_training = True
       else:
            self.cont = 0

# %%
class DetectorAnomalias:

    def __init__(self, nu=.5):
        input_shape = (32, 32, 3)
        inputs = tf.keras.layers.Input(shape=input_shape)
        l2_val = 1e-4
        x = tf.keras.layers.Conv2D(64, 3, activation="relu", kernel_regularizer=tf.keras.regularizers.L2(l2_val))(inputs)
        x = tf.keras.layers.Conv2D(64, 3, activation="relu", kernel_regularizer=tf.keras.regularizers.L2(l2_val))(x)
        x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

        x = tf.keras.layers.Conv2D(128, 3, activation="relu", kernel_regularizer=tf.keras.regularizers.L2(l2_val))(x)
        x = tf.keras.layers.Conv2D(128, 3, activation="relu", kernel_regularizer=tf.keras.regularizers.L2(l2_val))(x)
        x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

        x = tf.keras.layers.Conv2D(256, 3, activation="relu", kernel_regularizer=tf.keras.regularizers.L2(l2_val))(x)
        x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

        x = tf.keras.layers.Flatten()(x)
        x = tf.keras.layers.Dense(512, activation="relu")(x)

        outputs = tf.keras.layers.Dense(1, activation='linear')(x)

        self.model = tf.keras.models.Model(inputs, outputs)

        self.model.r = tf.Variable(1.0, trainable=False, name='r', dtype=tf.float32)
        self.model.nu = tf.Variable(nu, trainable=False, name='nu', dtype=tf.float32)

        self.model.compile(optimizer="Adam",
                           loss=self.loss_function)

    def loss_function(self, y_true, y_pred):
        l2 = tf.add_n([tf.reduce_sum(tf.square(var)) for var in self.model.trainable_weights])
        reg_loss = 0.5 * l2
        return reg_loss + (1 / (self.model.nu * tf.cast(tf.shape(y_true)[0], tf.float32))) * tf.reduce_sum(tf.maximum(0.0, self.model.r - y_pred))
    
    def fit(self, X, y=None, sample_weight=None, epochs=20, batch_size=32):
        dummy_y = np.zeros((len(X), 1))

        return self.model.fit(
            X,
            dummy_y,
            epochs=epochs,
            batch_size=batch_size,
            verbose=1,
            callbacks=[
                ChangeRCallback(X)
            ]
        )
        
    def predict(self, X, batch_size=32):
        preds = []
        for i in range(0, len(X), batch_size):
            batch = X[i:i+batch_size]
            p = self.model(batch, training=False)
            preds.append(p.numpy())
        return np.vstack(preds)
        
    def __del__(self):
        tf.keras.backend.clear_session()

# %%
modelo_detector = DetectorAnomalias(0.9)
modelo_detector.fit(x_train, batch_size=128)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775854196.376143     592 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3554 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/20
# 2026-04-10 22:49:59.086443: I external/local_xla/xla/service/service.cc:163] XLA service 0x75468000db30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-04-10 22:49:59.086466: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 4050 Laptop GPU, Compute Capability 8.9
# 2026-04-10 22:49:59.161151: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-04-10 22:49:59.470149: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91400
# 13/79 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 348.3378
# I0000 00:00:1775854203.711259     793 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step
# Cambiando r a 0.844226 , max: 1.639473 , min: 0.60111165
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 14s 100ms/step - loss: 97.8046
# Epoch 2/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Cambiando r a 0.6967982 , max: 1.2870616 , min: 0.52263343
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1.8553
# Epoch 3/20
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Cambiando r a 0.62533367 , max: 0.9311915 , min: 0.54339695
# Convergencia obtenida. Finalizando el entrenamiento.
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.6802

# %%
typical_unlabeled_data = unlabeled_train[(modelo_detector.predict(unlabeled_train) > modelo_detector.model.r)[:, 0]]

# %%
model = self_training(
    miCNN_func,
    x_train,
    y_train,
    typical_unlabeled_data,
    x_test,
    y_test,
    thresh=0.9,
    train_epochs=5
)

_, test_accuracy = model.evaluate(x_test, y_test, verbose=1)

print("Test accuracy: ", test_accuracy)
# Out:
# /mnt/c/Users/npanb/Documents/wsl_entornos_python/AP/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Train Epoch:  1
# Epoch 1/20
# 2026-04-10 19:49:35.627442: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2677', 11260 bytes spill stores, 11408 bytes spill loads
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 90ms/step - accuracy: 0.0555 - loss: 4.8821
# Epoch 2/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.1116 - loss: 4.0792
# Epoch 3/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.1685 - loss: 3.6483
# Epoch 4/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.2122 - loss: 3.3115
# Epoch 5/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.2542 - loss: 3.0440
# Epoch 6/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3021 - loss: 2.7829
# Epoch 7/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3506 - loss: 2.5524
# Epoch 8/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3945 - loss: 2.3399
# Epoch 9/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.4290 - loss: 2.1619
# Epoch 10/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.4739 - loss: 1.9748
# Epoch 11/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5059 - loss: 1.8111
# Epoch 12/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.5361 - loss: 1.6844
# Epoch 13/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.5783 - loss: 1.5392
# Epoch 14/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.5921 - loss: 1.4209
# Epoch 15/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6289 - loss: 1.2968
# Epoch 16/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6482 - loss: 1.2155
# Epoch 17/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6845 - loss: 1.0969
# Epoch 18/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7135 - loss: 0.9886
# Epoch 19/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7329 - loss: 0.9062
# Epoch 20/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.5995 - loss: 1.3695
# 2026-04-10 19:50:24.932064: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_174', 60 bytes spill stores, 60 bytes spill loads
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step
# Train Epoch:  2
# Epoch 1/20
# 121/122 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1248 - loss: 4.5232
# 2026-04-10 19:53:11.633030: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2672', 60 bytes spill stores, 60 bytes spill loads
#
# 2026-04-10 19:53:11.709643: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3868', 100 bytes spill stores, 100 bytes spill loads
#
# 2026-04-10 19:53:11.921627: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2672', 11756 bytes spill stores, 11088 bytes spill loads
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 16s 79ms/step - accuracy: 0.1850 - loss: 3.9590
# Epoch 2/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.3282 - loss: 2.9619
# Epoch 3/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.4178 - loss: 2.4660
# Epoch 4/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.4880 - loss: 2.1239
# Epoch 5/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.5287 - loss: 1.8870
# Epoch 6/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.5745 - loss: 1.6641
# Epoch 7/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6097 - loss: 1.5083
# Epoch 8/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6397 - loss: 1.3672
# Epoch 9/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6661 - loss: 1.2389
# Epoch 10/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6873 - loss: 1.1321
# Epoch 11/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7184 - loss: 1.0157
# Epoch 12/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.7363 - loss: 0.9411
# Epoch 13/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.7556 - loss: 0.8613
# Epoch 14/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.7755 - loss: 0.7741
# Epoch 15/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8015 - loss: 0.6917
# Epoch 16/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.8121 - loss: 0.6369
# Epoch 17/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8244 - loss: 0.5796
# Epoch 18/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8285 - loss: 0.5623
# Epoch 19/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8467 - loss: 0.5080
# Epoch 20/20
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8631 - loss: 0.4546
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Train Epoch:  3
# Epoch 1/20
# 151/154 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1501 - loss: 4.3183
# 2026-04-10 19:59:28.152872: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2955', 60 bytes spill stores, 60 bytes spill loads
#
# 2026-04-10 19:59:28.325979: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3860', 112 bytes spill stores, 112 bytes spill loads
#
# 2026-04-10 19:59:28.491580: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2955', 11756 bytes spill stores, 11088 bytes spill loads
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.2271 - loss: 3.6486
# Epoch 2/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.4130 - loss: 2.4923
# Epoch 3/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.5128 - loss: 1.9902
# Epoch 4/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.5753 - loss: 1.6976
# Epoch 5/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6121 - loss: 1.5189
# Epoch 6/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6517 - loss: 1.3457
# Epoch 7/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6813 - loss: 1.2139
# Epoch 8/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7003 - loss: 1.1060
# Epoch 9/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.7219 - loss: 1.0088
# Epoch 10/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7415 - loss: 0.9329
# Epoch 11/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.7643 - loss: 0.8410
# Epoch 12/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7769 - loss: 0.7827
# Epoch 13/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7970 - loss: 0.7035
# Epoch 14/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8079 - loss: 0.6508
# Epoch 15/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8253 - loss: 0.5861
# Epoch 16/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8398 - loss: 0.5325
# Epoch 17/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8437 - loss: 0.5113
# Epoch 18/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8552 - loss: 0.4746
# Epoch 19/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8635 - loss: 0.4566
# Epoch 20/20
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8719 - loss: 0.4153
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Train Epoch:  4
# Epoch 1/20
# 178/180 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1525 - loss: 4.2381
# 2026-04-10 20:08:27.354009: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-04-10 20:08:27.354146: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-04-10 20:08:27.776164: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2672', 20 bytes spill stores, 20 bytes spill loads
#
# 2026-04-10 20:08:28.008222: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3351', 12 bytes spill stores, 12 bytes spill loads
#
# 2026-04-10 20:08:28.009995: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2672', 856 bytes spill stores, 720 bytes spill loads
#
# 2026-04-10 20:08:28.351673: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3885', 108 bytes spill stores, 108 bytes spill loads
#
# 2026-04-10 20:08:28.430591: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3351', 8 bytes spill stores, 8 bytes spill loads
#
# 2026-04-10 20:08:28.464363: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3351', 12 bytes spill stores, 12 bytes spill loads
#
# 2026-04-10 20:08:28.488734: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3351', 4 bytes spill stores, 4 bytes spill loads
#
# 2026-04-10 20:08:28.698328: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3868', 104 bytes spill stores, 104 bytes spill loads
#
# 2026-04-10 20:08:28.745030: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3885', 36 bytes spill stores, 36 bytes spill loads
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 19s 57ms/step - accuracy: 0.2287 - loss: 3.5728
# Epoch 2/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.4123 - loss: 2.4312
# Epoch 3/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.5276 - loss: 1.8937
# Epoch 4/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.5907 - loss: 1.5956
# Epoch 5/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.6373 - loss: 1.3904
# Epoch 6/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.6732 - loss: 1.2322
# Epoch 7/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.6998 - loss: 1.1257
# Epoch 8/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7233 - loss: 1.0201
# Epoch 9/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7442 - loss: 0.9261
# Epoch 10/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.7574 - loss: 0.8580
# Epoch 11/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7765 - loss: 0.7805
# Epoch 12/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7917 - loss: 0.7257
# Epoch 13/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7974 - loss: 0.6843
# Epoch 14/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.8191 - loss: 0.6166
# Epoch 15/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8239 - loss: 0.5848
# Epoch 16/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8397 - loss: 0.5241
# Epoch 17/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8481 - loss: 0.4961
# Epoch 18/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8610 - loss: 0.4555
# Epoch 19/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.8634 - loss: 0.4411
# Epoch 20/20
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.8714 - loss: 0.4146
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# Train Epoch:  5
# Epoch 1/20
# 196/199 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1543 - loss: 4.1511
# 2026-04-10 20:19:32.153955: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-04-10 20:19:32.909764: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2672', 60 bytes spill stores, 60 bytes spill loads
#
# 2026-04-10 20:19:32.973486: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3868', 116 bytes spill stores, 116 bytes spill loads
#
# 2026-04-10 20:19:33.211099: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3885', 120 bytes spill stores, 120 bytes spill loads
#
# 2026-04-10 20:19:33.307356: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2672', 11756 bytes spill stores, 11088 bytes spill loads
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 20s 67ms/step - accuracy: 0.2440 - loss: 3.4366
# Epoch 2/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.4487 - loss: 2.2464
# Epoch 3/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.5530 - loss: 1.7697
# Epoch 4/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.6196 - loss: 1.4848
# Epoch 5/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.6586 - loss: 1.3175
# Epoch 6/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.6892 - loss: 1.1793
# Epoch 7/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.7133 - loss: 1.0716
# Epoch 8/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7310 - loss: 0.9877
# Epoch 9/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7491 - loss: 0.9051
# Epoch 10/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7705 - loss: 0.8324
# Epoch 11/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7775 - loss: 0.7688
# Epoch 12/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.7948 - loss: 0.7117
# Epoch 13/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8024 - loss: 0.6744
# Epoch 14/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.8186 - loss: 0.6149
# Epoch 15/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8236 - loss: 0.5925
# Epoch 16/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8371 - loss: 0.5389
# Epoch 17/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8444 - loss: 0.5090
# Epoch 18/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8530 - loss: 0.4773
# Epoch 19/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8564 - loss: 0.4585
# Epoch 20/20
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8687 - loss: 0.4217
# 1125/1125 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4418 - loss: 2.7950
# Test accuracy:  0.44179999828338623

# %%
autoencoder = MiAutoencoder(input_shape=x_train.shape[1:])
classifier = MiClasificador(input_shape=256)  # tamaño del code

autoencoder, classifier = semisupervised_training(
    autoencoder,
    classifier,
    x_train,
    y_train,
    typical_unlabeled_data
)

pred_data = autoencoder.get_encoded_data(x_test)
print("Test accuracy :", classifier.score(pred_data, y_test))
# Out:
# Epoch 1/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 34s 71ms/step - loss: 0.6083
# Epoch 2/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - loss: 0.5824
# Epoch 3/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 22s 61ms/step - loss: 0.5778
# Epoch 4/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step - loss: 0.5751
# Epoch 5/5
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - loss: 0.5736
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# Epoch 1/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.0845 - loss: 4.5934
# Epoch 2/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1953 - loss: 3.5681
# Epoch 3/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2660 - loss: 3.1243
# Epoch 4/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3367 - loss: 2.7175
# Epoch 5/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4063 - loss: 2.4160
# Epoch 6/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4574 - loss: 2.1347
# Epoch 7/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5170 - loss: 1.9017
# Epoch 8/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5696 - loss: 1.6840
# Epoch 9/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6124 - loss: 1.4935
# Epoch 10/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6599 - loss: 1.3039
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Test accuracy : 0.23720000684261322

# %%
model = MiClasificadorSemisupervisado(input_shape=x_train.shape[1:])

model = semisupervised_training_v2(
    model,
    x_train,
    y_train,
    typical_unlabeled_data
)

print("Test accuracy :", model.score(x_test, y_test))
# Out:
# Epoch 1/15
# 2026-04-10 22:53:19.063092: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5317', 4 bytes spill stores, 4 bytes spill loads
#
# 2026-04-10 22:53:22.084215: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.30GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-04-10 22:53:25.975731: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-04-10 22:53:28.121186: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.62GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 179/180 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - classification_accuracy: 0.0199 - classification_loss: 2.2106 - decoding_loss: 0.7133 - loss: 11.4099
# 2026-04-10 22:53:54.967543: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_5317', 4 bytes spill stores, 4 bytes spill loads
#
# 2026-04-10 22:53:56.984991: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.04GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-04-10 22:54:01.432570: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.21GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 54s 175ms/step - classification_accuracy: 0.0196 - classification_loss: 2.0932 - decoding_loss: 0.6612 - loss: 10.7938
# Epoch 2/15
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 21s 119ms/step - classification_accuracy: 0.0262 - classification_loss: 1.8753 - decoding_loss: 0.6296 - loss: 9.6893
# Epoch 3/15
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 22s 122ms/step - classification_accuracy: 0.0336 - classification_loss: 1.7266 - decoding_loss: 0.6240 - loss: 8.9457
# Epoch 4/15
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 19s 106ms/step - classification_accuracy: 0.0369 - classification_loss: 1.6272 - decoding_loss: 0.6210 - loss: 8.4478
# Epoch 5/15
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 22s 123ms/step - classification_accuracy: 0.0443 - classification_loss: 1.5301 - decoding_loss: 0.6186 - loss: 7.9629
# Epoch 6/15
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 19s 106ms/step - classification_accuracy: 0.0517 - classification_loss: 1.4425 - decoding_loss: 0.6176 - loss: 7.5217
# Epoch 7/15
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 22s 123ms/step - classification_accuracy: 0.0598 - classification_loss: 1.3505 - decoding_loss: 0.6162 - loss: 7.0617
# Epoch 8/15
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 22s 123ms/step - classification_accuracy: 0.0636 - classification_loss: 1.3005 - decoding_loss: 0.6177 - loss: 6.8110
# Epoch 9/15
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 19s 106ms/step - classification_accuracy: 0.0718 - classification_loss: 1.2040 - decoding_loss: 0.6176 - loss: 6.3280
# Epoch 10/15
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 22s 123ms/step - classification_accuracy: 0.0778 - classification_loss: 1.1374 - decoding_loss: 0.6161 - loss: 5.9935
# Epoch 11/15
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 22s 122ms/step - classification_accuracy: 0.0883 - classification_loss: 1.0435 - decoding_loss: 0.6168 - loss: 5.5281
# Epoch 12/15
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 20s 109ms/step - classification_accuracy: 0.0943 - classification_loss: 0.9818 - decoding_loss: 0.6167 - loss: 5.2189
# Epoch 13/15
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 22s 123ms/step - classification_accuracy: 0.1008 - classification_loss: 0.9072 - decoding_loss: 0.6171 - loss: 4.8431
# Epoch 14/15
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 19s 107ms/step - classification_accuracy: 0.1101 - classification_loss: 0.8422 - decoding_loss: 0.6168 - loss: 4.5180
# Epoch 15/15
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 22s 123ms/step - classification_accuracy: 0.1156 - classification_loss: 0.7820 - decoding_loss: 0.6170 - loss: 4.2177
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step
# Test accuracy : 0.01

# %% [markdown]
# #### Responde las siguientes preguntas:
# ####    a. ¿Se mejoran los resultados con respecto a los anteriores ejercicios? ¿Qué conclusiones sacas de estos resultados?

# %% [markdown]
# #### 6. Repite los Ejercicios 3-5 cambiando el autencoder por la técnica definida en el apartado “Hay vida más allá del autoencoder” del Notebook 4. Contesta a las preguntas de dichos ejercicios. Se cumplirán los siguientes puntos:
#
# ####    a. La arquitectura de la red será igual a la parte encoder del autencoder definido en los ejercicios anteriores
# ####    b. El modelo debe entrenar correctamente.

# %%
data_augmentation = tf.keras.models.Sequential(
    [
        tf.keras.layers.Input(shape=(32, 32, 3)),
        # tf.keras.layers.RandomFlip("horizontal"),  # Puede ser util en otros casos
        tf.keras.layers.RandomRotation(0.05),
        tf.keras.layers.RandomTranslation(0.15, 0.15),
        tf.keras.layers.RandomZoom(.15),
    ]
)

data_augmentation_2 = tf.keras.models.Sequential(
    [
        tf.keras.layers.Input(shape=(32, 32, 3)),
        # tf.keras.layers.RandomFlip("horizontal"),  # Puede ser util en otros casos
        tf.keras.layers.RandomTranslation(0.15, 0.15),
        tf.keras.layers.Resizing(48, 48), # para CIFAR, para MNIST usar 40 en lugar de 48
        tf.keras.layers.RandomCrop(32, 32), # para CIFAR, para MNIST usar 28 en lugar de 32
    ]
)

# %%
from sklearn.metrics import v_measure_score


class ModeloAug:

    def __init__(self, tau=5, lamda=0.5):
        self.tau = tau
        self.lamda = lamda
        self.aug = data_augmentation
        self.aug2 = data_augmentation_2


        inputs = tf.keras.layers.Input(shape=(32, 32, 3))
        # encoder
        x = tf.keras.layers.Conv2D(64, (3, 3), activation="relu", padding='same')(inputs)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Conv2D(64, (3, 3), activation="relu", padding='same')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
        x = tf.keras.layers.Dropout(0.2)(x)

        x = tf.keras.layers.Conv2D(128, (3, 3), activation="relu", padding='same')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Conv2D(128, (3, 3), activation="relu", padding='same')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
        x = tf.keras.layers.Dropout(0.3)(x)

        x = tf.keras.layers.Conv2D(256, (3, 3), activation="relu", padding='same')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

        x = tf.keras.layers.Flatten()(x)
        code = tf.keras.layers.Dense(512, activation="relu")(x)
        cluster = tf.keras.layers.Dense(100, activation="softmax", name="classification")(code)

        self.encoder = tf.keras.Model(inputs, code)
        self.cluster_model = tf.keras.Model(inputs, cluster)
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

    def loss_C(self, clustered1, clustered2):
        return tf.reduce_mean(clustered1*(1-clustered1) + clustered2*(1-clustered2))   # reduce_mean pasa de matriz a escalar

    def loss_M(self, encoded1, encoded2):
        encoded1 = tf.math.l2_normalize(encoded1, axis=1)
        encoded2 = tf.math.l2_normalize(encoded2, axis=1)
        M = tf.matmul(encoded1, encoded2, transpose_b=True)
        identity_matrix = tf.eye((tf.shape(encoded1)[0]))  # matriz identidad
        return tf.reduce_mean(
            tf.keras.losses.categorical_crossentropy(identity_matrix, (tf.nn.softmax(M/self.tau, axis=1)))
        )

    def fit(self, X, y_train, epochs=10, batch_size=128):
        y_true = np.array(y_train).flatten()
        dataset = tf.data.Dataset.from_tensor_slices(X).batch(batch_size)
        for epoch in range(epochs):
            total_epoch_loss = 0
            for batch in dataset:
                # batch = tf.reshape(batch, (-1, 32, 32, 3))
                with tf.GradientTape() as tape:
                    augX1 = self.aug(batch)
                    augX2 = self.aug2(batch)

                    encoded1 = self.encoder(augX1)
                    encoded2 = self.encoder(augX2)
                    
                    clustered1 = self.cluster_model(augX1)
                    clustered2 = self.cluster_model(augX2)

                    lossC = self.loss_C(clustered1, clustered2)
                    lossM = self.loss_M(encoded1, encoded2)

                    loss = lossM + self.lamda*lossC

                vars = self.cluster_model.trainable_variables    # cogemos solo los pesos del modelo completo (encoder+cluster)
                grads = tape.gradient(loss, vars)     # calculamos los gradientes del loss respecto a cada peso
                self.optimizer.apply_gradients(zip(grads, vars))   # actualizamos pesos
                total_epoch_loss += loss
            probs = self.cluster_model.predict(X, verbose=0)
            preds = np.argmax(probs, axis=1)
            v_measure = v_measure_score(y_true, preds)
            print("epoch:", (epoch+1), "loss:", float(total_epoch_loss), "V-measure: ", v_measure)

    def get_representation(self, X):
        return self.encoder.predict(X)

    def predict_clusters(self, X):
        probs = self.cluster_model.predict(X.reshape(-1, 32, 32, 3))
        return np.argmax(probs, axis=1)

    def __del__(self):
        tf.keras.backend.clear_session()

# %%
model = ModeloAug()
model.fit(x_train, y_train, epochs=15, batch_size=128)
# Out:
# 2026-04-10 23:09:49.314297: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-04-10 23:09:50.078396: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_163', 60 bytes spill stores, 60 bytes spill loads
# epoch: 1 loss: 373.8074951171875 V-measure:  0.08437741653013259
# 2026-04-10 23:10:08.324690: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# epoch: 2 loss: 371.8179626464844 V-measure:  0.08155863034364282
# epoch: 3 loss: 370.96746826171875 V-measure:  0.07062989611589324
# 2026-04-10 23:10:46.261331: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# epoch: 4 loss: 370.6966247558594 V-measure:  0.0816107982359687
# epoch: 5 loss: 370.3181457519531 V-measure:  0.07698026586413566
# epoch: 6 loss: 370.2868957519531 V-measure:  0.07272422013353698
# epoch: 7 loss: 369.9610595703125 V-measure:  0.07309533971127803
# 2026-04-10 23:12:01.915018: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# epoch: 8 loss: 369.9365539550781 V-measure:  0.07894057885664225
# epoch: 9 loss: 369.6603698730469 V-measure:  0.0749938351223694
# epoch: 10 loss: 369.6389465332031 V-measure:  0.07243784568126628
# epoch: 11 loss: 369.5028076171875 V-measure:  0.0761147608587437
# epoch: 12 loss: 369.4588317871094 V-measure:  0.07926326098807625
# epoch: 13 loss: 369.4644470214844 V-measure:  0.09651644378824963
# epoch: 14 loss: 369.55828857421875 V-measure:  0.0780892274351652
# epoch: 15 loss: 369.4405212402344 V-measure:  0.0827255983578685
